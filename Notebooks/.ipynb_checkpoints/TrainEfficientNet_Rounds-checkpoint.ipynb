# %%
import numpy as np 
import pandas as pd 
#import pydicom
import matplotlib.pyplot as plt 

import torch 
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.optim.lr_scheduler import ReduceLROnPlateau

from PIL import Image
from skimage.transform import resize
from sklearn.metrics import confusion_matrix, roc_curve, auc
from efficientnet_pytorch import EfficientNet

# %%
# upload train dataframe
train_df_allsamples = pd.read_csv("../TrainTestDataFrames/marking.csv")
train_df_allsamples.head()
# Out:
#    patient_id      image_id  target  source     sex  age_approx  \
# 0  IP_7279968  ISIC_2637011       0  ISIC20    male        45.0
# 1  IP_3075186  ISIC_0015719       0  ISIC20  female        45.0
# 2  IP_2842074  ISIC_0052212       0  ISIC20  female        50.0
# 3  IP_6890425  ISIC_0068279       0  ISIC20  female        45.0
# 4  IP_8723313  ISIC_0074268       0  ISIC20  female        55.0
#
#   anatom_site_general_challenge
# 0                     head/neck
# 1               upper extremity
# 2               lower extremity
# 3                     head/neck
# 4               upper extremity

# %%
# create dictionary that maps image name to target 
image_names = train_df_allsamples["image_id"].values 
targets = train_df_allsamples["target"].values
img_to_target = {image_name:target for image_name, target in zip(image_names, targets)}

percent_tp = sum(targets)/len(targets) * 100 
print("{} training samples total.".format(len(targets)))
print("Only {:.3f} percent of training data set is a true positive.".format(percent_tp))
print("Therefore, the baseline accuracy is {:.3f}".format(np.max([percent_tp, 100-percent_tp])))
# Out:
# 60487 training samples total.
# Only 9.058 percent of training data set is a true positive.
# Therefore, the baseline accuracy is 90.942

# %%
# update so that the number of positives balances negatives
train_df_pos = train_df_allsamples.iloc[targets>0, :]
train_df_neg = train_df_allsamples.iloc[targets==0, :]
train_df_negsample = train_df_neg.sample(n=int(train_df_pos.shape[0]))

# concatenate negative and positive samples, then shuffle using .sample() 
#train_val_df = pd.concat((train_df_pos, train_df_negsample)).sample(frac=1)
train_val_df = train_df_allsamples.sample(frac=1)

train_val_split = .9
n_train_val = train_val_df.shape[0]
n_train = int(train_val_split*n_train_val)

train_df = train_val_df[:n_train]
val_df = train_val_df[n_train:]

# create dictionary that maps image name to target 
image_names = val_df["image_id"].values 
val_targets = val_df["target"].values

percent_tp = sum(val_targets)/len(val_targets) * 100 
baseline = np.max([percent_tp, 100-percent_tp])

print("{} Training and {} Validation samples".format(n_train, n_train_val-n_train))
print("{:.3f} percent of validation data set is a positive.".format(percent_tp))
print("Baseline validation accuracy is {:.3f}".format(baseline))
# Out:
# 54438 Training and 6049 Validation samples
# 8.944 percent of validation data set is a positive.
# Baseline validation accuracy is 91.056

# %%
# Device configuration (GPU can be enabled in settings)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
#device = 'cpu'
print(device)
# Out:
# cuda:0

# %%
meta_features = ['sex', 'age_approx', 'anatom_site_general_challenge'] 

encoder = {}
for feature in meta_features: 
    # determine unique features  
    categories = np.unique(np.array(train_df[feature].values, str))
    for i, category in enumerate(categories): 
        if category != 'nan':
            encoder[category] = np.float(i)
encoder['nan'] = np.nan

'''
Training done in rounds, need different transforms in each round. 

round 1: Slight addition of noise 
round 2: More noise 
round 3: More noise

'''

# define a unique transform each time a positive is resampled: 

# ROUND 1 transforms 

# basic transform with noise 
transform_1_round1 = transforms.Compose([
    transforms.RandomRotation(degrees=5),
    transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0), ratio=(0.9, 1.1)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])])

# horizontal or vertical flip 
transform_2_round1 = transforms.Compose([
    transforms.RandomRotation(degrees=5),
    transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0), ratio=(0.9, 1.1)),
    transforms.RandomHorizontalFlip(1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])])

# ROUND 2 transforms 

# basic transform 
transform_1_round2 = transforms.Compose([
    transforms.RandomRotation(degrees=10),
    transforms.ColorJitter(brightness=32. / 255.,saturation=0.5),
    transforms.RandomResizedCrop(size=256, scale=(0.5, 1.0), ratio=(0.7, 1.3)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])])

# horizontal or vertical flip 
transform_2_round2 = transforms.Compose([
    transforms.RandomRotation(degrees=10),
    transforms.ColorJitter(brightness=32. / 255.,saturation=0.5),
    transforms.RandomResizedCrop(size=256, scale=(0.5, 1.0), ratio=(0.7, 1.3)),
    transforms.RandomVerticalFlip(1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])])


# no flip or rotation for test/validation data 
transform_valid = transforms.Compose([
    transforms.RandomResizedCrop(size=256, scale=(1.0, 1.0), ratio=(1.0, 1.0)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])
])

def make_weights_for_balanced_classes(df, nclasses=2):   
    targets = df["target"].values
    count = [0] * nclasses                                                      
    for label in targets:                                                         
        count[label] += 1                                                     
    weight_per_class = [0.] * nclasses                                      
    N = float(sum(count))                                                   
    for i in range(nclasses):                                                   
        weight_per_class[i] = N/float(count[i])                                 
    weight = [0] * len(targets)                                              
    for idx, label in enumerate(targets):                                          
        weight[idx] = weight_per_class[label]   
        
    return np.array(weight)  

class ValidDataset(torch.utils.data.Dataset):
    def __init__(self, df, path_to_files):
        # 1. Initialize file paths or a list of file names.
        self.path = path_to_files
        self.df = df

    def __getitem__(self, index):
        # 1. Read one data from file (e.g. using numpy.fromfile, PIL.Image.open).
        
        # load X 
        img_name = self.df['image_id'].values[index]
        img_path = self.path + img_name + ".jpg"
        img = plt.imread(img_path)
        
        # determine meta data 
        meta = self.df[meta_features].values[index]
        meta_data = np.array([encoder[str(m)] for m in meta])
        
        # load y 
        label = self.df["target"].values[index]
        target = torch.tensor(label, dtype=torch.float32)
        
        # 2. Preprocess the data (e.g. torchvision.Transform).
        img = Image.fromarray(img)
        #img = img.resize((256, 256))
        img_processed = transform_valid(img)
        # 3. Return a data pair (e.g. image and label).
        return img_processed, target
        
    def __len__(self):
        # total size of your dataset.
        return self.df.shape[0]

# round 1 data loader 
class MyDataLoader_1():
    def __init__(self, df, path, batchsize, min_balance=None):
        # store df, path, weights, ...
        self.df = df 
        self.path = path
        self.w = make_weights_for_balanced_classes(df)
        self.batchsize = batchsize 
        self.balanced = True
        self.min_balance = min_balance
        
        # create a dictionary to map image_ids to index and target in dataframe 
        image_ids = self.df['image_id'].values 
        self.targets = self.df['target'].values
        inds = np.arange(len(image_ids))
        self.imgID2Idx = {im_id:ind for (im_id, ind) in zip(image_ids, inds)}
        self.imgID2Target = {im_id:target for (im_id, target) in zip(image_ids, self.targets)}
        
        # keep track of how many times samples have been drawn 
        self.counts = np.zeros(len(image_ids))
        
    def get_batch(self):
        # get image ids for the batch 
        if np.sum(self.w > 0) >= self.batchsize:
            batch_image_ids = self.df.sample(n=self.batchsize, weights=self.w)['image_id'].values
        else:
            # update batchsize 
            print("Updating batchsize, maximum dataset size reached")
            self.batchsize = np.sum(self.w > 0)
            batch_image_ids = self.df.sample(n=self.batchsize, weights=self.w)['image_id'].values
        
        # get the index locations for the image ids 
        batch_sample_inds = [self.imgID2Idx[im_id] for im_id in batch_image_ids]
        batch_targets = [self.imgID2Target[im_id] for im_id in batch_image_ids]
        
        # Update counts 
        self.counts[batch_sample_inds] += 1
        
        # Update sampling weights so that target=0 --> w = 0, target=1 --> w /= 2 
        for ind, target in zip(batch_sample_inds, batch_targets):
            # if the sample is a negative, then we don't want to sample it again 
            # if the sample has already been sampled 2 times, it shouldn't be sampled again
            # if target is positive, sampling should happen less frequently 
            if target == 0 or self.counts[ind] == 2:
                self.w[ind] = 0 
            else:
                self.w[ind] /= 2 
        
        # Data returned in shape [Batchsize, Channels, H, W]
        images = np.zeros((self.batchsize, 3, 256, 256)) 
        labels = np.zeros(self.batchsize)
        #meta_data = np.zeros((self.batchsize, 3))
        
        for i, index in enumerate(batch_sample_inds):
            
            # 1. load image
            img_name = self.df['image_id'].values[index]
            img_path = self.path + img_name + ".jpg"
            img = plt.imread(img_path)

            # 2. Preprocess the data (e.g. torchvision.Transform).
            img = Image.fromarray(img)
            if self.counts[index] == 1:
                images[i, :, :, :] = transform_1_round1(img)
            if self.counts[index] == 2:
                images[i, :, :, :] = transform_2_round1(img)
            
            # 3. store label 
            labels[i] = self.imgID2Target[img_name]
                
            # 4. get meta_data 
            #meta = self.df[meta_features].values[index]
            #meta_data[i, :] = np.array([encoder[str(m)] for m in meta])
                
        # Quit once all positive samples have zero valued weights 
        if np.sum(self.w[self.targets==1]) == 0:
            self.balanced = False
            
        # If a min balance is specified, quit at min balance
        if self.min_balance:
            if sum(labels)/len(labels) <= self.min_balance:
                self.balanced = False
        
        # return data 
        X = torch.tensor(images, dtype = torch.float32)
        y = torch.tensor(labels, dtype = torch.float32)
        return X, y #, meta_data
    
# round 1 data loader 
class MyDataLoader_1():
    def __init__(self, df, path, batchsize, min_balance=None):
        # store df, path, weights, ...
        self.df = df 
        self.path = path
        self.w = make_weights_for_balanced_classes(df)
        self.batchsize = batchsize 
        self.balanced = True
        self.min_balance = min_balance
        
        # create a dictionary to map image_ids to index and target in dataframe 
        image_ids = self.df['image_id'].values 
        self.targets = self.df['target'].values
        inds = np.arange(len(image_ids))
        self.imgID2Idx = {im_id:ind for (im_id, ind) in zip(image_ids, inds)}
        self.imgID2Target = {im_id:target for (im_id, target) in zip(image_ids, self.targets)}
        
        # keep track of how many times samples have been drawn 
        self.counts = np.zeros(len(image_ids))
        
    def get_batch(self):
        # get image ids for the batch 
        if np.sum(self.w > 0) >= self.batchsize:
            batch_image_ids = self.df.sample(n=self.batchsize, weights=self.w)['image_id'].values
        else:
            # update batchsize 
            print("Updating batchsize, maximum dataset size reached")
            self.batchsize = np.sum(self.w > 0)
            batch_image_ids = self.df.sample(n=self.batchsize, weights=self.w)['image_id'].values
        
        # get the index locations for the image ids 
        batch_sample_inds = [self.imgID2Idx[im_id] for im_id in batch_image_ids]
        batch_targets = [self.imgID2Target[im_id] for im_id in batch_image_ids]
        
        # Update counts 
        self.counts[batch_sample_inds] += 1
        
        # Update sampling weights so that target=0 --> w = 0, target=1 --> w /= 2 
        for ind, target in zip(batch_sample_inds, batch_targets):
            # if the sample is a negative, then we don't want to sample it again 
            # if the sample has already been sampled 2 times, it shouldn't be sampled again
            # if target is positive, sampling should happen less frequently 
            if target == 0 or self.counts[ind] == 2:
                self.w[ind] = 0 
            else:
                self.w[ind] /= 2 
        
        # Data returned in shape [Batchsize, Channels, H, W]
        images = np.zeros((self.batchsize, 3, 256, 256)) 
        labels = np.zeros(self.batchsize)
        #meta_data = np.zeros((self.batchsize, 3))
        
        for i, index in enumerate(batch_sample_inds):
            
            # 1. load image
            img_name = self.df['image_id'].values[index]
            img_path = self.path + img_name + ".jpg"
            img = plt.imread(img_path)

            # 2. Preprocess the data (e.g. torchvision.Transform).
            img = Image.fromarray(img)
            if self.counts[index] == 1:
                images[i, :, :, :] = transform_1_round2(img)
            if self.counts[index] == 2:
                images[i, :, :, :] = transform_2_round2(img)
            
            # 3. store label 
            labels[i] = self.imgID2Target[img_name]
                
            # 4. get meta_data 
            #meta = self.df[meta_features].values[index]
            #meta_data[i, :] = np.array([encoder[str(m)] for m in meta])
                
        # Quit once all positive samples have zero valued weights 
        if np.sum(self.w[self.targets==1]) == 0:
            self.balanced = False
            
        # If a min balance is specified, quit at min balance
        if self.min_balance:
            if sum(labels)/len(labels) <= self.min_balance:
                self.balanced = False
        
        # return data 
        X = torch.tensor(images, dtype = torch.float32)
        y = torch.tensor(labels, dtype = torch.float32)
        return X, y #, meta_data

# %%
# First, load the EfficientNet with pre-trained parameters 
ENet = EfficientNet.from_pretrained('efficientnet-b0').to(device)
# Out:
# Loaded pretrained weights for efficientnet-b0

# %%
# Convolutional neural network
class MyENet(nn.Module):
    def __init__(self, Net):
        super(MyENet, self).__init__()
        self.Net = Net
        self.output = nn.Sequential(
            nn.Linear(1000, 1),
            nn.Sigmoid())
        
    def embedding(self, x):
        out = self.Net(x)
        return out 
        
    def forward(self, x):
        out = self.Net(x)
        out = self.output(out)
        return out

model = MyENet(ENet).to(device)

# %%
# Train the model
# Use the prebuilt data loader.
path = "../../data-512/512x512-dataset-melanoma/512x512-dataset-melanoma/"

# evaluate performance on validation data 
valid_dataset = ValidDataset(val_df, path)                                              
valid_loader = torch.utils.data.DataLoader(dataset=valid_dataset) 


# save losses from training 
num_epochs = 50
batchsize  = 25

train_roc = []
val_roc   = []
losses    = []
patience     = 3
set_patience = 3 
best_val     = 0

# Loss and optimizer
criterion = nn.BCELoss()
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# scheduler reduces learning rate by factor of 10 when val auc does not improve
scheduler = ReduceLROnPlateau(optimizer=optimizer, min_lr=3e-6, mode='max', patience=0, verbose=True)


'''        
train_dataset = ValidDataset(train_df, path)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batchsize, shuffle=True)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
'''
for epoch in range(num_epochs):
    train_loader = MyDataLoader(train_df, path, batchsize=batchsize, min_balance=.25)
    while train_loader.balanced:
        images, labels = train_loader.get_batch()

        # set up model for training 
        model = model.train()
        
        images = images.to(device)
        labels = torch.reshape(labels, [len(labels), 1])
        labels = labels.to(device)
        
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # store loss
        losses.append(loss)
        
        # Calculate ROC
        predictions = outputs.detach().cpu().numpy().ravel()
        targets = labels.cpu().numpy().ravel()

        fpr, tpr, _ = roc_curve(np.array(targets, np.int), np.array(predictions).ravel())
        train_roc_auc = auc(fpr, tpr)
        train_roc.append(train_roc_auc)
        
        # Calculate balance 
        balance = np.sum(targets) / len(targets)
        
        print ('Epoch [{}/{}], Balance {:.2f}, Loss: {:.4f}, Train ROC AUC: {:.4f}' 
               .format(epoch+1, num_epochs, balance, loss.item(), train_roc_auc))
        
    # prep model for evaluation
    valid_predictions = []
    valid_targets = []
    model.eval() 
    with torch.no_grad():
        for j, (images, labels) in enumerate(valid_loader):
            images = images.to(device)

            labels = torch.reshape(labels, [len(labels), 1])
            labels = labels.to(device)

            # Forward pass
            outputs = model(images)

            # Calculate val ROC
            valid_predictions += list(outputs.detach().cpu().numpy().ravel())
            valid_targets += list(labels.cpu().numpy().ravel()) 

    fpr, tpr, _ = roc_curve(np.array(valid_targets, np.int), np.array(valid_predictions).ravel())
    val_roc_auc = auc(fpr, tpr)
    val_roc.append(val_roc_auc)
    
    print ('\nEpoch [{}/{}], Val ROC AUC: {:.4f}\n'.format(epoch+1, num_epochs, val_roc_auc))
    
    # learning rate is reduced if val roc doesn't improve 
    scheduler.step(val_roc_auc)
    
    if val_roc_auc >= best_val:
        best_val = val_roc_auc
        patience = set_patience        
        torch.save(model.state_dict(), '../Models/ENETmodel_all.ckpt')  
    else:
        patience -= 1
        if patience == 0:
            print('Early stopping. Best validation roc_auc: {:.3f}'.format(best_val))
            model.load_state_dict(torch.load('../Models/ENETmodel_all.ckpt'), strict=False)
            break

# Load best model 
model.load_state_dict(torch.load('../Models/ENETmodel_all.ckpt'))
# Out:
# Epoch [1/50], Balance 0.48, Loss: 0.7772, Train ROC AUC: 0.4359
# Epoch [1/50], Balance 0.40, Loss: 0.6824, Train ROC AUC: 0.8000
# Epoch [1/50], Balance 0.40, Loss: 0.6813, Train ROC AUC: 0.7200
# Epoch [1/50], Balance 0.60, Loss: 0.7589, Train ROC AUC: 0.7200
# Epoch [1/50], Balance 0.60, Loss: 0.8209, Train ROC AUC: 0.6333
# Epoch [1/50], Balance 0.64, Loss: 0.4933, Train ROC AUC: 0.8611
# Epoch [1/50], Balance 0.60, Loss: 0.6167, Train ROC AUC: 0.8000
# Epoch [1/50], Balance 0.36, Loss: 0.8403, Train ROC AUC: 0.8056
# Epoch [1/50], Balance 0.40, Loss: 0.6398, Train ROC AUC: 0.8933
# Epoch [1/50], Balance 0.48, Loss: 0.8103, Train ROC AUC: 0.7115
# Epoch [1/50], Balance 0.40, Loss: 0.6336, Train ROC AUC: 0.9267
# Epoch [1/50], Balance 0.48, Loss: 0.4635, Train ROC AUC: 0.8397
# Epoch [1/50], Balance 0.56, Loss: 0.9590, Train ROC AUC: 0.6753
# Epoch [1/50], Balance 0.56, Loss: 1.3375, Train ROC AUC: 0.5065
# Epoch [1/50], Balance 0.60, Loss: 0.7725, Train ROC AUC: 0.7333
# Epoch [1/50], Balance 0.36, Loss: 0.8959, Train ROC AUC: 0.7083
# Epoch [1/50], Balance 0.48, Loss: 0.5751, Train ROC AUC: 0.7821
# Epoch [1/50], Balance 0.60, Loss: 0.6210, Train ROC AUC: 0.7800
# Epoch [1/50], Balance 0.60, Loss: 0.7067, Train ROC AUC: 0.6667
# Epoch [1/50], Balance 0.32, Loss: 0.7241, Train ROC AUC: 0.6250
# Epoch [1/50], Balance 0.44, Loss: 0.5815, Train ROC AUC: 0.7792
# Epoch [1/50], Balance 0.44, Loss: 0.5411, Train ROC AUC: 0.8117
# Epoch [1/50], Balance 0.52, Loss: 0.7070, Train ROC AUC: 0.7115
# Epoch [1/50], Balance 0.44, Loss: 0.4803, Train ROC AUC: 0.8896
# Epoch [1/50], Balance 0.44, Loss: 0.2768, Train ROC AUC: 0.9610
# Epoch [1/50], Balance 0.52, Loss: 0.4722, Train ROC AUC: 0.8718
# Epoch [1/50], Balance 0.64, Loss: 0.5800, Train ROC AUC: 0.8125
# Epoch [1/50], Balance 0.52, Loss: 0.4393, Train ROC AUC: 0.8526
# Epoch [1/50], Balance 0.56, Loss: 0.7478, Train ROC AUC: 0.7013
# Epoch [1/50], Balance 0.52, Loss: 0.2685, Train ROC AUC: 0.9808
# Epoch [1/50], Balance 0.40, Loss: 0.5683, Train ROC AUC: 0.8067
# Epoch [1/50], Balance 0.32, Loss: 0.5174, Train ROC AUC: 0.8750
# Epoch [1/50], Balance 0.68, Loss: 0.4703, Train ROC AUC: 0.8824
# Epoch [1/50], Balance 0.48, Loss: 0.4020, Train ROC AUC: 0.8846
# Epoch [1/50], Balance 0.44, Loss: 0.3343, Train ROC AUC: 0.9740
# Epoch [1/50], Balance 0.48, Loss: 0.8366, Train ROC AUC: 0.7115
# Epoch [1/50], Balance 0.56, Loss: 0.3721, Train ROC AUC: 0.9481
# Epoch [1/50], Balance 0.56, Loss: 0.4286, Train ROC AUC: 0.9286
# Epoch [1/50], Balance 0.60, Loss: 0.8582, Train ROC AUC: 0.6133
# Epoch [1/50], Balance 0.60, Loss: 0.6928, Train ROC AUC: 0.7133
# Epoch [1/50], Balance 0.40, Loss: 0.4726, Train ROC AUC: 0.8267
# Epoch [1/50], Balance 0.36, Loss: 0.4866, Train ROC AUC: 0.8056
# Epoch [1/50], Balance 0.52, Loss: 0.7288, Train ROC AUC: 0.6667
# Epoch [1/50], Balance 0.56, Loss: 0.4134, Train ROC AUC: 0.9091
# Epoch [1/50], Balance 0.44, Loss: 0.4660, Train ROC AUC: 0.8312
# Epoch [1/50], Balance 0.40, Loss: 0.6198, Train ROC AUC: 0.7600
# Epoch [1/50], Balance 0.56, Loss: 0.5456, Train ROC AUC: 0.7987
# Epoch [1/50], Balance 0.56, Loss: 0.5149, Train ROC AUC: 0.8636
# Epoch [1/50], Balance 0.72, Loss: 0.5849, Train ROC AUC: 0.7619
# Epoch [1/50], Balance 0.40, Loss: 0.4648, Train ROC AUC: 0.8467
# Epoch [1/50], Balance 0.56, Loss: 0.2568, Train ROC AUC: 1.0000
# Epoch [1/50], Balance 0.44, Loss: 0.4918, Train ROC AUC: 0.9026
# Epoch [1/50], Balance 0.40, Loss: 0.4465, Train ROC AUC: 0.9200
# Epoch [1/50], Balance 0.28, Loss: 0.6436, Train ROC AUC: 0.8889
# Epoch [1/50], Balance 0.60, Loss: 0.5122, Train ROC AUC: 0.8400
# Epoch [1/50], Balance 0.48, Loss: 0.2493, Train ROC AUC: 0.9615
# Epoch [1/50], Balance 0.36, Loss: 0.5831, Train ROC AUC: 0.8056
# Epoch [1/50], Balance 0.60, Loss: 0.9039, Train ROC AUC: 0.8333
# Epoch [1/50], Balance 0.44, Loss: 0.3800, Train ROC AUC: 0.9026
# Epoch [1/50], Balance 0.52, Loss: 0.5439, Train ROC AUC: 0.8590
# Epoch [1/50], Balance 0.48, Loss: 0.3822, Train ROC AUC: 0.9167
# Epoch [1/50], Balance 0.44, Loss: 0.5639, Train ROC AUC: 0.8312
# Epoch [1/50], Balance 0.44, Loss: 0.4464, Train ROC AUC: 0.8571
# Epoch [1/50], Balance 0.44, Loss: 0.6838, Train ROC AUC: 0.8117
# Epoch [1/50], Balance 0.48, Loss: 0.7013, Train ROC AUC: 0.6859
# Epoch [1/50], Balance 0.56, Loss: 0.4029, Train ROC AUC: 0.8831
# Epoch [1/50], Balance 0.56, Loss: 0.3751, Train ROC AUC: 0.9351
# Epoch [1/50], Balance 0.64, Loss: 0.7674, Train ROC AUC: 0.8056
# Epoch [1/50], Balance 0.52, Loss: 0.5137, Train ROC AUC: 0.8846
# Epoch [1/50], Balance 0.56, Loss: 0.4712, Train ROC AUC: 0.8701
# Epoch [1/50], Balance 0.40, Loss: 0.5479, Train ROC AUC: 0.8333
# Epoch [1/50], Balance 0.52, Loss: 0.8388, Train ROC AUC: 0.5962
# Epoch [1/50], Balance 0.52, Loss: 0.3707, Train ROC AUC: 0.9423
# Epoch [1/50], Balance 0.52, Loss: 0.5924, Train ROC AUC: 0.7051
# Epoch [1/50], Balance 0.32, Loss: 0.4953, Train ROC AUC: 0.8897
# Epoch [1/50], Balance 0.40, Loss: 0.4550, Train ROC AUC: 0.8867
# Epoch [1/50], Balance 0.56, Loss: 0.4964, Train ROC AUC: 0.9091
# Epoch [1/50], Balance 0.48, Loss: 0.5302, Train ROC AUC: 0.8013
# Epoch [1/50], Balance 0.52, Loss: 0.3850, Train ROC AUC: 0.9487
# Epoch [1/50], Balance 0.48, Loss: 0.4125, Train ROC AUC: 0.9295
# Epoch [1/50], Balance 0.32, Loss: 0.3591, Train ROC AUC: 0.9412
# Epoch [1/50], Balance 0.56, Loss: 0.7290, Train ROC AUC: 0.7403
# Epoch [1/50], Balance 0.44, Loss: 0.7073, Train ROC AUC: 0.7078
# Epoch [1/50], Balance 0.60, Loss: 0.6843, Train ROC AUC: 0.8400
# Epoch [1/50], Balance 0.36, Loss: 0.6894, Train ROC AUC: 0.8125
# Epoch [1/50], Balance 0.60, Loss: 0.6859, Train ROC AUC: 0.7667
# Epoch [1/50], Balance 0.56, Loss: 0.5677, Train ROC AUC: 0.8506
# Epoch [1/50], Balance 0.40, Loss: 0.5779, Train ROC AUC: 0.7533
# Epoch [1/50], Balance 0.44, Loss: 0.5186, Train ROC AUC: 0.8247
# Epoch [1/50], Balance 0.64, Loss: 0.4978, Train ROC AUC: 0.8472
# Epoch [1/50], Balance 0.44, Loss: 0.3963, Train ROC AUC: 0.9156
# Epoch [1/50], Balance 0.24, Loss: 0.5193, Train ROC AUC: 0.9211
#
# Epoch [1/50], Val ROC AUC: 0.8062
#
# Epoch [2/50], Balance 0.60, Loss: 0.6809, Train ROC AUC: 0.7267
# Epoch [2/50], Balance 0.52, Loss: 0.5669, Train ROC AUC: 0.7885
# Epoch [2/50], Balance 0.56, Loss: 0.6624, Train ROC AUC: 0.6688
# Epoch [2/50], Balance 0.68, Loss: 0.5389, Train ROC AUC: 0.8382
# Epoch [2/50], Balance 0.64, Loss: 0.4723, Train ROC AUC: 0.8750
# Epoch [2/50], Balance 0.64, Loss: 0.3926, Train ROC AUC: 0.9236
# Epoch [2/50], Balance 0.36, Loss: 0.4888, Train ROC AUC: 0.9028
# Epoch [2/50], Balance 0.56, Loss: 0.4020, Train ROC AUC: 0.9286
# Epoch [2/50], Balance 0.44, Loss: 0.5468, Train ROC AUC: 0.8052
# Epoch [2/50], Balance 0.40, Loss: 0.5348, Train ROC AUC: 0.8867
# Epoch [2/50], Balance 0.52, Loss: 0.5625, Train ROC AUC: 0.7692
# Epoch [2/50], Balance 0.28, Loss: 0.5000, Train ROC AUC: 0.9524
# Epoch [2/50], Balance 0.52, Loss: 0.5181, Train ROC AUC: 0.8205
# Epoch [2/50], Balance 0.36, Loss: 0.6079, Train ROC AUC: 0.8333
# Epoch [2/50], Balance 0.56, Loss: 0.4344, Train ROC AUC: 0.8831
# Epoch [2/50], Balance 0.60, Loss: 0.6872, Train ROC AUC: 0.7067
# Epoch [2/50], Balance 0.44, Loss: 0.4402, Train ROC AUC: 0.8766
# Epoch [2/50], Balance 0.52, Loss: 0.5358, Train ROC AUC: 0.7885
# Epoch [2/50], Balance 0.36, Loss: 0.4748, Train ROC AUC: 0.8333
# Epoch [2/50], Balance 0.48, Loss: 0.5237, Train ROC AUC: 0.8397
# Epoch [2/50], Balance 0.56, Loss: 0.4034, Train ROC AUC: 0.8701
# Epoch [2/50], Balance 0.52, Loss: 0.5962, Train ROC AUC: 0.7500
# Epoch [2/50], Balance 0.68, Loss: 0.4973, Train ROC AUC: 0.9044
# Epoch [2/50], Balance 0.56, Loss: 0.6083, Train ROC AUC: 0.7792
# Epoch [2/50], Balance 0.64, Loss: 0.3197, Train ROC AUC: 0.9792
# Epoch [2/50], Balance 0.44, Loss: 0.4034, Train ROC AUC: 0.8896
# Epoch [2/50], Balance 0.32, Loss: 0.7618, Train ROC AUC: 0.7647
# Epoch [2/50], Balance 0.40, Loss: 0.4570, Train ROC AUC: 0.8800
# Epoch [2/50], Balance 0.24, Loss: 0.8731, Train ROC AUC: 0.7982
#
# Epoch [2/50], Val ROC AUC: 0.8400
#
# Epoch [3/50], Balance 0.48, Loss: 0.3048, Train ROC AUC: 0.9487
# Epoch [3/50], Balance 0.80, Loss: 0.7441, Train ROC AUC: 0.6400
# Epoch [3/50], Balance 0.60, Loss: 0.3919, Train ROC AUC: 0.9333
# Epoch [3/50], Balance 0.52, Loss: 0.5372, Train ROC AUC: 0.8397
# Epoch [3/50], Balance 0.32, Loss: 0.6460, Train ROC AUC: 0.7059
# Epoch [3/50], Balance 0.48, Loss: 0.3600, Train ROC AUC: 0.9487
# Epoch [3/50], Balance 0.56, Loss: 0.3959, Train ROC AUC: 0.9026
# Epoch [3/50], Balance 0.56, Loss: 0.5399, Train ROC AUC: 0.8506
# Epoch [3/50], Balance 0.52, Loss: 0.5203, Train ROC AUC: 0.8013
# Epoch [3/50], Balance 0.60, Loss: 0.3066, Train ROC AUC: 1.0000
# Epoch [3/50], Balance 0.48, Loss: 0.4927, Train ROC AUC: 0.7692
# Epoch [3/50], Balance 0.44, Loss: 0.3990, Train ROC AUC: 0.8831
# Epoch [3/50], Balance 0.52, Loss: 0.3659, Train ROC AUC: 0.9167
# Epoch [3/50], Balance 0.20, Loss: 0.6083, Train ROC AUC: 0.8700
#
# Epoch [3/50], Val ROC AUC: 0.8629
#
# Epoch [4/50], Balance 0.40, Loss: 0.5315, Train ROC AUC: 0.7733
# Epoch [4/50], Balance 0.68, Loss: 0.6554, Train ROC AUC: 0.7132
# Epoch [4/50], Balance 0.52, Loss: 0.7111, Train ROC AUC: 0.7564
# Epoch [4/50], Balance 0.48, Loss: 0.4188, Train ROC AUC: 0.9167
# Epoch [4/50], Balance 0.40, Loss: 0.5143, Train ROC AUC: 0.8200
# Epoch [4/50], Balance 0.60, Loss: 0.4024, Train ROC AUC: 0.9267
# Epoch [4/50], Balance 0.52, Loss: 0.3391, Train ROC AUC: 0.9551
# Epoch [4/50], Balance 0.48, Loss: 0.5871, Train ROC AUC: 0.7372
# Epoch [4/50], Balance 0.36, Loss: 0.5787, Train ROC AUC: 0.8333
# Epoch [4/50], Balance 0.48, Loss: 0.5043, Train ROC AUC: 0.8397
# Epoch [4/50], Balance 0.40, Loss: 0.4258, Train ROC AUC: 0.9200
# Epoch [4/50], Balance 0.36, Loss: 0.4214, Train ROC AUC: 0.9028
# Epoch [4/50], Balance 0.56, Loss: 0.4795, Train ROC AUC: 0.8506
# Epoch [4/50], Balance 0.64, Loss: 0.4119, Train ROC AUC: 0.9514
# Epoch [4/50], Balance 0.56, Loss: 0.4435, Train ROC AUC: 0.8182
# Epoch [4/50], Balance 0.64, Loss: 0.4744, Train ROC AUC: 0.8958
# Epoch [4/50], Balance 0.56, Loss: 0.3971, Train ROC AUC: 0.9091
# Epoch [4/50], Balance 0.60, Loss: 0.3896, Train ROC AUC: 0.9067
# Epoch [4/50], Balance 0.60, Loss: 0.2849, Train ROC AUC: 0.9600
# Epoch [4/50], Balance 0.32, Loss: 0.8226, Train ROC AUC: 0.7868
# Epoch [4/50], Balance 0.40, Loss: 0.5426, Train ROC AUC: 0.8400
# Epoch [4/50], Balance 0.48, Loss: 0.3522, Train ROC AUC: 0.9167
# Epoch [4/50], Balance 0.44, Loss: 0.3324, Train ROC AUC: 0.9610
# Epoch [4/50], Balance 0.48, Loss: 0.3826, Train ROC AUC: 0.9103
# Epoch [4/50], Balance 0.36, Loss: 0.4936, Train ROC AUC: 0.8542
# Epoch [4/50], Balance 0.52, Loss: 0.9966, Train ROC AUC: 0.7628
# Epoch [4/50], Balance 0.52, Loss: 0.6264, Train ROC AUC: 0.7628
# Epoch [4/50], Balance 0.52, Loss: 0.4692, Train ROC AUC: 0.8590
# Epoch [4/50], Balance 0.68, Loss: 0.6741, Train ROC AUC: 0.7941
# Epoch [4/50], Balance 0.44, Loss: 0.5876, Train ROC AUC: 0.7013
# Epoch [4/50], Balance 0.52, Loss: 0.3875, Train ROC AUC: 0.9231
# Epoch [4/50], Balance 0.72, Loss: 0.6214, Train ROC AUC: 0.8571
# Epoch [4/50], Balance 0.56, Loss: 0.4402, Train ROC AUC: 0.9351
# Epoch [4/50], Balance 0.56, Loss: 0.4404, Train ROC AUC: 0.9026
# Epoch [4/50], Balance 0.52, Loss: 0.4523, Train ROC AUC: 0.8782
# Epoch [4/50], Balance 0.44, Loss: 0.5305, Train ROC AUC: 0.8117
# Epoch [4/50], Balance 0.36, Loss: 0.5676, Train ROC AUC: 0.7708
# Epoch [4/50], Balance 0.32, Loss: 0.4889, Train ROC AUC: 0.8750
# Epoch [4/50], Balance 0.52, Loss: 0.3312, Train ROC AUC: 0.9551
# Epoch [4/50], Balance 0.44, Loss: 0.5435, Train ROC AUC: 0.8312
# Epoch [4/50], Balance 0.40, Loss: 0.3072, Train ROC AUC: 1.0000
# Epoch [4/50], Balance 0.44, Loss: 0.3578, Train ROC AUC: 0.9221
# Epoch [4/50], Balance 0.36, Loss: 0.4418, Train ROC AUC: 0.9097
# Epoch [4/50], Balance 0.60, Loss: 0.5648, Train ROC AUC: 0.8200
# Epoch [4/50], Balance 0.60, Loss: 0.6619, Train ROC AUC: 0.8133
# Epoch [4/50], Balance 0.44, Loss: 0.6293, Train ROC AUC: 0.7987
# Epoch [4/50], Balance 0.48, Loss: 0.3243, Train ROC AUC: 0.9423
# Epoch [4/50], Balance 0.48, Loss: 0.3101, Train ROC AUC: 0.9487
# Epoch [4/50], Balance 0.52, Loss: 0.3744, Train ROC AUC: 0.9359
# Epoch [4/50], Balance 0.52, Loss: 0.3564, Train ROC AUC: 0.9423
# Epoch [4/50], Balance 0.32, Loss: 0.3437, Train ROC AUC: 0.9412
# Epoch [4/50], Balance 0.32, Loss: 0.3629, Train ROC AUC: 0.9338
# Epoch [4/50], Balance 0.36, Loss: 0.2943, Train ROC AUC: 0.9583
# Epoch [4/50], Balance 0.36, Loss: 0.4137, Train ROC AUC: 0.8681
# Epoch [4/50], Balance 0.52, Loss: 0.3685, Train ROC AUC: 0.9551
# Epoch [4/50], Balance 0.40, Loss: 0.5808, Train ROC AUC: 0.8533
# Epoch [4/50], Balance 0.60, Loss: 0.4137, Train ROC AUC: 0.9200
# Epoch [4/50], Balance 0.56, Loss: 0.4156, Train ROC AUC: 0.9091
# Epoch [4/50], Balance 0.36, Loss: 0.3912, Train ROC AUC: 0.8750
# Epoch [4/50], Balance 0.60, Loss: 0.3876, Train ROC AUC: 0.9133
# Epoch [4/50], Balance 0.68, Loss: 0.5179, Train ROC AUC: 0.9044
# Epoch [4/50], Balance 0.32, Loss: 0.4077, Train ROC AUC: 0.9412
# Epoch [4/50], Balance 0.28, Loss: 0.7306, Train ROC AUC: 0.8571
# Epoch [4/50], Balance 0.64, Loss: 0.3280, Train ROC AUC: 0.9583
# Epoch [4/50], Balance 0.28, Loss: 0.6515, Train ROC AUC: 0.8730
# Epoch [4/50], Balance 0.56, Loss: 0.5399, Train ROC AUC: 0.8766
# Epoch [4/50], Balance 0.60, Loss: 0.3972, Train ROC AUC: 0.9133
# Epoch [4/50], Balance 0.56, Loss: 0.4230, Train ROC AUC: 0.8636
# Epoch [4/50], Balance 0.40, Loss: 0.4687, Train ROC AUC: 0.8800
# Epoch [4/50], Balance 0.44, Loss: 0.5696, Train ROC AUC: 0.7792
# Epoch [4/50], Balance 0.44, Loss: 0.4555, Train ROC AUC: 0.9091
# Epoch [4/50], Balance 0.60, Loss: 0.6210, Train ROC AUC: 0.7467
# Epoch [4/50], Balance 0.60, Loss: 0.5043, Train ROC AUC: 0.8133
# Epoch [4/50], Balance 0.56, Loss: 0.5238, Train ROC AUC: 0.8182
# Epoch [4/50], Balance 0.52, Loss: 0.3552, Train ROC AUC: 0.9295
# Epoch [4/50], Balance 0.48, Loss: 0.4061, Train ROC AUC: 0.9359
# Epoch [4/50], Balance 0.52, Loss: 0.4575, Train ROC AUC: 0.8654
# Epoch [4/50], Balance 0.60, Loss: 0.4874, Train ROC AUC: 0.8400
# Epoch [4/50], Balance 0.40, Loss: 0.6657, Train ROC AUC: 0.7400
# Epoch [4/50], Balance 0.36, Loss: 0.3948, Train ROC AUC: 0.9514
# Epoch [4/50], Balance 0.48, Loss: 0.3601, Train ROC AUC: 0.9359
# Epoch [4/50], Balance 0.44, Loss: 0.5760, Train ROC AUC: 0.7922
# Epoch [4/50], Balance 0.40, Loss: 0.3237, Train ROC AUC: 0.9467
# Epoch [4/50], Balance 0.56, Loss: 0.4614, Train ROC AUC: 0.8766
# Epoch [4/50], Balance 0.40, Loss: 0.5277, Train ROC AUC: 0.8200
# Epoch [4/50], Balance 0.60, Loss: 0.7698, Train ROC AUC: 0.6933
# Epoch [4/50], Balance 0.36, Loss: 0.4445, Train ROC AUC: 0.8472
# Epoch [4/50], Balance 0.56, Loss: 0.5469, Train ROC AUC: 0.8312
# Epoch [4/50], Balance 0.40, Loss: 0.4187, Train ROC AUC: 0.8733
# Epoch [4/50], Balance 0.32, Loss: 0.4588, Train ROC AUC: 0.8750
# Epoch [4/50], Balance 0.48, Loss: 0.6562, Train ROC AUC: 0.6603
# Epoch [4/50], Balance 0.56, Loss: 0.3225, Train ROC AUC: 0.9805
# Epoch [4/50], Balance 0.40, Loss: 0.3947, Train ROC AUC: 0.9333
# Epoch [4/50], Balance 0.36, Loss: 0.6145, Train ROC AUC: 0.7500
# Epoch [4/50], Balance 0.60, Loss: 0.4836, Train ROC AUC: 0.9200
# Epoch [4/50], Balance 0.48, Loss: 0.4329, Train ROC AUC: 0.8910
# Epoch [4/50], Balance 0.40, Loss: 0.6214, Train ROC AUC: 0.7267
# Epoch [4/50], Balance 0.40, Loss: 0.4563, Train ROC AUC: 0.8400
# Epoch [4/50], Balance 0.64, Loss: 0.6646, Train ROC AUC: 0.7986
# Epoch [4/50], Balance 0.44, Loss: 0.4612, Train ROC AUC: 0.8636
# Epoch [4/50], Balance 0.44, Loss: 0.5262, Train ROC AUC: 0.8442
# Epoch [4/50], Balance 0.32, Loss: 0.5194, Train ROC AUC: 0.8603
# Epoch [4/50], Balance 0.52, Loss: 0.5335, Train ROC AUC: 0.7885
# Epoch [4/50], Balance 0.48, Loss: 0.3886, Train ROC AUC: 0.9038
# Epoch [4/50], Balance 0.40, Loss: 0.4302, Train ROC AUC: 0.9333
# Epoch [4/50], Balance 0.48, Loss: 0.4436, Train ROC AUC: 0.9103
# Epoch [4/50], Balance 0.28, Loss: 0.5109, Train ROC AUC: 0.8571
# Epoch [4/50], Balance 0.56, Loss: 0.3793, Train ROC AUC: 0.9156
# Epoch [4/50], Balance 0.40, Loss: 0.4296, Train ROC AUC: 0.8933
# Epoch [4/50], Balance 0.28, Loss: 0.4118, Train ROC AUC: 0.9206
# Epoch [4/50], Balance 0.48, Loss: 0.2853, Train ROC AUC: 0.9744
# Epoch [4/50], Balance 0.44, Loss: 0.3471, Train ROC AUC: 0.9545
# Epoch [4/50], Balance 0.60, Loss: 0.4718, Train ROC AUC: 0.8933
# Epoch [4/50], Balance 0.64, Loss: 0.3553, Train ROC AUC: 0.9375
# Epoch [4/50], Balance 0.56, Loss: 0.3552, Train ROC AUC: 0.9091
# Epoch [4/50], Balance 0.40, Loss: 0.5024, Train ROC AUC: 0.8333
# Epoch [4/50], Balance 0.40, Loss: 0.5717, Train ROC AUC: 0.8400
# Epoch [4/50], Balance 0.48, Loss: 0.7261, Train ROC AUC: 0.7500
# Epoch [4/50], Balance 0.44, Loss: 0.6245, Train ROC AUC: 0.8312
# Epoch [4/50], Balance 0.56, Loss: 0.4275, Train ROC AUC: 0.8506
# Epoch [4/50], Balance 0.36, Loss: 0.2344, Train ROC AUC: 1.0000
# Epoch [4/50], Balance 0.40, Loss: 0.3265, Train ROC AUC: 0.9933
# Epoch [4/50], Balance 0.48, Loss: 0.5249, Train ROC AUC: 0.8077
# Epoch [4/50], Balance 0.44, Loss: 0.4414, Train ROC AUC: 0.8506
# Epoch [4/50], Balance 0.48, Loss: 0.2790, Train ROC AUC: 0.9808
# Epoch [4/50], Balance 0.44, Loss: 0.3216, Train ROC AUC: 0.9610
# Epoch [4/50], Balance 0.48, Loss: 0.3470, Train ROC AUC: 0.9359
# Epoch [4/50], Balance 0.56, Loss: 0.4315, Train ROC AUC: 0.9221
# Epoch [4/50], Balance 0.44, Loss: 0.5827, Train ROC AUC: 0.8117
# Epoch [4/50], Balance 0.48, Loss: 0.4252, Train ROC AUC: 0.8846
# Epoch [4/50], Balance 0.36, Loss: 0.4053, Train ROC AUC: 0.9306
# Epoch [4/50], Balance 0.24, Loss: 0.6983, Train ROC AUC: 0.6316
#
# Epoch [4/50], Val ROC AUC: 0.8663
#
# Epoch [5/50], Balance 0.40, Loss: 0.3559, Train ROC AUC: 0.9067
# Epoch [5/50], Balance 0.64, Loss: 0.6804, Train ROC AUC: 0.8472
# Epoch [5/50], Balance 0.48, Loss: 0.4326, Train ROC AUC: 0.8462
# Epoch [5/50], Balance 0.40, Loss: 0.2778, Train ROC AUC: 0.9867
# Epoch [5/50], Balance 0.56, Loss: 0.5872, Train ROC AUC: 0.7922
# Epoch [5/50], Balance 0.44, Loss: 0.4475, Train ROC AUC: 0.8831
# Epoch [5/50], Balance 0.44, Loss: 0.5199, Train ROC AUC: 0.8247
# Epoch [5/50], Balance 0.64, Loss: 0.3971, Train ROC AUC: 0.9514
# Epoch [5/50], Balance 0.44, Loss: 0.5153, Train ROC AUC: 0.8182
# Epoch [5/50], Balance 0.48, Loss: 0.3723, Train ROC AUC: 0.8974
# Epoch [5/50], Balance 0.52, Loss: 0.5562, Train ROC AUC: 0.7692
# Epoch [5/50], Balance 0.44, Loss: 0.3892, Train ROC AUC: 0.9091
# Epoch [5/50], Balance 0.40, Loss: 0.5552, Train ROC AUC: 0.7867
# Epoch [5/50], Balance 0.48, Loss: 0.3271, Train ROC AUC: 0.9551
# Epoch [5/50], Balance 0.48, Loss: 0.4533, Train ROC AUC: 0.8590
# Epoch [5/50], Balance 0.44, Loss: 0.4746, Train ROC AUC: 0.8442
# Epoch [5/50], Balance 0.44, Loss: 0.4325, Train ROC AUC: 0.8571
# Epoch [5/50], Balance 0.36, Loss: 0.4577, Train ROC AUC: 0.8472
# Epoch [5/50], Balance 0.48, Loss: 0.7078, Train ROC AUC: 0.6538
# Epoch [5/50], Balance 0.72, Loss: 0.6758, Train ROC AUC: 0.8175
# Epoch [5/50], Balance 0.60, Loss: 0.7264, Train ROC AUC: 0.6600
# Epoch [5/50], Balance 0.64, Loss: 0.5791, Train ROC AUC: 0.7847
# Epoch [5/50], Balance 0.60, Loss: 0.5280, Train ROC AUC: 0.8200
# Epoch [5/50], Balance 0.36, Loss: 0.3874, Train ROC AUC: 0.9722
# Epoch [5/50], Balance 0.64, Loss: 0.4538, Train ROC AUC: 0.9028
# Epoch [5/50], Balance 0.52, Loss: 0.5280, Train ROC AUC: 0.7885
# Epoch [5/50], Balance 0.48, Loss: 0.4105, Train ROC AUC: 0.9359
# Epoch [5/50], Balance 0.52, Loss: 0.4725, Train ROC AUC: 0.8205
# Epoch [5/50], Balance 0.64, Loss: 0.4279, Train ROC AUC: 0.8819
# Epoch [5/50], Balance 0.52, Loss: 0.4255, Train ROC AUC: 0.8910
# Epoch [5/50], Balance 0.60, Loss: 0.4084, Train ROC AUC: 0.8667
# Epoch [5/50], Balance 0.44, Loss: 0.5976, Train ROC AUC: 0.8312
# Epoch [5/50], Balance 0.48, Loss: 0.6293, Train ROC AUC: 0.7500
# Epoch [5/50], Balance 0.32, Loss: 0.4500, Train ROC AUC: 0.9632
# Epoch [5/50], Balance 0.72, Loss: 0.3777, Train ROC AUC: 0.9286
# Epoch [5/50], Balance 0.44, Loss: 0.4139, Train ROC AUC: 0.9026
# Epoch [5/50], Balance 0.48, Loss: 0.3230, Train ROC AUC: 0.9295
# Epoch [5/50], Balance 0.60, Loss: 0.4947, Train ROC AUC: 0.8733
# Epoch [5/50], Balance 0.56, Loss: 0.6909, Train ROC AUC: 0.7987
# Epoch [5/50], Balance 0.44, Loss: 0.3496, Train ROC AUC: 0.9286
# Epoch [5/50], Balance 0.36, Loss: 0.3840, Train ROC AUC: 0.9236
# Epoch [5/50], Balance 0.48, Loss: 0.3660, Train ROC AUC: 0.9103
# Epoch [5/50], Balance 0.28, Loss: 0.6085, Train ROC AUC: 0.8016
# Epoch [5/50], Balance 0.60, Loss: 0.5216, Train ROC AUC: 0.8533
# Epoch [5/50], Balance 0.48, Loss: 0.2560, Train ROC AUC: 0.9936
# Epoch [5/50], Balance 0.44, Loss: 0.3275, Train ROC AUC: 0.9740
# Epoch [5/50], Balance 0.48, Loss: 0.4095, Train ROC AUC: 0.8910
# Epoch [5/50], Balance 0.24, Loss: 0.5110, Train ROC AUC: 0.8509
#
# Epoch [5/50], Val ROC AUC: 0.8541
#
# Epoch     5: reducing learning rate of group 0 to 1.0000e-04.
# Epoch [6/50], Balance 0.60, Loss: 0.5353, Train ROC AUC: 0.9000
# Epoch [6/50], Balance 0.56, Loss: 0.5107, Train ROC AUC: 0.8701
# Epoch [6/50], Balance 0.56, Loss: 0.7482, Train ROC AUC: 0.6429
# Epoch [6/50], Balance 0.48, Loss: 0.4137, Train ROC AUC: 0.8846
# Epoch [6/50], Balance 0.56, Loss: 0.4157, Train ROC AUC: 0.9091
# Epoch [6/50], Balance 0.40, Loss: 0.5694, Train ROC AUC: 0.7733
# Epoch [6/50], Balance 0.48, Loss: 0.4448, Train ROC AUC: 0.8974
# Epoch [6/50], Balance 0.44, Loss: 0.5943, Train ROC AUC: 0.7857
# Epoch [6/50], Balance 0.52, Loss: 0.4126, Train ROC AUC: 0.9038
# Epoch [6/50], Balance 0.48, Loss: 0.3789, Train ROC AUC: 0.9295
# Epoch [6/50], Balance 0.40, Loss: 0.3430, Train ROC AUC: 0.9600
# Epoch [6/50], Balance 0.56, Loss: 0.5608, Train ROC AUC: 0.8442
# Epoch [6/50], Balance 0.48, Loss: 0.5186, Train ROC AUC: 0.8397
# Epoch [6/50], Balance 0.56, Loss: 0.5266, Train ROC AUC: 0.8312
# Epoch [6/50], Balance 0.52, Loss: 0.4437, Train ROC AUC: 0.8910
# Epoch [6/50], Balance 0.64, Loss: 0.4734, Train ROC AUC: 0.9028
# Epoch [6/50], Balance 0.60, Loss: 0.4287, Train ROC AUC: 0.9200
# Epoch [6/50], Balance 0.44, Loss: 0.4366, Train ROC AUC: 0.8831
# Epoch [6/50], Balance 0.56, Loss: 0.3474, Train ROC AUC: 0.9610
# Epoch [6/50], Balance 0.56, Loss: 0.2835, Train ROC AUC: 0.9870
# Epoch [6/50], Balance 0.44, Loss: 0.4392, Train ROC AUC: 0.8831
# Epoch [6/50], Balance 0.48, Loss: 0.4716, Train ROC AUC: 0.8590
# Epoch [6/50], Balance 0.56, Loss: 0.3188, Train ROC AUC: 0.9870
# Epoch [6/50], Balance 0.48, Loss: 0.2931, Train ROC AUC: 0.9936
# Epoch [6/50], Balance 0.56, Loss: 0.2923, Train ROC AUC: 1.0000
# Epoch [6/50], Balance 0.52, Loss: 0.5794, Train ROC AUC: 0.8462
# Epoch [6/50], Balance 0.44, Loss: 0.3983, Train ROC AUC: 0.8896
# Epoch [6/50], Balance 0.40, Loss: 0.3029, Train ROC AUC: 0.9667
# Epoch [6/50], Balance 0.56, Loss: 0.3915, Train ROC AUC: 0.9286
# Epoch [6/50], Balance 0.64, Loss: 0.4606, Train ROC AUC: 0.9167
# Epoch [6/50], Balance 0.56, Loss: 0.3134, Train ROC AUC: 0.9740
# Epoch [6/50], Balance 0.56, Loss: 0.5456, Train ROC AUC: 0.7987
# Epoch [6/50], Balance 0.52, Loss: 0.3607, Train ROC AUC: 0.9231
# Epoch [6/50], Balance 0.40, Loss: 0.3007, Train ROC AUC: 0.9533
# Epoch [6/50], Balance 0.60, Loss: 0.4127, Train ROC AUC: 0.8933
# Epoch [6/50], Balance 0.40, Loss: 0.2919, Train ROC AUC: 0.9600
# Epoch [6/50], Balance 0.60, Loss: 0.3622, Train ROC AUC: 0.9200
# Epoch [6/50], Balance 0.44, Loss: 0.3529, Train ROC AUC: 0.9221
# Epoch [6/50], Balance 0.48, Loss: 0.3147, Train ROC AUC: 0.9359
# Epoch [6/50], Balance 0.68, Loss: 0.5135, Train ROC AUC: 0.8603
# Epoch [6/50], Balance 0.56, Loss: 0.5524, Train ROC AUC: 0.8117
# Epoch [6/50], Balance 0.48, Loss: 0.3548, Train ROC AUC: 0.9295
# Epoch [6/50], Balance 0.28, Loss: 0.5588, Train ROC AUC: 0.9127
# Epoch [6/50], Balance 0.40, Loss: 0.2302, Train ROC AUC: 0.9933
# Epoch [6/50], Balance 0.60, Loss: 0.5452, Train ROC AUC: 0.8800
# Epoch [6/50], Balance 0.36, Loss: 0.3738, Train ROC AUC: 0.9167
# Epoch [6/50], Balance 0.52, Loss: 0.3872, Train ROC AUC: 0.8910
# Epoch [6/50], Balance 0.64, Loss: 0.3559, Train ROC AUC: 0.9722
# Epoch [6/50], Balance 0.48, Loss: 0.2771, Train ROC AUC: 0.9679
# Epoch [6/50], Balance 0.36, Loss: 0.4182, Train ROC AUC: 0.9028
# Epoch [6/50], Balance 0.48, Loss: 0.3667, Train ROC AUC: 0.9038
# Epoch [6/50], Balance 0.40, Loss: 0.3554, Train ROC AUC: 0.9333
# Epoch [6/50], Balance 0.40, Loss: 0.3613, Train ROC AUC: 0.9267
# Epoch [6/50], Balance 0.40, Loss: 0.5393, Train ROC AUC: 0.8200
# Epoch [6/50], Balance 0.20, Loss: 0.4524, Train ROC AUC: 0.9900
#
# Epoch [6/50], Val ROC AUC: 0.8966
#
# Epoch [7/50], Balance 0.32, Loss: 0.5073, Train ROC AUC: 0.8676
# Epoch [7/50], Balance 0.40, Loss: 0.5181, Train ROC AUC: 0.8467
# Epoch [7/50], Balance 0.76, Loss: 0.5327, Train ROC AUC: 0.9386
# Epoch [7/50], Balance 0.56, Loss: 0.3127, Train ROC AUC: 0.9545
# Epoch [7/50], Balance 0.64, Loss: 0.5066, Train ROC AUC: 0.8750
# Epoch [7/50], Balance 0.60, Loss: 0.3813, Train ROC AUC: 0.9267
# Epoch [7/50], Balance 0.36, Loss: 0.3769, Train ROC AUC: 0.9375
# Epoch [7/50], Balance 0.52, Loss: 0.3608, Train ROC AUC: 0.9167
# Epoch [7/50], Balance 0.68, Loss: 0.6012, Train ROC AUC: 0.8162
# Epoch [7/50], Balance 0.64, Loss: 0.4706, Train ROC AUC: 0.8750
# Epoch [7/50], Balance 0.68, Loss: 0.3088, Train ROC AUC: 0.9853
# Epoch [7/50], Balance 0.52, Loss: 0.4717, Train ROC AUC: 0.8462
# Epoch [7/50], Balance 0.60, Loss: 0.2657, Train ROC AUC: 0.9867
# Epoch [7/50], Balance 0.44, Loss: 0.2451, Train ROC AUC: 0.9675
# Epoch [7/50], Balance 0.68, Loss: 0.5238, Train ROC AUC: 0.8162
# Epoch [7/50], Balance 0.56, Loss: 0.4187, Train ROC AUC: 0.9091
# Epoch [7/50], Balance 0.52, Loss: 0.3282, Train ROC AUC: 0.9487
# Epoch [7/50], Balance 0.44, Loss: 0.2986, Train ROC AUC: 0.9481
# Epoch [7/50], Balance 0.52, Loss: 0.3378, Train ROC AUC: 0.9295
# Epoch [7/50], Balance 0.56, Loss: 0.4119, Train ROC AUC: 0.9091
# Epoch [7/50], Balance 0.52, Loss: 0.3322, Train ROC AUC: 0.9359
# Epoch [7/50], Balance 0.60, Loss: 0.4236, Train ROC AUC: 0.8333
# Epoch [7/50], Balance 0.28, Loss: 0.4926, Train ROC AUC: 0.9365
# Epoch [7/50], Balance 0.56, Loss: 0.2684, Train ROC AUC: 0.9675
# Epoch [7/50], Balance 0.60, Loss: 0.2488, Train ROC AUC: 0.9800
# Epoch [7/50], Balance 0.40, Loss: 0.4447, Train ROC AUC: 0.8667
# Epoch [7/50], Balance 0.56, Loss: 0.3046, Train ROC AUC: 0.9545
# Epoch [7/50], Balance 0.64, Loss: 0.2981, Train ROC AUC: 0.9722
# Epoch [7/50], Balance 0.52, Loss: 0.3983, Train ROC AUC: 0.8654
# Epoch [7/50], Balance 0.48, Loss: 0.5040, Train ROC AUC: 0.8462
# Epoch [7/50], Balance 0.44, Loss: 0.5357, Train ROC AUC: 0.8442
# Epoch [7/50], Balance 0.48, Loss: 0.3200, Train ROC AUC: 0.9487
# Epoch [7/50], Balance 0.40, Loss: 0.5243, Train ROC AUC: 0.8400
# Epoch [7/50], Balance 0.48, Loss: 0.4274, Train ROC AUC: 0.8910
# Epoch [7/50], Balance 0.60, Loss: 0.2591, Train ROC AUC: 0.9800
# Epoch [7/50], Balance 0.52, Loss: 0.2929, Train ROC AUC: 0.9487
# Epoch [7/50], Balance 0.32, Loss: 0.4042, Train ROC AUC: 0.9926
# Epoch [7/50], Balance 0.32, Loss: 0.4479, Train ROC AUC: 0.9338
# Epoch [7/50], Balance 0.44, Loss: 0.2621, Train ROC AUC: 0.9740
# Epoch [7/50], Balance 0.44, Loss: 0.3431, Train ROC AUC: 0.9286
# Epoch [7/50], Balance 0.36, Loss: 0.3939, Train ROC AUC: 0.9236
# Epoch [7/50], Balance 0.52, Loss: 0.2926, Train ROC AUC: 0.9423
# Epoch [7/50], Balance 0.48, Loss: 0.3289, Train ROC AUC: 0.9295
# Epoch [7/50], Balance 0.56, Loss: 0.4002, Train ROC AUC: 0.8831
# Epoch [7/50], Balance 0.44, Loss: 0.4309, Train ROC AUC: 0.9221
# Epoch [7/50], Balance 0.24, Loss: 0.7167, Train ROC AUC: 0.8246
#
# Epoch [7/50], Val ROC AUC: 0.9022
#
# Epoch [8/50], Balance 0.68, Loss: 0.3269, Train ROC AUC: 0.9632
# Epoch [8/50], Balance 0.40, Loss: 0.5251, Train ROC AUC: 0.8133
# Epoch [8/50], Balance 0.52, Loss: 0.4954, Train ROC AUC: 0.8590
# Epoch [8/50], Balance 0.36, Loss: 0.4374, Train ROC AUC: 0.9028
# Epoch [8/50], Balance 0.52, Loss: 0.2809, Train ROC AUC: 0.9744
# Epoch [8/50], Balance 0.56, Loss: 0.4079, Train ROC AUC: 0.8961
# Epoch [8/50], Balance 0.64, Loss: 0.4479, Train ROC AUC: 0.9028
# Epoch [8/50], Balance 0.60, Loss: 0.3384, Train ROC AUC: 0.9333
# Epoch [8/50], Balance 0.56, Loss: 0.3916, Train ROC AUC: 0.9221
# Epoch [8/50], Balance 0.64, Loss: 0.4712, Train ROC AUC: 0.9097
# Epoch [8/50], Balance 0.64, Loss: 0.5755, Train ROC AUC: 0.7778
# Epoch [8/50], Balance 0.28, Loss: 0.5832, Train ROC AUC: 0.8254
# Epoch [8/50], Balance 0.24, Loss: 0.6200, Train ROC AUC: 0.8684
#
# Epoch [8/50], Val ROC AUC: 0.9039
#
# Epoch [9/50], Balance 0.44, Loss: 0.3579, Train ROC AUC: 0.9156
# Epoch [9/50], Balance 0.56, Loss: 0.3863, Train ROC AUC: 0.8831
# Epoch [9/50], Balance 0.52, Loss: 0.3454, Train ROC AUC: 0.9231
# Epoch [9/50], Balance 0.40, Loss: 0.2535, Train ROC AUC: 0.9800
# Epoch [9/50], Balance 0.40, Loss: 0.8393, Train ROC AUC: 0.7400
# Epoch [9/50], Balance 0.48, Loss: 0.4130, Train ROC AUC: 0.8846
# Epoch [9/50], Balance 0.36, Loss: 0.4184, Train ROC AUC: 0.9028
# Epoch [9/50], Balance 0.68, Loss: 0.4063, Train ROC AUC: 0.9191
# Epoch [9/50], Balance 0.36, Loss: 0.6847, Train ROC AUC: 0.7292
# Epoch [9/50], Balance 0.36, Loss: 0.4794, Train ROC AUC: 0.8889
# Epoch [9/50], Balance 0.32, Loss: 0.2879, Train ROC AUC: 0.9853
# Epoch [9/50], Balance 0.56, Loss: 0.4911, Train ROC AUC: 0.8312
# Epoch [9/50], Balance 0.60, Loss: 0.5130, Train ROC AUC: 0.8400
# Epoch [9/50], Balance 0.48, Loss: 0.4044, Train ROC AUC: 0.8654
# Epoch [9/50], Balance 0.44, Loss: 0.3079, Train ROC AUC: 0.9481
# Epoch [9/50], Balance 0.60, Loss: 0.4189, Train ROC AUC: 0.9267
# Epoch [9/50], Balance 0.32, Loss: 0.4488, Train ROC AUC: 0.8971
# Epoch [9/50], Balance 0.52, Loss: 0.6652, Train ROC AUC: 0.7436
# Epoch [9/50], Balance 0.44, Loss: 0.3065, Train ROC AUC: 0.9481
# Epoch [9/50], Balance 0.52, Loss: 0.3729, Train ROC AUC: 0.9103
# Epoch [9/50], Balance 0.68, Loss: 0.9588, Train ROC AUC: 0.5515
# Epoch [9/50], Balance 0.56, Loss: 0.4623, Train ROC AUC: 0.8312
# Epoch [9/50], Balance 0.52, Loss: 0.3092, Train ROC AUC: 0.9551
# Epoch [9/50], Balance 0.56, Loss: 0.5067, Train ROC AUC: 0.8117
# Epoch [9/50], Balance 0.40, Loss: 0.3848, Train ROC AUC: 0.9333
# Epoch [9/50], Balance 0.44, Loss: 0.4705, Train ROC AUC: 0.8052
# Epoch [9/50], Balance 0.60, Loss: 0.3713, Train ROC AUC: 0.9533
# Epoch [9/50], Balance 0.52, Loss: 0.3794, Train ROC AUC: 0.9167
# Epoch [9/50], Balance 0.68, Loss: 0.4897, Train ROC AUC: 0.8897
# Epoch [9/50], Balance 0.44, Loss: 0.4433, Train ROC AUC: 0.8636
# Epoch [9/50], Balance 0.56, Loss: 0.4726, Train ROC AUC: 0.8571
# Epoch [9/50], Balance 0.32, Loss: 0.4455, Train ROC AUC: 0.8529
# Epoch [9/50], Balance 0.32, Loss: 0.4776, Train ROC AUC: 0.8676
# Epoch [9/50], Balance 0.56, Loss: 0.5333, Train ROC AUC: 0.7792
# Epoch [9/50], Balance 0.40, Loss: 0.4173, Train ROC AUC: 0.9067
# Epoch [9/50], Balance 0.48, Loss: 0.3113, Train ROC AUC: 0.9615
# Epoch [9/50], Balance 0.44, Loss: 0.3715, Train ROC AUC: 0.9286
# Epoch [9/50], Balance 0.44, Loss: 0.3342, Train ROC AUC: 0.9481
# Epoch [9/50], Balance 0.56, Loss: 0.4701, Train ROC AUC: 0.8636
# Epoch [9/50], Balance 0.60, Loss: 0.3308, Train ROC AUC: 0.9400
# Epoch [9/50], Balance 0.44, Loss: 0.3041, Train ROC AUC: 0.9740
# Epoch [9/50], Balance 0.48, Loss: 0.3952, Train ROC AUC: 0.9103
# Epoch [9/50], Balance 0.40, Loss: 0.3024, Train ROC AUC: 0.9800
# Epoch [9/50], Balance 0.48, Loss: 0.2674, Train ROC AUC: 0.9872
# Epoch [9/50], Balance 0.52, Loss: 0.3572, Train ROC AUC: 0.9167
# Epoch [9/50], Balance 0.40, Loss: 0.7824, Train ROC AUC: 0.6933
# Epoch [9/50], Balance 0.36, Loss: 0.2604, Train ROC AUC: 0.9931
# Epoch [9/50], Balance 0.56, Loss: 0.4106, Train ROC AUC: 0.9221
# Epoch [9/50], Balance 0.44, Loss: 0.2442, Train ROC AUC: 0.9870
# Epoch [9/50], Balance 0.52, Loss: 0.3450, Train ROC AUC: 0.9167
# Epoch [9/50], Balance 0.28, Loss: 0.4961, Train ROC AUC: 0.8492
# Epoch [9/50], Balance 0.52, Loss: 0.4213, Train ROC AUC: 0.8910
# Epoch [9/50], Balance 0.40, Loss: 0.4251, Train ROC AUC: 0.8867
# Epoch [9/50], Balance 0.64, Loss: 0.4571, Train ROC AUC: 0.8958
# Epoch [9/50], Balance 0.40, Loss: 0.4009, Train ROC AUC: 0.8933
# Epoch [9/50], Balance 0.60, Loss: 0.3693, Train ROC AUC: 0.9067
# Epoch [9/50], Balance 0.40, Loss: 0.2396, Train ROC AUC: 0.9867
# Epoch [9/50], Balance 0.68, Loss: 0.6278, Train ROC AUC: 0.7868
# Epoch [9/50], Balance 0.52, Loss: 0.3787, Train ROC AUC: 0.9295
# Epoch [9/50], Balance 0.40, Loss: 0.3440, Train ROC AUC: 0.9067
# Epoch [9/50], Balance 0.44, Loss: 0.6248, Train ROC AUC: 0.7532
# Epoch [9/50], Balance 0.36, Loss: 0.3552, Train ROC AUC: 0.9236
# Epoch [9/50], Balance 0.48, Loss: 0.3072, Train ROC AUC: 0.9423
# Epoch [9/50], Balance 0.56, Loss: 0.3961, Train ROC AUC: 0.9221
# Epoch [9/50], Balance 0.40, Loss: 0.3196, Train ROC AUC: 0.9733
# Epoch [9/50], Balance 0.52, Loss: 0.2541, Train ROC AUC: 0.9808
# Epoch [9/50], Balance 0.56, Loss: 0.3841, Train ROC AUC: 0.9091
# Epoch [9/50], Balance 0.48, Loss: 0.4043, Train ROC AUC: 0.8654
# Epoch [9/50], Balance 0.64, Loss: 0.4300, Train ROC AUC: 0.9097
# Epoch [9/50], Balance 0.72, Loss: 0.8725, Train ROC AUC: 0.7222
# Epoch [9/50], Balance 0.48, Loss: 0.2565, Train ROC AUC: 0.9615
# Epoch [9/50], Balance 0.48, Loss: 0.7960, Train ROC AUC: 0.6987
# Epoch [9/50], Balance 0.48, Loss: 0.3806, Train ROC AUC: 0.9103
# Epoch [9/50], Balance 0.48, Loss: 0.4181, Train ROC AUC: 0.8846
# Epoch [9/50], Balance 0.48, Loss: 0.5296, Train ROC AUC: 0.7821
# Epoch [9/50], Balance 0.44, Loss: 0.3339, Train ROC AUC: 0.9351
# Epoch [9/50], Balance 0.72, Loss: 0.4900, Train ROC AUC: 0.9286
# Epoch [9/50], Balance 0.44, Loss: 0.4488, Train ROC AUC: 0.8636
# Epoch [9/50], Balance 0.48, Loss: 0.3966, Train ROC AUC: 0.8718
# Epoch [9/50], Balance 0.52, Loss: 0.4346, Train ROC AUC: 0.8590
# Epoch [9/50], Balance 0.48, Loss: 0.4122, Train ROC AUC: 0.8910
# Epoch [9/50], Balance 0.36, Loss: 0.3892, Train ROC AUC: 0.9236
# Epoch [9/50], Balance 0.56, Loss: 0.2689, Train ROC AUC: 0.9610
# Epoch [9/50], Balance 0.36, Loss: 0.2754, Train ROC AUC: 1.0000
# Epoch [9/50], Balance 0.40, Loss: 0.5150, Train ROC AUC: 0.8467
# Epoch [9/50], Balance 0.40, Loss: 0.3471, Train ROC AUC: 0.9467
# Epoch [9/50], Balance 0.44, Loss: 0.3628, Train ROC AUC: 0.9416
# Epoch [9/50], Balance 0.56, Loss: 0.4502, Train ROC AUC: 0.8571
# Epoch [9/50], Balance 0.64, Loss: 0.4576, Train ROC AUC: 0.9167
# Epoch [9/50], Balance 0.44, Loss: 0.2128, Train ROC AUC: 1.0000
# Epoch [9/50], Balance 0.44, Loss: 0.2710, Train ROC AUC: 0.9610
# Epoch [9/50], Balance 0.56, Loss: 0.3650, Train ROC AUC: 0.9221
# Epoch [9/50], Balance 0.48, Loss: 0.4313, Train ROC AUC: 0.8782
# Epoch [9/50], Balance 0.36, Loss: 0.4011, Train ROC AUC: 0.8819
# Epoch [9/50], Balance 0.40, Loss: 0.3262, Train ROC AUC: 0.9667
# Epoch [9/50], Balance 0.52, Loss: 0.3748, Train ROC AUC: 0.9295
# Epoch [9/50], Balance 0.48, Loss: 0.3415, Train ROC AUC: 0.9423
# Epoch [9/50], Balance 0.40, Loss: 0.4143, Train ROC AUC: 0.8733
# Epoch [9/50], Balance 0.32, Loss: 0.4396, Train ROC AUC: 0.9044
# Epoch [9/50], Balance 0.40, Loss: 0.3361, Train ROC AUC: 0.9467
# Epoch [9/50], Balance 0.56, Loss: 0.2729, Train ROC AUC: 0.9805
# Epoch [9/50], Balance 0.56, Loss: 0.4227, Train ROC AUC: 0.8766
# Epoch [9/50], Balance 0.44, Loss: 0.3644, Train ROC AUC: 0.9351
# Epoch [9/50], Balance 0.40, Loss: 0.4596, Train ROC AUC: 0.8467
# Epoch [9/50], Balance 0.52, Loss: 0.2887, Train ROC AUC: 0.9359
# Epoch [9/50], Balance 0.40, Loss: 0.3818, Train ROC AUC: 0.8867
# Epoch [9/50], Balance 0.48, Loss: 0.2557, Train ROC AUC: 0.9744
# Epoch [9/50], Balance 0.52, Loss: 0.5537, Train ROC AUC: 0.7949
# Epoch [9/50], Balance 0.40, Loss: 0.4738, Train ROC AUC: 0.8667
# Epoch [9/50], Balance 0.36, Loss: 0.3526, Train ROC AUC: 0.9375
# Epoch [9/50], Balance 0.52, Loss: 0.3099, Train ROC AUC: 0.9487
# Epoch [9/50], Balance 0.40, Loss: 0.2793, Train ROC AUC: 0.9533
# Epoch [9/50], Balance 0.44, Loss: 0.2683, Train ROC AUC: 0.9805
# Epoch [9/50], Balance 0.32, Loss: 0.4618, Train ROC AUC: 0.8750
# Epoch [9/50], Balance 0.64, Loss: 0.3861, Train ROC AUC: 0.9097
# Epoch [9/50], Balance 0.48, Loss: 0.3580, Train ROC AUC: 0.9359
# Epoch [9/50], Balance 0.44, Loss: 0.5947, Train ROC AUC: 0.8052
# Epoch [9/50], Balance 0.28, Loss: 0.7448, Train ROC AUC: 0.7063
# Epoch [9/50], Balance 0.36, Loss: 0.3987, Train ROC AUC: 0.9306
# Epoch [9/50], Balance 0.56, Loss: 0.4245, Train ROC AUC: 0.9156
# Epoch [9/50], Balance 0.56, Loss: 0.3114, Train ROC AUC: 0.9416
# Epoch [9/50], Balance 0.52, Loss: 0.3124, Train ROC AUC: 0.9487
# Epoch [9/50], Balance 0.52, Loss: 0.4144, Train ROC AUC: 0.9038
# Epoch [9/50], Balance 0.56, Loss: 0.3365, Train ROC AUC: 0.9610
# Epoch [9/50], Balance 0.56, Loss: 0.5043, Train ROC AUC: 0.8377
# Epoch [9/50], Balance 0.68, Loss: 0.3370, Train ROC AUC: 0.9559
# Epoch [9/50], Balance 0.48, Loss: 0.2410, Train ROC AUC: 0.9808
# Epoch [9/50], Balance 0.32, Loss: 0.4036, Train ROC AUC: 0.9044
# Epoch [9/50], Balance 0.40, Loss: 0.2752, Train ROC AUC: 0.9600
# Epoch [9/50], Balance 0.48, Loss: 0.4232, Train ROC AUC: 0.8718
# Epoch [9/50], Balance 0.40, Loss: 0.4086, Train ROC AUC: 0.8933
# Epoch [9/50], Balance 0.52, Loss: 0.2786, Train ROC AUC: 0.9551
# Epoch [9/50], Balance 0.64, Loss: 0.2818, Train ROC AUC: 0.9931
# Epoch [9/50], Balance 0.28, Loss: 0.3992, Train ROC AUC: 0.9127
# Epoch [9/50], Balance 0.44, Loss: 0.2788, Train ROC AUC: 0.9675
# Epoch [9/50], Balance 0.60, Loss: 0.3956, Train ROC AUC: 0.9133
# Epoch [9/50], Balance 0.48, Loss: 0.3361, Train ROC AUC: 0.9551
# Epoch [9/50], Balance 0.52, Loss: 0.5593, Train ROC AUC: 0.8333
# Epoch [9/50], Balance 0.44, Loss: 0.4017, Train ROC AUC: 0.9091
# Epoch [9/50], Balance 0.40, Loss: 0.7003, Train ROC AUC: 0.7467
# Epoch [9/50], Balance 0.40, Loss: 0.3655, Train ROC AUC: 0.9267
# Epoch [9/50], Balance 0.40, Loss: 0.3275, Train ROC AUC: 0.9333
# Epoch [9/50], Balance 0.48, Loss: 0.3662, Train ROC AUC: 0.9231
# Epoch [9/50], Balance 0.36, Loss: 0.4945, Train ROC AUC: 0.8889
# Epoch [9/50], Balance 0.64, Loss: 0.3291, Train ROC AUC: 0.9583
# Epoch [9/50], Balance 0.56, Loss: 0.2223, Train ROC AUC: 1.0000
# Epoch [9/50], Balance 0.52, Loss: 0.4485, Train ROC AUC: 0.8846
# Epoch [9/50], Balance 0.40, Loss: 0.3696, Train ROC AUC: 0.9267
# Epoch [9/50], Balance 0.52, Loss: 0.4554, Train ROC AUC: 0.8141
# Epoch [9/50], Balance 0.48, Loss: 0.3387, Train ROC AUC: 0.9167
# Epoch [9/50], Balance 0.76, Loss: 0.5516, Train ROC AUC: 0.9561
# Epoch [9/50], Balance 0.32, Loss: 0.5671, Train ROC AUC: 0.8015
# Epoch [9/50], Balance 0.64, Loss: 0.3231, Train ROC AUC: 0.9722
# Epoch [9/50], Balance 0.40, Loss: 0.3973, Train ROC AUC: 0.9067
# Epoch [9/50], Balance 0.36, Loss: 0.4627, Train ROC AUC: 0.9167
# Epoch [9/50], Balance 0.44, Loss: 0.3504, Train ROC AUC: 0.9481
# Epoch [9/50], Balance 0.60, Loss: 0.3737, Train ROC AUC: 0.9133
# Epoch [9/50], Balance 0.60, Loss: 0.2091, Train ROC AUC: 0.9867
# Epoch [9/50], Balance 0.64, Loss: 0.6119, Train ROC AUC: 0.8333
# Epoch [9/50], Balance 0.64, Loss: 0.4238, Train ROC AUC: 0.9167
# Epoch [9/50], Balance 0.32, Loss: 0.4217, Train ROC AUC: 0.9191
# Epoch [9/50], Balance 0.44, Loss: 0.2244, Train ROC AUC: 1.0000
# Epoch [9/50], Balance 0.52, Loss: 0.4057, Train ROC AUC: 0.9167
# Epoch [9/50], Balance 0.48, Loss: 0.3328, Train ROC AUC: 0.9295
# Epoch [9/50], Balance 0.68, Loss: 0.6179, Train ROC AUC: 0.8382
# Epoch [9/50], Balance 0.48, Loss: 0.3054, Train ROC AUC: 0.9359
# Epoch [9/50], Balance 0.56, Loss: 0.2493, Train ROC AUC: 0.9545
# Epoch [9/50], Balance 0.52, Loss: 0.4483, Train ROC AUC: 0.8333
# Epoch [9/50], Balance 0.44, Loss: 0.2649, Train ROC AUC: 0.9545
# Epoch [9/50], Balance 0.40, Loss: 0.4701, Train ROC AUC: 0.8533
# Epoch [9/50], Balance 0.68, Loss: 0.6920, Train ROC AUC: 0.7721
# Epoch [9/50], Balance 0.48, Loss: 0.2908, Train ROC AUC: 0.9679
# Epoch [9/50], Balance 0.40, Loss: 0.5472, Train ROC AUC: 0.7733
# Epoch [9/50], Balance 0.56, Loss: 0.5306, Train ROC AUC: 0.7792
# Epoch [9/50], Balance 0.44, Loss: 0.4191, Train ROC AUC: 0.8961
# Epoch [9/50], Balance 0.40, Loss: 0.5546, Train ROC AUC: 0.8267
# Epoch [9/50], Balance 0.56, Loss: 0.3876, Train ROC AUC: 0.8831
# Epoch [9/50], Balance 0.52, Loss: 0.3969, Train ROC AUC: 0.8910
# Epoch [9/50], Balance 0.64, Loss: 0.2737, Train ROC AUC: 0.9861
# Epoch [9/50], Balance 0.52, Loss: 0.3493, Train ROC AUC: 0.9103
# Epoch [9/50], Balance 0.48, Loss: 0.3280, Train ROC AUC: 0.9295
# Epoch [9/50], Balance 0.60, Loss: 0.5415, Train ROC AUC: 0.8467
# Epoch [9/50], Balance 0.44, Loss: 0.3965, Train ROC AUC: 0.8831
# Epoch [9/50], Balance 0.52, Loss: 0.5771, Train ROC AUC: 0.8269
# Epoch [9/50], Balance 0.44, Loss: 0.3528, Train ROC AUC: 0.9156
# Epoch [9/50], Balance 0.40, Loss: 0.4026, Train ROC AUC: 0.8867
# Epoch [9/50], Balance 0.52, Loss: 0.2839, Train ROC AUC: 0.9679
# Epoch [9/50], Balance 0.64, Loss: 0.2452, Train ROC AUC: 1.0000
# Epoch [9/50], Balance 0.44, Loss: 0.3664, Train ROC AUC: 0.9026
# Epoch [9/50], Balance 0.56, Loss: 0.6085, Train ROC AUC: 0.7792
# Epoch [9/50], Balance 0.32, Loss: 0.5913, Train ROC AUC: 0.8235
# Epoch [9/50], Balance 0.64, Loss: 0.5425, Train ROC AUC: 0.8056
# Epoch [9/50], Balance 0.48, Loss: 0.4358, Train ROC AUC: 0.8846
# Epoch [9/50], Balance 0.40, Loss: 0.4659, Train ROC AUC: 0.8667
# Epoch [9/50], Balance 0.40, Loss: 0.6893, Train ROC AUC: 0.7267
# Epoch [9/50], Balance 0.36, Loss: 0.2818, Train ROC AUC: 0.9861
# Epoch [9/50], Balance 0.52, Loss: 0.6450, Train ROC AUC: 0.7436
# Epoch [9/50], Balance 0.40, Loss: 0.4046, Train ROC AUC: 0.9200
# Epoch [9/50], Balance 0.36, Loss: 0.4282, Train ROC AUC: 0.9097
# Epoch [9/50], Balance 0.44, Loss: 0.2744, Train ROC AUC: 0.9675
# Epoch [9/50], Balance 0.20, Loss: 0.5152, Train ROC AUC: 0.9100
#
# Epoch [9/50], Val ROC AUC: 0.9082
#
# Epoch [10/50], Balance 0.60, Loss: 0.4224, Train ROC AUC: 0.8867
# Epoch [10/50], Balance 0.52, Loss: 0.3653, Train ROC AUC: 0.9423
# Epoch [10/50], Balance 0.40, Loss: 0.3458, Train ROC AUC: 0.9267
# Epoch [10/50], Balance 0.44, Loss: 0.4226, Train ROC AUC: 0.8636
# Epoch [10/50], Balance 0.52, Loss: 0.4138, Train ROC AUC: 0.8782
# Epoch [10/50], Balance 0.60, Loss: 0.4995, Train ROC AUC: 0.8267
# Epoch [10/50], Balance 0.68, Loss: 0.4046, Train ROC AUC: 0.9265
# Epoch [10/50], Balance 0.40, Loss: 0.3381, Train ROC AUC: 0.9400
# Epoch [10/50], Balance 0.48, Loss: 0.3707, Train ROC AUC: 0.9167
# Epoch [10/50], Balance 0.60, Loss: 0.3618, Train ROC AUC: 0.9133
# Epoch [10/50], Balance 0.36, Loss: 0.2737, Train ROC AUC: 0.9861
# Epoch [10/50], Balance 0.52, Loss: 0.4494, Train ROC AUC: 0.8846
# Epoch [10/50], Balance 0.36, Loss: 0.2743, Train ROC AUC: 1.0000
# Epoch [10/50], Balance 0.60, Loss: 0.3157, Train ROC AUC: 0.9733
# Epoch [10/50], Balance 0.24, Loss: 0.4969, Train ROC AUC: 0.8333
#
# Epoch [10/50], Val ROC AUC: 0.9133
#
# Epoch [11/50], Balance 0.44, Loss: 0.4337, Train ROC AUC: 0.8766
# Epoch [11/50], Balance 0.56, Loss: 0.4905, Train ROC AUC: 0.8701
# Epoch [11/50], Balance 0.32, Loss: 0.4934, Train ROC AUC: 0.8897
# Epoch [11/50], Balance 0.56, Loss: 0.3356, Train ROC AUC: 0.9416
# Epoch [11/50], Balance 0.44, Loss: 0.4542, Train ROC AUC: 0.8571
# Epoch [11/50], Balance 0.56, Loss: 0.4679, Train ROC AUC: 0.8831
# Epoch [11/50], Balance 0.56, Loss: 0.2707, Train ROC AUC: 0.9740
# Epoch [11/50], Balance 0.40, Loss: 0.3173, Train ROC AUC: 0.9667
# Epoch [11/50], Balance 0.40, Loss: 0.3294, Train ROC AUC: 0.9333
# Epoch [11/50], Balance 0.52, Loss: 0.3102, Train ROC AUC: 0.9615
# Epoch [11/50], Balance 0.52, Loss: 0.2549, Train ROC AUC: 0.9872
# Epoch [11/50], Balance 0.44, Loss: 0.3230, Train ROC AUC: 0.9481
# Epoch [11/50], Balance 0.44, Loss: 0.4997, Train ROC AUC: 0.8312
# Epoch [11/50], Balance 0.44, Loss: 0.3308, Train ROC AUC: 0.9286
# Epoch [11/50], Balance 0.52, Loss: 0.2835, Train ROC AUC: 0.9551
# Epoch [11/50], Balance 0.44, Loss: 0.3680, Train ROC AUC: 0.8831
# Epoch [11/50], Balance 0.56, Loss: 0.3750, Train ROC AUC: 0.9026
# Epoch [11/50], Balance 0.44, Loss: 0.3577, Train ROC AUC: 0.9221
# Epoch [11/50], Balance 0.52, Loss: 0.4049, Train ROC AUC: 0.8782
# Epoch [11/50], Balance 0.32, Loss: 0.3768, Train ROC AUC: 0.9412
# Epoch [11/50], Balance 0.56, Loss: 0.5350, Train ROC AUC: 0.8117
# Epoch [11/50], Balance 0.68, Loss: 0.3315, Train ROC AUC: 0.9265
# Epoch [11/50], Balance 0.40, Loss: 0.2359, Train ROC AUC: 0.9667
# Epoch [11/50], Balance 0.48, Loss: 0.6903, Train ROC AUC: 0.7885
# Epoch [11/50], Balance 0.40, Loss: 0.3010, Train ROC AUC: 0.9867
# Epoch [11/50], Balance 0.60, Loss: 0.4571, Train ROC AUC: 0.9400
# Epoch [11/50], Balance 0.48, Loss: 0.1849, Train ROC AUC: 1.0000
# Epoch [11/50], Balance 0.52, Loss: 0.3983, Train ROC AUC: 0.9103
# Epoch [11/50], Balance 0.44, Loss: 0.2981, Train ROC AUC: 0.9935
# Epoch [11/50], Balance 0.72, Loss: 0.3028, Train ROC AUC: 1.0000
# Epoch [11/50], Balance 0.52, Loss: 0.5947, Train ROC AUC: 0.7821
# Epoch [11/50], Balance 0.48, Loss: 0.2305, Train ROC AUC: 0.9936
# Epoch [11/50], Balance 0.44, Loss: 0.2421, Train ROC AUC: 0.9805
# Epoch [11/50], Balance 0.40, Loss: 0.4507, Train ROC AUC: 0.8400
# Epoch [11/50], Balance 0.44, Loss: 0.3528, Train ROC AUC: 0.9286
# Epoch [11/50], Balance 0.64, Loss: 0.3710, Train ROC AUC: 0.9444
# Epoch [11/50], Balance 0.40, Loss: 0.4207, Train ROC AUC: 0.9000
# Epoch [11/50], Balance 0.48, Loss: 0.3969, Train ROC AUC: 0.8910
# Epoch [11/50], Balance 0.32, Loss: 0.3002, Train ROC AUC: 0.9632
# Epoch [11/50], Balance 0.28, Loss: 0.6551, Train ROC AUC: 0.8016
# Epoch [11/50], Balance 0.40, Loss: 0.2748, Train ROC AUC: 0.9400
# Epoch [11/50], Balance 0.40, Loss: 0.3048, Train ROC AUC: 0.9533
# Epoch [11/50], Balance 0.60, Loss: 0.2173, Train ROC AUC: 0.9933
# Epoch [11/50], Balance 0.44, Loss: 0.2741, Train ROC AUC: 0.9545
# Epoch [11/50], Balance 0.44, Loss: 0.5214, Train ROC AUC: 0.8571
# Epoch [11/50], Balance 0.40, Loss: 0.4066, Train ROC AUC: 0.9133
# Epoch [11/50], Balance 0.48, Loss: 0.5093, Train ROC AUC: 0.8526
# Epoch [11/50], Balance 0.60, Loss: 0.4789, Train ROC AUC: 0.8533
# Epoch [11/50], Balance 0.64, Loss: 0.3704, Train ROC AUC: 0.9722
# Epoch [11/50], Balance 0.64, Loss: 0.3982, Train ROC AUC: 0.9236
# Epoch [11/50], Balance 0.60, Loss: 0.2870, Train ROC AUC: 0.9467
# Epoch [11/50], Balance 0.60, Loss: 0.3363, Train ROC AUC: 0.9200
# Epoch [11/50], Balance 0.56, Loss: 0.3449, Train ROC AUC: 0.9026
# Epoch [11/50], Balance 0.48, Loss: 0.5728, Train ROC AUC: 0.8013
# Epoch [11/50], Balance 0.68, Loss: 0.4345, Train ROC AUC: 0.8750
# Epoch [11/50], Balance 0.32, Loss: 0.2955, Train ROC AUC: 0.9706
# Epoch [11/50], Balance 0.56, Loss: 0.3347, Train ROC AUC: 0.9286
# Epoch [11/50], Balance 0.52, Loss: 0.4415, Train ROC AUC: 0.8654
# Epoch [11/50], Balance 0.52, Loss: 0.3987, Train ROC AUC: 0.9038
# Epoch [11/50], Balance 0.56, Loss: 0.3393, Train ROC AUC: 0.9091
# Epoch [11/50], Balance 0.64, Loss: 0.2817, Train ROC AUC: 0.9861
# Epoch [11/50], Balance 0.56, Loss: 0.4713, Train ROC AUC: 0.8701
# Epoch [11/50], Balance 0.48, Loss: 0.3999, Train ROC AUC: 0.9038
# Epoch [11/50], Balance 0.52, Loss: 0.3842, Train ROC AUC: 0.8910
# Epoch [11/50], Balance 0.40, Loss: 0.2598, Train ROC AUC: 0.9867
# Epoch [11/50], Balance 0.44, Loss: 0.2633, Train ROC AUC: 0.9740
# Epoch [11/50], Balance 0.32, Loss: 0.5319, Train ROC AUC: 0.8603
# Epoch [11/50], Balance 0.56, Loss: 0.2516, Train ROC AUC: 0.9935
# Epoch [11/50], Balance 0.48, Loss: 0.4513, Train ROC AUC: 0.8654
# Epoch [11/50], Balance 0.44, Loss: 0.1660, Train ROC AUC: 0.9935
# Epoch [11/50], Balance 0.44, Loss: 0.4185, Train ROC AUC: 0.8571
# Epoch [11/50], Balance 0.56, Loss: 0.5985, Train ROC AUC: 0.8117
# Epoch [11/50], Balance 0.44, Loss: 0.3617, Train ROC AUC: 0.9221
# Epoch [11/50], Balance 0.60, Loss: 0.4634, Train ROC AUC: 0.8600
# Epoch [11/50], Balance 0.48, Loss: 0.2719, Train ROC AUC: 0.9615
# Epoch [11/50], Balance 0.52, Loss: 0.2589, Train ROC AUC: 0.9808
# Epoch [11/50], Balance 0.44, Loss: 0.2562, Train ROC AUC: 0.9675
# Epoch [11/50], Balance 0.44, Loss: 0.3653, Train ROC AUC: 0.9091
# Epoch [11/50], Balance 0.64, Loss: 0.3810, Train ROC AUC: 0.9236
# Epoch [11/50], Balance 0.60, Loss: 0.4846, Train ROC AUC: 0.8400
# Epoch [11/50], Balance 0.68, Loss: 0.5326, Train ROC AUC: 0.8603
# Epoch [11/50], Balance 0.60, Loss: 0.4245, Train ROC AUC: 0.8400
# Epoch [11/50], Balance 0.44, Loss: 0.2990, Train ROC AUC: 0.9675
# Epoch [11/50], Balance 0.40, Loss: 0.2484, Train ROC AUC: 0.9867
# Epoch [11/50], Balance 0.48, Loss: 0.5070, Train ROC AUC: 0.8526
# Epoch [11/50], Balance 0.36, Loss: 0.4457, Train ROC AUC: 0.8542
# Epoch [11/50], Balance 0.36, Loss: 0.1936, Train ROC AUC: 1.0000
# Epoch [11/50], Balance 0.56, Loss: 0.2740, Train ROC AUC: 0.9675
# Epoch [11/50], Balance 0.40, Loss: 0.2938, Train ROC AUC: 0.9667
# Epoch [11/50], Balance 0.32, Loss: 0.5325, Train ROC AUC: 0.9118
# Epoch [11/50], Balance 0.52, Loss: 0.3243, Train ROC AUC: 0.9359
# Epoch [11/50], Balance 0.40, Loss: 0.6445, Train ROC AUC: 0.7733
# Epoch [11/50], Balance 0.44, Loss: 0.4706, Train ROC AUC: 0.8312
# Epoch [11/50], Balance 0.52, Loss: 0.5123, Train ROC AUC: 0.8718
# Epoch [11/50], Balance 0.44, Loss: 0.2398, Train ROC AUC: 0.9805
# Epoch [11/50], Balance 0.36, Loss: 0.4706, Train ROC AUC: 0.8125
# ...
# Epoch [18/50], Balance 0.48, Loss: 0.3448, Train ROC AUC: 0.9231
# Epoch [18/50], Balance 0.44, Loss: 0.2425, Train ROC AUC: 0.9870
# Epoch [18/50], Balance 0.56, Loss: 0.7321, Train ROC AUC: 0.7727
# Epoch [18/50], Balance 0.36, Loss: 0.2962, Train ROC AUC: 0.9861
# Epoch [18/50], Balance 0.52, Loss: 0.3002, Train ROC AUC: 0.9551
# Epoch [18/50], Balance 0.44, Loss: 0.3297, Train ROC AUC: 0.9351
# Epoch [18/50], Balance 0.52, Loss: 0.2344, Train ROC AUC: 0.9808
# Epoch [18/50], Balance 0.48, Loss: 0.5315, Train ROC AUC: 0.8462
# Epoch [18/50], Balance 0.32, Loss: 0.3135, Train ROC AUC: 0.9485
# Epoch [18/50], Balance 0.52, Loss: 0.4491, Train ROC AUC: 0.8846
# Epoch [18/50], Balance 0.44, Loss: 0.3669, Train ROC AUC: 0.9156
# Epoch [18/50], Balance 0.44, Loss: 0.2036, Train ROC AUC: 0.9870
# Epoch [18/50], Balance 0.64, Loss: 0.3438, Train ROC AUC: 0.9583
# Epoch [18/50], Balance 0.52, Loss: 0.2708, Train ROC AUC: 0.9744
# Epoch [18/50], Balance 0.52, Loss: 0.3407, Train ROC AUC: 0.9103
# Epoch [18/50], Balance 0.60, Loss: 0.4114, Train ROC AUC: 0.8867
# Epoch [18/50], Balance 0.48, Loss: 0.2626, Train ROC AUC: 0.9808
# Epoch [18/50], Balance 0.36, Loss: 0.4134, Train ROC AUC: 0.9375
# Epoch [18/50], Balance 0.68, Loss: 0.3846, Train ROC AUC: 0.9412
# Epoch [18/50], Balance 0.52, Loss: 0.4892, Train ROC AUC: 0.8269
# Epoch [18/50], Balance 0.60, Loss: 0.3984, Train ROC AUC: 0.9133
# Epoch [18/50], Balance 0.64, Loss: 0.3277, Train ROC AUC: 0.9792
# Epoch [18/50], Balance 0.44, Loss: 0.3526, Train ROC AUC: 0.9221
# Epoch [18/50], Balance 0.28, Loss: 0.3564, Train ROC AUC: 0.9603
# Epoch [18/50], Balance 0.56, Loss: 0.3151, Train ROC AUC: 0.9545
# Epoch [18/50], Balance 0.68, Loss: 0.2270, Train ROC AUC: 1.0000
# Epoch [18/50], Balance 0.44, Loss: 0.3267, Train ROC AUC: 0.9545
# Epoch [18/50], Balance 0.48, Loss: 0.4186, Train ROC AUC: 0.8718
# Epoch [18/50], Balance 0.64, Loss: 0.3312, Train ROC AUC: 0.9306
# Epoch [18/50], Balance 0.48, Loss: 0.4792, Train ROC AUC: 0.8526
# Epoch [18/50], Balance 0.64, Loss: 0.3121, Train ROC AUC: 0.9722
# Epoch [18/50], Balance 0.44, Loss: 0.3288, Train ROC AUC: 0.9286
# Epoch [18/50], Balance 0.64, Loss: 0.2911, Train ROC AUC: 0.9861
# Epoch [18/50], Balance 0.48, Loss: 0.3159, Train ROC AUC: 0.9295
# Epoch [18/50], Balance 0.52, Loss: 0.4197, Train ROC AUC: 0.8974
# Epoch [18/50], Balance 0.36, Loss: 0.3721, Train ROC AUC: 0.9375
# Epoch [18/50], Balance 0.48, Loss: 0.2915, Train ROC AUC: 0.9487
# Epoch [18/50], Balance 0.48, Loss: 0.6024, Train ROC AUC: 0.7949
# Epoch [18/50], Balance 0.60, Loss: 0.2794, Train ROC AUC: 0.9600
# Epoch [18/50], Balance 0.40, Loss: 0.2572, Train ROC AUC: 0.9867
# Epoch [18/50], Balance 0.76, Loss: 0.6136, Train ROC AUC: 0.8246
# Epoch [18/50], Balance 0.56, Loss: 0.3798, Train ROC AUC: 0.9286
# Epoch [18/50], Balance 0.56, Loss: 0.5424, Train ROC AUC: 0.7922
# Epoch [18/50], Balance 0.36, Loss: 0.2065, Train ROC AUC: 1.0000
# Epoch [18/50], Balance 0.56, Loss: 0.2945, Train ROC AUC: 0.9675
# Epoch [18/50], Balance 0.44, Loss: 0.2082, Train ROC AUC: 0.9805
# Epoch [18/50], Balance 0.44, Loss: 0.3369, Train ROC AUC: 0.9416
# Epoch [18/50], Balance 0.44, Loss: 0.3124, Train ROC AUC: 0.9545
# Epoch [18/50], Balance 0.52, Loss: 0.4097, Train ROC AUC: 0.8846
# Epoch [18/50], Balance 0.52, Loss: 0.3302, Train ROC AUC: 0.9423
# Epoch [18/50], Balance 0.24, Loss: 0.3346, Train ROC AUC: 1.0000
#
# Epoch [18/50], Val ROC AUC: 0.9174
#
# Epoch    18: reducing learning rate of group 0 to 3.0000e-06.
# Epoch [19/50], Balance 0.48, Loss: 0.3679, Train ROC AUC: 0.9295
# Epoch [19/50], Balance 0.40, Loss: 0.2690, Train ROC AUC: 0.9800
# Epoch [19/50], Balance 0.40, Loss: 0.5195, Train ROC AUC: 0.8600
# Epoch [19/50], Balance 0.52, Loss: 0.2423, Train ROC AUC: 0.9872
# Epoch [19/50], Balance 0.68, Loss: 0.6816, Train ROC AUC: 0.8162
# Epoch [19/50], Balance 0.48, Loss: 0.5343, Train ROC AUC: 0.7949
# Epoch [19/50], Balance 0.60, Loss: 0.3641, Train ROC AUC: 0.9333
# Epoch [19/50], Balance 0.48, Loss: 0.4570, Train ROC AUC: 0.8526
# Epoch [19/50], Balance 0.40, Loss: 0.3592, Train ROC AUC: 0.9000
# Epoch [19/50], Balance 0.48, Loss: 0.3733, Train ROC AUC: 0.9423
# Epoch [19/50], Balance 0.56, Loss: 0.3031, Train ROC AUC: 0.9221
# Epoch [19/50], Balance 0.44, Loss: 0.2047, Train ROC AUC: 0.9805
# Epoch [19/50], Balance 0.48, Loss: 0.1591, Train ROC AUC: 1.0000
# Epoch [19/50], Balance 0.48, Loss: 0.4785, Train ROC AUC: 0.8526
# Epoch [19/50], Balance 0.52, Loss: 0.4169, Train ROC AUC: 0.8974
# Epoch [19/50], Balance 0.32, Loss: 0.5968, Train ROC AUC: 0.8456
# Epoch [19/50], Balance 0.40, Loss: 0.2975, Train ROC AUC: 0.9533
# Epoch [19/50], Balance 0.52, Loss: 0.4486, Train ROC AUC: 0.8718
# Epoch [19/50], Balance 0.56, Loss: 0.4449, Train ROC AUC: 0.8571
# Epoch [19/50], Balance 0.52, Loss: 0.2143, Train ROC AUC: 0.9936
# Epoch [19/50], Balance 0.28, Loss: 0.4994, Train ROC AUC: 0.9444
# Epoch [19/50], Balance 0.52, Loss: 0.4386, Train ROC AUC: 0.8718
# Epoch [19/50], Balance 0.56, Loss: 0.2595, Train ROC AUC: 0.9805
# Epoch [19/50], Balance 0.48, Loss: 0.2770, Train ROC AUC: 0.9679
# Epoch [19/50], Balance 0.64, Loss: 0.3749, Train ROC AUC: 0.9514
# Epoch [19/50], Balance 0.40, Loss: 0.5354, Train ROC AUC: 0.8600
# Epoch [19/50], Balance 0.60, Loss: 0.2526, Train ROC AUC: 0.9667
# Epoch [19/50], Balance 0.44, Loss: 0.3561, Train ROC AUC: 0.9286
# Epoch [19/50], Balance 0.52, Loss: 0.4309, Train ROC AUC: 0.8654
# Epoch [19/50], Balance 0.56, Loss: 0.1846, Train ROC AUC: 1.0000
# Epoch [19/50], Balance 0.40, Loss: 0.2141, Train ROC AUC: 1.0000
# Epoch [19/50], Balance 0.40, Loss: 0.3631, Train ROC AUC: 0.9200
# Epoch [19/50], Balance 0.56, Loss: 0.3568, Train ROC AUC: 0.9026
# Epoch [19/50], Balance 0.60, Loss: 0.2326, Train ROC AUC: 1.0000
# Epoch [19/50], Balance 0.72, Loss: 0.3397, Train ROC AUC: 0.9683
# Epoch [19/50], Balance 0.44, Loss: 0.4480, Train ROC AUC: 0.8701
# Epoch [19/50], Balance 0.48, Loss: 0.3849, Train ROC AUC: 0.9167
# Epoch [19/50], Balance 0.56, Loss: 0.4148, Train ROC AUC: 0.8701
# Epoch [19/50], Balance 0.68, Loss: 0.2699, Train ROC AUC: 0.9853
# Epoch [19/50], Balance 0.36, Loss: 0.2220, Train ROC AUC: 0.9931
# Epoch [19/50], Balance 0.40, Loss: 0.2894, Train ROC AUC: 0.9533
# Epoch [19/50], Balance 0.44, Loss: 0.3149, Train ROC AUC: 0.9286
# Epoch [19/50], Balance 0.52, Loss: 0.3567, Train ROC AUC: 0.9231
# Epoch [19/50], Balance 0.44, Loss: 0.3307, Train ROC AUC: 0.9221
# Epoch [19/50], Balance 0.40, Loss: 0.3073, Train ROC AUC: 0.9333
# Epoch [19/50], Balance 0.52, Loss: 0.3650, Train ROC AUC: 0.9038
# Epoch [19/50], Balance 0.48, Loss: 0.2359, Train ROC AUC: 0.9744
# Epoch [19/50], Balance 0.68, Loss: 0.5900, Train ROC AUC: 0.8603
# Epoch [19/50], Balance 0.32, Loss: 0.2861, Train ROC AUC: 0.9706
# Epoch [19/50], Balance 0.64, Loss: 0.4067, Train ROC AUC: 0.9375
# Epoch [19/50], Balance 0.40, Loss: 0.4235, Train ROC AUC: 0.8667
# Epoch [19/50], Balance 0.28, Loss: 0.5394, Train ROC AUC: 0.8651
# Epoch [19/50], Balance 0.44, Loss: 0.2778, Train ROC AUC: 0.9610
# Epoch [19/50], Balance 0.48, Loss: 0.3604, Train ROC AUC: 0.9103
# Epoch [19/50], Balance 0.48, Loss: 0.5119, Train ROC AUC: 0.8397
# Epoch [19/50], Balance 0.44, Loss: 0.2659, Train ROC AUC: 0.9740
# Epoch [19/50], Balance 0.24, Loss: 0.5842, Train ROC AUC: 0.8421
#
# Epoch [19/50], Val ROC AUC: 0.9175
#
# Epoch [20/50], Balance 0.56, Loss: 0.3641, Train ROC AUC: 0.9286
# Epoch [20/50], Balance 0.52, Loss: 0.3255, Train ROC AUC: 0.9487
# Epoch [20/50], Balance 0.52, Loss: 0.3057, Train ROC AUC: 0.9359
# Epoch [20/50], Balance 0.40, Loss: 0.2489, Train ROC AUC: 0.9933
# Epoch [20/50], Balance 0.60, Loss: 0.3921, Train ROC AUC: 0.9267
# Epoch [20/50], Balance 0.36, Loss: 0.4182, Train ROC AUC: 0.8819
# Epoch [20/50], Balance 0.60, Loss: 0.3649, Train ROC AUC: 0.9600
# Epoch [20/50], Balance 0.40, Loss: 0.2289, Train ROC AUC: 0.9733
# Epoch [20/50], Balance 0.68, Loss: 0.3981, Train ROC AUC: 0.9412
# Epoch [20/50], Balance 0.44, Loss: 0.5510, Train ROC AUC: 0.8377
# Epoch [20/50], Balance 0.56, Loss: 0.4078, Train ROC AUC: 0.9351
# Epoch [20/50], Balance 0.40, Loss: 0.3012, Train ROC AUC: 0.9400
# Epoch [20/50], Balance 0.60, Loss: 0.4123, Train ROC AUC: 0.8867
# Epoch [20/50], Balance 0.44, Loss: 0.2980, Train ROC AUC: 0.9545
# Epoch [20/50], Balance 0.52, Loss: 0.2459, Train ROC AUC: 0.9615
# Epoch [20/50], Balance 0.56, Loss: 0.3241, Train ROC AUC: 0.9740
# Epoch [20/50], Balance 0.56, Loss: 0.2888, Train ROC AUC: 0.9481
# Epoch [20/50], Balance 0.56, Loss: 0.4207, Train ROC AUC: 0.8961
# Epoch [20/50], Balance 0.44, Loss: 0.4829, Train ROC AUC: 0.8377
# Epoch [20/50], Balance 0.48, Loss: 0.2540, Train ROC AUC: 0.9615
# Epoch [20/50], Balance 0.48, Loss: 0.3487, Train ROC AUC: 0.9103
# Epoch [20/50], Balance 0.48, Loss: 0.3613, Train ROC AUC: 0.9359
# Epoch [20/50], Balance 0.36, Loss: 0.2539, Train ROC AUC: 0.9931
# Epoch [20/50], Balance 0.60, Loss: 0.3611, Train ROC AUC: 0.9333
# Epoch [20/50], Balance 0.56, Loss: 0.2487, Train ROC AUC: 0.9610
# Epoch [20/50], Balance 0.44, Loss: 0.4070, Train ROC AUC: 0.9026
# Epoch [20/50], Balance 0.36, Loss: 0.6123, Train ROC AUC: 0.8403
# Epoch [20/50], Balance 0.40, Loss: 0.3727, Train ROC AUC: 0.9133
# Epoch [20/50], Balance 0.56, Loss: 0.6682, Train ROC AUC: 0.7078
# Epoch [20/50], Balance 0.60, Loss: 0.3829, Train ROC AUC: 0.9267
# Epoch [20/50], Balance 0.48, Loss: 0.3052, Train ROC AUC: 0.9423
# Epoch [20/50], Balance 0.52, Loss: 0.3428, Train ROC AUC: 0.9167
# Epoch [20/50], Balance 0.52, Loss: 0.2864, Train ROC AUC: 0.9487
# Epoch [20/50], Balance 0.48, Loss: 0.4759, Train ROC AUC: 0.8590
# Epoch [20/50], Balance 0.60, Loss: 0.4466, Train ROC AUC: 0.9200
# Epoch [20/50], Balance 0.64, Loss: 0.4150, Train ROC AUC: 0.8681
# Epoch [20/50], Balance 0.40, Loss: 0.5012, Train ROC AUC: 0.8533
# Epoch [20/50], Balance 0.24, Loss: 0.3165, Train ROC AUC: 1.0000
#
# Epoch [20/50], Val ROC AUC: 0.9181
#
# Epoch [21/50], Balance 0.36, Loss: 0.3462, Train ROC AUC: 0.9306
# Epoch [21/50], Balance 0.56, Loss: 0.2802, Train ROC AUC: 0.9740
# Epoch [21/50], Balance 0.36, Loss: 0.4676, Train ROC AUC: 0.8958
# Epoch [21/50], Balance 0.44, Loss: 0.3500, Train ROC AUC: 0.9351
# Epoch [21/50], Balance 0.28, Loss: 0.3947, Train ROC AUC: 0.9762
# Epoch [21/50], Balance 0.52, Loss: 0.3153, Train ROC AUC: 0.9359
# Epoch [21/50], Balance 0.44, Loss: 0.2288, Train ROC AUC: 0.9870
# Epoch [21/50], Balance 0.56, Loss: 0.3202, Train ROC AUC: 0.9416
# Epoch [21/50], Balance 0.48, Loss: 0.5789, Train ROC AUC: 0.7821
# Epoch [21/50], Balance 0.36, Loss: 0.2871, Train ROC AUC: 0.9792
# Epoch [21/50], Balance 0.44, Loss: 0.4656, Train ROC AUC: 0.8831
# Epoch [21/50], Balance 0.44, Loss: 0.5779, Train ROC AUC: 0.7987
# Epoch [21/50], Balance 0.40, Loss: 0.3823, Train ROC AUC: 0.9267
# Epoch [21/50], Balance 0.48, Loss: 0.2775, Train ROC AUC: 0.9615
# Epoch [21/50], Balance 0.68, Loss: 0.5913, Train ROC AUC: 0.8015
# Epoch [21/50], Balance 0.52, Loss: 0.2528, Train ROC AUC: 0.9679
# Epoch [21/50], Balance 0.32, Loss: 0.5303, Train ROC AUC: 0.9044
# Epoch [21/50], Balance 0.56, Loss: 0.2407, Train ROC AUC: 0.9935
# Epoch [21/50], Balance 0.52, Loss: 0.5028, Train ROC AUC: 0.8526
# Epoch [21/50], Balance 0.40, Loss: 0.2464, Train ROC AUC: 0.9800
# Epoch [21/50], Balance 0.44, Loss: 0.3028, Train ROC AUC: 0.9416
# Epoch [21/50], Balance 0.44, Loss: 0.2559, Train ROC AUC: 0.9805
# Epoch [21/50], Balance 0.44, Loss: 0.3014, Train ROC AUC: 0.9416
# Epoch [21/50], Balance 0.52, Loss: 0.2818, Train ROC AUC: 0.9551
# Epoch [21/50], Balance 0.56, Loss: 0.3035, Train ROC AUC: 0.9545
# Epoch [21/50], Balance 0.56, Loss: 0.2677, Train ROC AUC: 0.9481
# Epoch [21/50], Balance 0.52, Loss: 0.3365, Train ROC AUC: 0.9359
# Epoch [21/50], Balance 0.52, Loss: 0.2748, Train ROC AUC: 0.9872
# Epoch [21/50], Balance 0.44, Loss: 0.4874, Train ROC AUC: 0.8506
# Epoch [21/50], Balance 0.48, Loss: 0.4099, Train ROC AUC: 0.8974
# Epoch [21/50], Balance 0.36, Loss: 0.3405, Train ROC AUC: 0.9444
# Epoch [21/50], Balance 0.56, Loss: 0.2762, Train ROC AUC: 0.9675
# Epoch [21/50], Balance 0.40, Loss: 0.3700, Train ROC AUC: 0.9267
# Epoch [21/50], Balance 0.36, Loss: 0.3457, Train ROC AUC: 0.9514
# Epoch [21/50], Balance 0.32, Loss: 0.2912, Train ROC AUC: 0.9706
# Epoch [21/50], Balance 0.44, Loss: 0.6195, Train ROC AUC: 0.8052
# Epoch [21/50], Balance 0.44, Loss: 0.2876, Train ROC AUC: 0.9286
# Epoch [21/50], Balance 0.56, Loss: 0.3514, Train ROC AUC: 0.9286
# Epoch [21/50], Balance 0.44, Loss: 0.4151, Train ROC AUC: 0.8896
# Epoch [21/50], Balance 0.52, Loss: 0.5098, Train ROC AUC: 0.8526
# Epoch [21/50], Balance 0.36, Loss: 0.3752, Train ROC AUC: 0.9097
# Epoch [21/50], Balance 0.56, Loss: 0.4431, Train ROC AUC: 0.9026
# Epoch [21/50], Balance 0.44, Loss: 0.2428, Train ROC AUC: 0.9805
# Epoch [21/50], Balance 0.64, Loss: 0.2556, Train ROC AUC: 0.9861
# Epoch [21/50], Balance 0.64, Loss: 0.4849, Train ROC AUC: 0.9028
# Epoch [21/50], Balance 0.52, Loss: 0.5273, Train ROC AUC: 0.8654
# Epoch [21/50], Balance 0.32, Loss: 0.3140, Train ROC AUC: 0.9632
# Epoch [21/50], Balance 0.24, Loss: 0.4197, Train ROC AUC: 0.9386
#
# Epoch [21/50], Val ROC AUC: 0.9181
#
# Epoch [22/50], Balance 0.60, Loss: 0.4950, Train ROC AUC: 0.8467
# Epoch [22/50], Balance 0.56, Loss: 0.3235, Train ROC AUC: 0.9286
# Epoch [22/50], Balance 0.36, Loss: 0.4027, Train ROC AUC: 0.9306
# Epoch [22/50], Balance 0.72, Loss: 0.4722, Train ROC AUC: 0.9444
# Epoch [22/50], Balance 0.56, Loss: 0.2502, Train ROC AUC: 0.9740
# Epoch [22/50], Balance 0.52, Loss: 0.3304, Train ROC AUC: 0.9487
# Epoch [22/50], Balance 0.40, Loss: 0.3742, Train ROC AUC: 0.9267
# Epoch [22/50], Balance 0.40, Loss: 0.4156, Train ROC AUC: 0.9067
# Epoch [22/50], Balance 0.24, Loss: 0.5741, Train ROC AUC: 0.8684
#
# Epoch [22/50], Val ROC AUC: 0.9179
#
# Epoch [23/50], Balance 0.60, Loss: 0.2712, Train ROC AUC: 0.9800
# Epoch [23/50], Balance 0.60, Loss: 0.2898, Train ROC AUC: 0.9400
# Epoch [23/50], Balance 0.48, Loss: 0.2466, Train ROC AUC: 0.9679
# Epoch [23/50], Balance 0.60, Loss: 0.1920, Train ROC AUC: 0.9933
# Epoch [23/50], Balance 0.56, Loss: 0.3878, Train ROC AUC: 0.9091
# Epoch [23/50], Balance 0.36, Loss: 0.2211, Train ROC AUC: 1.0000
# Epoch [23/50], Balance 0.36, Loss: 0.3472, Train ROC AUC: 0.9653
# Epoch [23/50], Balance 0.52, Loss: 0.2465, Train ROC AUC: 0.9744
# Epoch [23/50], Balance 0.44, Loss: 0.3468, Train ROC AUC: 0.9156
# Epoch [23/50], Balance 0.48, Loss: 0.4156, Train ROC AUC: 0.9038
# Epoch [23/50], Balance 0.76, Loss: 0.6544, Train ROC AUC: 0.8158
# Epoch [23/50], Balance 0.36, Loss: 0.1774, Train ROC AUC: 1.0000
# Epoch [23/50], Balance 0.60, Loss: 0.3549, Train ROC AUC: 0.9533
# Epoch [23/50], Balance 0.44, Loss: 0.3636, Train ROC AUC: 0.9221
# Epoch [23/50], Balance 0.48, Loss: 0.2550, Train ROC AUC: 0.9808
# Epoch [23/50], Balance 0.60, Loss: 0.2616, Train ROC AUC: 0.9733
# Epoch [23/50], Balance 0.52, Loss: 0.3701, Train ROC AUC: 0.9103
# Epoch [23/50], Balance 0.48, Loss: 0.2892, Train ROC AUC: 0.9615
# Epoch [23/50], Balance 0.56, Loss: 0.2672, Train ROC AUC: 0.9740
# Epoch [23/50], Balance 0.76, Loss: 0.8507, Train ROC AUC: 0.7982
# Epoch [23/50], Balance 0.36, Loss: 0.6030, Train ROC AUC: 0.8056
# Epoch [23/50], Balance 0.44, Loss: 0.4628, Train ROC AUC: 0.8182
# Epoch [23/50], Balance 0.56, Loss: 0.3269, Train ROC AUC: 0.9351
# Epoch [23/50], Balance 0.40, Loss: 0.2787, Train ROC AUC: 0.9600
# Epoch [23/50], Balance 0.56, Loss: 0.2766, Train ROC AUC: 0.9545
# Epoch [23/50], Balance 0.32, Loss: 0.3753, Train ROC AUC: 0.9485
# Epoch [23/50], Balance 0.48, Loss: 0.3130, Train ROC AUC: 0.9231
# Epoch [23/50], Balance 0.48, Loss: 0.4166, Train ROC AUC: 0.8846
# Epoch [23/50], Balance 0.52, Loss: 0.5125, Train ROC AUC: 0.8269
# Epoch [23/50], Balance 0.48, Loss: 0.3991, Train ROC AUC: 0.8718
# Epoch [23/50], Balance 0.68, Loss: 0.4201, Train ROC AUC: 0.8750
# Epoch [23/50], Balance 0.40, Loss: 0.3682, Train ROC AUC: 0.9000
# Epoch [23/50], Balance 0.64, Loss: 0.2957, Train ROC AUC: 0.9653
# Epoch [23/50], Balance 0.28, Loss: 0.3741, Train ROC AUC: 0.9762
# Epoch [23/50], Balance 0.36, Loss: 0.3441, Train ROC AUC: 0.9583
# Epoch [23/50], Balance 0.56, Loss: 0.2059, Train ROC AUC: 0.9935
# Epoch [23/50], Balance 0.16, Loss: 0.5313, Train ROC AUC: 0.9643
#
# Epoch [23/50], Val ROC AUC: 0.9177
#
# Early stopping. Best validation roc_auc: 0.918
# <All keys matched successfully>

# %%
plt.style.use('seaborn-colorblind')
plt.rcParams.update({'font.size': 16, 
                     'legend.framealpha':1, 
                     'legend.edgecolor':'inherit'}) 
plt.figure(figsize=(9, 6))

plt.plot(losses,label='Train loss')
#plt.ylim([.4, .8])
plt.legend()
plt.show()

# %%
plt.style.use('seaborn-colorblind')
plt.rcParams.update({'font.size': 16, 
                     'legend.framealpha':1, 
                     'legend.edgecolor':'inherit'}) 
plt.figure(figsize=(9, 6))

plt.plot(train_roc, label = 'Train ROC AUC')
plt.legend()
plt.show()

# %%
plt.style.use('seaborn-colorblind')
plt.rcParams.update({'font.size': 16, 
                     'legend.framealpha':1, 
                     'legend.edgecolor':'inherit'}) 
plt.figure(figsize=(9, 6))

plt.plot(val_roc, label = 'Validation ROC AUC')
plt.legend()
plt.show()

# %%
valid_predictions = []
valid_targets = []

model.eval() # prep model for evaluation
with torch.no_grad():
    for i, (images, labels) in enumerate(valid_loader):
        images = images.to(device)

        labels = torch.reshape(labels, [len(labels), 1])
        labels = labels.to(device)

        # Forward pass
        outputs = model(images)
        valid_predictions += list(outputs.detach().cpu().numpy().ravel())
        valid_targets += list(labels.cpu().numpy().ravel()) 

fpr, tpr, _ = roc_curve(np.array(valid_targets, np.int), np.array(valid_predictions).ravel())
roc_auc = auc(fpr, tpr)

percent_tp = sum(valid_targets)/len(valid_targets) * 100 
baseline = np.max([percent_tp, 100-percent_tp])
acc = 100 * np.sum(np.round(valid_predictions) == np.array(valid_targets)) / len(valid_targets)

print('\nBaseline classification accuracy: {:.2f}'.format(baseline))
print('\nModel classification accuracy:    {:.2f}'.format(acc))

plt.style.use('seaborn-colorblind')
plt.rcParams.update({'font.size': 16, 
                     'legend.framealpha':1, 
                     'legend.edgecolor':'inherit'}) 
plt.figure(figsize=(9, 6))

lw = 2
plt.plot(fpr, tpr, 
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")

plt.tight_layout()
plt.show()
# Out:
# Baseline classification accuracy: 91.06
#
# Model classification accuracy:    83.82

# %%
tn, fp, fn, tp = confusion_matrix(np.array(valid_targets, np.int), np.round(np.array(valid_predictions).ravel())).ravel()

accuracy = (tp + tn) / len(valid_targets)
precision = tp / (tp + fp)
recall = tp / (tp + fn)
print("Model accuracy: {:.2f}".format(accuracy))
print("Model precision: {:.2f}".format(precision))
print("Model recall: {:.2f}".format(recall))

print("\nConfusion Matrix: ")
print(confusion_matrix(np.array(valid_targets, np.int), np.round(np.array(valid_predictions).ravel())))
# Out:
# Model accuracy: 0.84
# Model precision: 0.33
# Model recall: 0.82
#
# Confusion Matrix:
# [[4628  880]
#  [  99  442]]

# %%
plt.style.use('seaborn-colorblind')
plt.rcParams.update({'font.size': 16, 
                     'legend.framealpha':1, 
                     'legend.edgecolor':'inherit'}) 
plt.figure(figsize=(9, 6))

plt.hist(valid_predictions)
plt.xlabel("P(y=malignant | x)")
plt.show()

# %%
train_df.to_csv("ENET_train_df_all.csv", index=False)
val_df.to_csv("ENET_val_df_all.csv", index=False)
