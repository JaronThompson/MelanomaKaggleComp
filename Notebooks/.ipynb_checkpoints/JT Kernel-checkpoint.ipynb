# %%
import numpy as np 
import pandas as pd 
#import pydicom
import matplotlib.pyplot as plt 

import torch 
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms

from PIL import Image
from skimage.transform import resize
from sklearn.metrics import confusion_matrix, roc_curve, auc

# %%
# upload train dataframe
train_df_allsamples = pd.read_csv("../../data/marking.csv")
train_df_allsamples.head()
# Out:
#    patient_id      image_id  target  source     sex  age_approx  \
# 0  IP_7279968  ISIC_2637011       0  ISIC20    male        45.0
# 1  IP_3075186  ISIC_0015719       0  ISIC20  female        45.0
# 2  IP_2842074  ISIC_0052212       0  ISIC20  female        50.0
# 3  IP_6890425  ISIC_0068279       0  ISIC20  female        45.0
# 4  IP_8723313  ISIC_0074268       0  ISIC20  female        55.0
#
#   anatom_site_general_challenge
# 0                     head/neck
# 1               upper extremity
# 2               lower extremity
# 3                     head/neck
# 4               upper extremity

# %%
# create dictionary that maps image name to target 
image_names = train_df_allsamples["image_id"].values 
targets = train_df_allsamples["target"].values
img_to_target = {image_name:target for image_name, target in zip(image_names, targets)}

percent_tp = sum(targets)/len(targets) * 100 
print("{} training samples total.".format(len(targets)))
print("Only {:.3f} percent of training data set is a true positive.".format(percent_tp))
print("Therefore, the baseline accuracy is {:.3f}".format(np.max([percent_tp, 100-percent_tp])))
# Out:
# 60487 training samples total.
# Only 9.058 percent of training data set is a true positive.
# Therefore, the baseline accuracy is 90.942

# %%
# update so that the number of positives balances negatives
train_df_pos = train_df_allsamples.iloc[targets>0, :]
train_df_neg = train_df_allsamples.iloc[targets==0, :]
train_df_negsample = train_df_neg.sample(n=int(train_df_pos.shape[0]))

# concatenate negative and positive samples, then shuffle using .sample() 
#train_val_df = pd.concat((train_df_pos, train_df_negsample)).sample(frac=1)
train_val_df = train_df_allsamples.sample(frac=1)

train_val_split = .99
n_train_val = train_val_df.shape[0]
n_train = int(train_val_split*n_train_val)

train_df = train_val_df[:n_train]
val_df = train_val_df[n_train:]

# create dictionary that maps image name to target 
image_names = val_df["image_id"].values 
val_targets = val_df["target"].values

percent_tp = sum(val_targets)/len(val_targets) * 100 
baseline = np.max([percent_tp, 100-percent_tp])

print("{} Training and {} Validation samples".format(n_train, n_train_val-n_train))
print("{:.3f} percent of validation data set is a positive.".format(percent_tp))
print("Baseline validation accuracy is {:.3f}".format(baseline))
# Out:
# 59882 Training and 605 Validation samples
# 9.917 percent of validation data set is a positive.
# Baseline validation accuracy is 90.083

# %%
# start by trying to display an image from training set 

# specify path to training data  
train_path = "../../data/512x512-dataset-melanoma/512x512-dataset-melanoma/"

# load all training files
train_files = [s+".jpg" for s in train_df["image_id"].values]

# pull an example 
img_ind = 0
example = train_path + train_files[img_ind]
img_name = train_files[img_ind].split(".")[0]
img = plt.imread(example)
print("image shape: ")
print(img.shape)
print("\n image is malignant?: {}".format(img_to_target[img_name]))

# display 
plt.figure(figsize=(9, 6))
plt.imshow(img)
plt.show()
# Out:
# image shape:
# (512, 512, 3)
#
#  image is malignant?: 0

# %% [markdown]
# Need image preprocessing steps to:
#
# 1. Isolate the melanoma and crop image
# 2. Ensure cropped images are a consistent size for input to CNN

# %%
# Device configuration (GPU can be enabled in settings)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
#device = 'cpu'
print(device)
# Out:
# cuda:0

# %%
# set up data loader class 
def relative_scale(img, size=128, focus=1.5):
    # crop image (e.g. focus = 2 cuts image size in half)
    w, h = img[:, :, 0].shape 
    
    x_start = w//2 - np.int(w/(2*focus))
    x_end = w//2 + np.int(w/(2*focus))
    
    y_start = h//2 - np.int(h/(2*focus))
    y_end = h//2 + np.int(h/(2*focus))
    
    img_crop = img[x_start:x_end, y_start:y_end, :]
    
    img_resize = cv2.resize(img, (size, size))
    return img_resize

transform = transforms.Compose(
                   [transforms.RandomHorizontalFlip(p=0.5),
                    transforms.RandomVerticalFlip(p=0.5),
                    transforms.ToTensor()])
                    #transforms.Normalize(mean=[1., 1., 1.], std=[.5, .5, .5])])

class Dataset(torch.utils.data.Dataset):
    def __init__(self, df, path_to_files):
        # 1. Initialize file paths or a list of file names.
        self.path = path_to_files
        self.df = df

    def __getitem__(self, index):
        # 1. Read one data from file (e.g. using numpy.fromfile, PIL.Image.open).
        
        # load X 
        img_name = self.df['image_id'].values[index]
        img_path = self.path + img_name + ".jpg"
        img = plt.imread(img_path)
        
        # load y 
        label = self.df["target"].values[index]
        target = torch.tensor(label, dtype=torch.float32)
        
        # 2. Preprocess the data (e.g. torchvision.Transform).
        img = Image.fromarray(img)
        #img = img.resize((256, 256))
        img_processed = transform(img)
        # 3. Return a data pair (e.g. image and label).
        return img_processed, target
        
    def __len__(self):
        # total size of your dataset.
        return self.df.shape[0]

# %%
# Data loader (this provides queues and threads in a very simple way).
train_path = "../../data/512x512-dataset-melanoma/512x512-dataset-melanoma/"
custom_dataset = Dataset(train_df, train_path)

train_loader = torch.utils.data.DataLoader(dataset=custom_dataset,
                                           batch_size=1,
                                           shuffle=False)

data_iter = iter(train_loader)

# Mini-batch images and labels.
images, labels = data_iter.next()

# lets look at the transformed image 
im = images[0, 0, :, :].numpy()
plt.figure(figsize=(9,6))
plt.imshow(im)
plt.show()

# %%
# Hyper parameters
num_epochs = 1
batch_size = 64
learning_rate = 0.001 

# Convolutional neural network
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=8, kernel_size=7, stride=2, padding=2),
            nn.BatchNorm2d(8),
            nn.ReLU(),
            nn.Dropout(p=0.3),
            nn.MaxPool2d(kernel_size=4, stride=4))
        self.layer2 = nn.Sequential(
            nn.Conv2d(8, 8, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(8),
            nn.ReLU(),
            nn.Dropout(p=0.3),
            nn.MaxPool2d(kernel_size=4, stride=4)) 
        self.fc = nn.Sequential(
            nn.Linear(1800, 32),
            nn.BatchNorm1d(32),
            nn.Sigmoid(),
            nn.Dropout(p=0.3))
        self.output = nn.Sequential(
            nn.Linear(32, 1),
            nn.Sigmoid())
        
    def embedding(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = out.reshape(out.size(0), -1)
        out = self.fc(out)
        return out 
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = out.reshape(out.size(0), -1)
        out = self.fc(out)
        out = self.output(out)
        return out

model = ConvNet().to(device)

# Loss and optimizer
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def make_weights_for_balanced_classes(df, nclasses=2):   
    targets = df["target"].values
    count = [0] * nclasses                                                      
    for label in targets:                                                         
        count[label] += 1                                                     
    weight_per_class = [0.] * nclasses                                      
    N = float(sum(count))                                                   
    for i in range(nclasses):                                                   
        weight_per_class[i] = N/float(count[i])                                 
    weight = [0] * len(targets)                                              
    for idx, label in enumerate(targets):                                          
        weight[idx] = weight_per_class[label]                                  
    return weight

# %%
# Train the model
# Use the prebuilt data loader.
path = "../../data/512x512-dataset-melanoma/512x512-dataset-melanoma/"

train_dataset = Dataset(train_df, path)
train_weights = make_weights_for_balanced_classes(train_df)
train_sampler = torch.utils.data.sampler.WeightedRandomSampler(train_weights, len(train_weights))                                                
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           sampler = train_sampler)   

# evaluate performance on validation data 
valid_dataset = Dataset(val_df, path)
valid_weights = make_weights_for_balanced_classes(val_df)
valid_sampler = torch.utils.data.sampler.WeightedRandomSampler(valid_weights, len(valid_weights))                                                
valid_loader = torch.utils.data.DataLoader(dataset=valid_dataset, 
                                           batch_size=50, 
                                           sampler = valid_sampler) 

# save losses from training 
losses = []
val_roc = []

total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        # set up model for training 
        model = model.train()
        
        images = images.to(device)
        labels = torch.reshape(labels, [len(labels), 1])
        labels = labels.to(device)
        
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # store loss
        losses.append(loss)
        
        # Calculate ROC
        predictions = outputs.detach().cpu().numpy().ravel()
        targets = labels.cpu().numpy().ravel()

        fpr, tpr, _ = roc_curve(np.array(targets, np.int), np.array(predictions).ravel())
        train_roc_auc = auc(fpr, tpr)
        
        # prep model for evaluation
        valid_predictions = []
        valid_targets = []
        model.eval() 
        with torch.no_grad():
            for j, (images, labels) in enumerate(valid_loader):
                images = images.to(device)

                labels = torch.reshape(labels, [len(labels), 1])
                labels = labels.to(device)

                # Forward pass
                outputs = model(images)

                # Calculate val ROC
                valid_predictions += list(outputs.detach().cpu().numpy().ravel())
                valid_targets += list(labels.cpu().numpy().ravel()) 

        fpr, tpr, _ = roc_curve(np.array(valid_targets, np.int), np.array(valid_predictions).ravel())
        val_roc_auc = auc(fpr, tpr)
        val_roc.append(val_roc_auc)
        
        print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Train ROC AUC: {:.4f}, Val ROC AUC: {:.4f}' 
               .format(epoch+1, num_epochs, i+1, total_step, loss.item(), train_roc_auc, val_roc_auc))
# Out:
# Epoch [1/1], Step [1/936], Loss: 0.6660, Train ROC AUC: 0.6115, Val ROC AUC: 0.6786
# Epoch [1/1], Step [2/936], Loss: 0.6193, Train ROC AUC: 0.8492, Val ROC AUC: 0.7241
# Epoch [1/1], Step [3/936], Loss: 0.5893, Train ROC AUC: 0.8172, Val ROC AUC: 0.6948
# Epoch [1/1], Step [4/936], Loss: 0.6036, Train ROC AUC: 0.7381, Val ROC AUC: 0.7092
# Epoch [1/1], Step [5/936], Loss: 0.6065, Train ROC AUC: 0.8506, Val ROC AUC: 0.6965
# Epoch [1/1], Step [6/936], Loss: 0.6074, Train ROC AUC: 0.7852, Val ROC AUC: 0.7091
# Epoch [1/1], Step [7/936], Loss: 0.5942, Train ROC AUC: 0.7667, Val ROC AUC: 0.7619
# Epoch [1/1], Step [8/936], Loss: 0.5798, Train ROC AUC: 0.8348, Val ROC AUC: 0.7383
# Epoch [1/1], Step [9/936], Loss: 0.6138, Train ROC AUC: 0.7383, Val ROC AUC: 0.7269
# Epoch [1/1], Step [10/936], Loss: 0.6047, Train ROC AUC: 0.7654, Val ROC AUC: 0.7534
# Epoch [1/1], Step [11/936], Loss: 0.6135, Train ROC AUC: 0.7305, Val ROC AUC: 0.7571
# Epoch [1/1], Step [12/936], Loss: 0.5946, Train ROC AUC: 0.7765, Val ROC AUC: 0.7140
# Epoch [1/1], Step [13/936], Loss: 0.5945, Train ROC AUC: 0.7791, Val ROC AUC: 0.7553
# Epoch [1/1], Step [14/936], Loss: 0.5947, Train ROC AUC: 0.7743, Val ROC AUC: 0.7570
# Epoch [1/1], Step [15/936], Loss: 0.6575, Train ROC AUC: 0.6455, Val ROC AUC: 0.7529
# Epoch [1/1], Step [16/936], Loss: 0.6934, Train ROC AUC: 0.5942, Val ROC AUC: 0.7658
# Epoch [1/1], Step [17/936], Loss: 0.6261, Train ROC AUC: 0.7275, Val ROC AUC: 0.7614
# Epoch [1/1], Step [18/936], Loss: 0.6178, Train ROC AUC: 0.7333, Val ROC AUC: 0.7733
# Epoch [1/1], Step [19/936], Loss: 0.5775, Train ROC AUC: 0.7956, Val ROC AUC: 0.8023
# Epoch [1/1], Step [20/936], Loss: 0.5983, Train ROC AUC: 0.7609, Val ROC AUC: 0.7916
# Epoch [1/1], Step [21/936], Loss: 0.5662, Train ROC AUC: 0.8262, Val ROC AUC: 0.8081
# Epoch [1/1], Step [22/936], Loss: 0.6553, Train ROC AUC: 0.6314, Val ROC AUC: 0.8127
# Epoch [1/1], Step [23/936], Loss: 0.5722, Train ROC AUC: 0.8304, Val ROC AUC: 0.8274
# Epoch [1/1], Step [24/936], Loss: 0.6038, Train ROC AUC: 0.7579, Val ROC AUC: 0.7652
# Epoch [1/1], Step [25/936], Loss: 0.5836, Train ROC AUC: 0.7948, Val ROC AUC: 0.7901
# Epoch [1/1], Step [26/936], Loss: 0.5674, Train ROC AUC: 0.8244, Val ROC AUC: 0.7688
# Epoch [1/1], Step [27/936], Loss: 0.5687, Train ROC AUC: 0.8409, Val ROC AUC: 0.7984
# Epoch [1/1], Step [28/936], Loss: 0.6251, Train ROC AUC: 0.7324, Val ROC AUC: 0.7522
# Epoch [1/1], Step [29/936], Loss: 0.5876, Train ROC AUC: 0.7520, Val ROC AUC: 0.7707
# Epoch [1/1], Step [30/936], Loss: 0.6259, Train ROC AUC: 0.7127, Val ROC AUC: 0.7886
# Epoch [1/1], Step [31/936], Loss: 0.5984, Train ROC AUC: 0.7628, Val ROC AUC: 0.7663
# Epoch [1/1], Step [32/936], Loss: 0.5949, Train ROC AUC: 0.7567, Val ROC AUC: 0.7704
# Epoch [1/1], Step [33/936], Loss: 0.5814, Train ROC AUC: 0.7852, Val ROC AUC: 0.7924
# Epoch [1/1], Step [34/936], Loss: 0.5537, Train ROC AUC: 0.8463, Val ROC AUC: 0.7934
# Epoch [1/1], Step [35/936], Loss: 0.5932, Train ROC AUC: 0.7742, Val ROC AUC: 0.7962
# Epoch [1/1], Step [36/936], Loss: 0.5849, Train ROC AUC: 0.7853, Val ROC AUC: 0.7717
# Epoch [1/1], Step [37/936], Loss: 0.6138, Train ROC AUC: 0.7214, Val ROC AUC: 0.7474
# Epoch [1/1], Step [38/936], Loss: 0.5656, Train ROC AUC: 0.8258, Val ROC AUC: 0.7803
# Epoch [1/1], Step [39/936], Loss: 0.5986, Train ROC AUC: 0.7407, Val ROC AUC: 0.7583
# Epoch [1/1], Step [40/936], Loss: 0.5456, Train ROC AUC: 0.8619, Val ROC AUC: 0.8152
# Epoch [1/1], Step [41/936], Loss: 0.5416, Train ROC AUC: 0.8436, Val ROC AUC: 0.8054
# Epoch [1/1], Step [42/936], Loss: 0.5181, Train ROC AUC: 0.8710, Val ROC AUC: 0.8135
# Epoch [1/1], Step [43/936], Loss: 0.6341, Train ROC AUC: 0.7163, Val ROC AUC: 0.7836
# Epoch [1/1], Step [44/936], Loss: 0.5665, Train ROC AUC: 0.8086, Val ROC AUC: 0.7747
# Epoch [1/1], Step [45/936], Loss: 0.5721, Train ROC AUC: 0.8167, Val ROC AUC: 0.7982
# Epoch [1/1], Step [46/936], Loss: 0.5329, Train ROC AUC: 0.8573, Val ROC AUC: 0.7752
# Epoch [1/1], Step [47/936], Loss: 0.5961, Train ROC AUC: 0.7768, Val ROC AUC: 0.7764
# Epoch [1/1], Step [48/936], Loss: 0.6223, Train ROC AUC: 0.6999, Val ROC AUC: 0.7983
# Epoch [1/1], Step [49/936], Loss: 0.5139, Train ROC AUC: 0.8925, Val ROC AUC: 0.8110
# Epoch [1/1], Step [50/936], Loss: 0.5669, Train ROC AUC: 0.8025, Val ROC AUC: 0.8013
# Epoch [1/1], Step [51/936], Loss: 0.5608, Train ROC AUC: 0.8016, Val ROC AUC: 0.7733
# Epoch [1/1], Step [52/936], Loss: 0.5320, Train ROC AUC: 0.8719, Val ROC AUC: 0.7699
# Epoch [1/1], Step [53/936], Loss: 0.5621, Train ROC AUC: 0.8035, Val ROC AUC: 0.7635
# Epoch [1/1], Step [54/936], Loss: 0.6360, Train ROC AUC: 0.6906, Val ROC AUC: 0.7918
# Epoch [1/1], Step [55/936], Loss: 0.5821, Train ROC AUC: 0.7744, Val ROC AUC: 0.8002
# Epoch [1/1], Step [56/936], Loss: 0.5824, Train ROC AUC: 0.7785, Val ROC AUC: 0.7874
# Epoch [1/1], Step [57/936], Loss: 0.5815, Train ROC AUC: 0.7627, Val ROC AUC: 0.7712
# Epoch [1/1], Step [58/936], Loss: 0.5473, Train ROC AUC: 0.8254, Val ROC AUC: 0.7829
# Epoch [1/1], Step [59/936], Loss: 0.6062, Train ROC AUC: 0.7074, Val ROC AUC: 0.7715
# Epoch [1/1], Step [60/936], Loss: 0.5973, Train ROC AUC: 0.7540, Val ROC AUC: 0.8140
# Epoch [1/1], Step [61/936], Loss: 0.5403, Train ROC AUC: 0.8304, Val ROC AUC: 0.7770
# Epoch [1/1], Step [62/936], Loss: 0.6494, Train ROC AUC: 0.6427, Val ROC AUC: 0.7384
# Epoch [1/1], Step [63/936], Loss: 0.5258, Train ROC AUC: 0.8428, Val ROC AUC: 0.7919
# Epoch [1/1], Step [64/936], Loss: 0.6197, Train ROC AUC: 0.7123, Val ROC AUC: 0.7592
# Epoch [1/1], Step [65/936], Loss: 0.5589, Train ROC AUC: 0.7990, Val ROC AUC: 0.7886
# Epoch [1/1], Step [66/936], Loss: 0.4826, Train ROC AUC: 0.9241, Val ROC AUC: 0.7836
# Epoch [1/1], Step [67/936], Loss: 0.5722, Train ROC AUC: 0.8027, Val ROC AUC: 0.7799
# Epoch [1/1], Step [68/936], Loss: 0.5479, Train ROC AUC: 0.8162, Val ROC AUC: 0.8126
# Epoch [1/1], Step [69/936], Loss: 0.5742, Train ROC AUC: 0.8174, Val ROC AUC: 0.8180
# Epoch [1/1], Step [70/936], Loss: 0.5959, Train ROC AUC: 0.7461, Val ROC AUC: 0.7549
# Epoch [1/1], Step [71/936], Loss: 0.5681, Train ROC AUC: 0.7928, Val ROC AUC: 0.7872
# Epoch [1/1], Step [72/936], Loss: 0.5155, Train ROC AUC: 0.8749, Val ROC AUC: 0.7943
# Epoch [1/1], Step [73/936], Loss: 0.5569, Train ROC AUC: 0.8359, Val ROC AUC: 0.7825
# Epoch [1/1], Step [74/936], Loss: 0.4803, Train ROC AUC: 0.9052, Val ROC AUC: 0.8206
# Epoch [1/1], Step [75/936], Loss: 0.5794, Train ROC AUC: 0.7833, Val ROC AUC: 0.7938
# Epoch [1/1], Step [76/936], Loss: 0.5320, Train ROC AUC: 0.8431, Val ROC AUC: 0.7952
# Epoch [1/1], Step [77/936], Loss: 0.6033, Train ROC AUC: 0.7426, Val ROC AUC: 0.8148
# Epoch [1/1], Step [78/936], Loss: 0.5626, Train ROC AUC: 0.7897, Val ROC AUC: 0.8252
# Epoch [1/1], Step [79/936], Loss: 0.5779, Train ROC AUC: 0.7645, Val ROC AUC: 0.7880
# Epoch [1/1], Step [80/936], Loss: 0.5462, Train ROC AUC: 0.8271, Val ROC AUC: 0.7774
# Epoch [1/1], Step [81/936], Loss: 0.5254, Train ROC AUC: 0.8471, Val ROC AUC: 0.7956
# Epoch [1/1], Step [82/936], Loss: 0.6280, Train ROC AUC: 0.7186, Val ROC AUC: 0.7872
# Epoch [1/1], Step [83/936], Loss: 0.5666, Train ROC AUC: 0.7729, Val ROC AUC: 0.8067
# Epoch [1/1], Step [84/936], Loss: 0.5425, Train ROC AUC: 0.8145, Val ROC AUC: 0.8036
# Epoch [1/1], Step [85/936], Loss: 0.5766, Train ROC AUC: 0.7628, Val ROC AUC: 0.8289
# Epoch [1/1], Step [86/936], Loss: 0.5555, Train ROC AUC: 0.8234, Val ROC AUC: 0.7874
# Epoch [1/1], Step [87/936], Loss: 0.5668, Train ROC AUC: 0.7754, Val ROC AUC: 0.8062
# Epoch [1/1], Step [88/936], Loss: 0.5255, Train ROC AUC: 0.8492, Val ROC AUC: 0.7950
# Epoch [1/1], Step [89/936], Loss: 0.6149, Train ROC AUC: 0.7312, Val ROC AUC: 0.7707
# Epoch [1/1], Step [90/936], Loss: 0.5967, Train ROC AUC: 0.7867, Val ROC AUC: 0.7797
# Epoch [1/1], Step [91/936], Loss: 0.5293, Train ROC AUC: 0.8446, Val ROC AUC: 0.7371
# Epoch [1/1], Step [92/936], Loss: 0.6408, Train ROC AUC: 0.6837, Val ROC AUC: 0.7907
# Epoch [1/1], Step [93/936], Loss: 0.5781, Train ROC AUC: 0.7758, Val ROC AUC: 0.7851
# Epoch [1/1], Step [94/936], Loss: 0.5448, Train ROC AUC: 0.8148, Val ROC AUC: 0.8227
# Epoch [1/1], Step [95/936], Loss: 0.5032, Train ROC AUC: 0.8790, Val ROC AUC: 0.7919
# Epoch [1/1], Step [96/936], Loss: 0.5399, Train ROC AUC: 0.8471, Val ROC AUC: 0.8034
# Epoch [1/1], Step [97/936], Loss: 0.5539, Train ROC AUC: 0.8421, Val ROC AUC: 0.7839
# Epoch [1/1], Step [98/936], Loss: 0.5773, Train ROC AUC: 0.8067, Val ROC AUC: 0.7858
# Epoch [1/1], Step [99/936], Loss: 0.5151, Train ROC AUC: 0.8529, Val ROC AUC: 0.7832
# Epoch [1/1], Step [100/936], Loss: 0.5863, Train ROC AUC: 0.7639, Val ROC AUC: 0.8078
# Epoch [1/1], Step [101/936], Loss: 0.5531, Train ROC AUC: 0.8078, Val ROC AUC: 0.7766
# Epoch [1/1], Step [102/936], Loss: 0.5365, Train ROC AUC: 0.8447, Val ROC AUC: 0.7937
# Epoch [1/1], Step [103/936], Loss: 0.5825, Train ROC AUC: 0.7517, Val ROC AUC: 0.7752
# Epoch [1/1], Step [104/936], Loss: 0.5511, Train ROC AUC: 0.8025, Val ROC AUC: 0.8068
# Epoch [1/1], Step [105/936], Loss: 0.5479, Train ROC AUC: 0.7988, Val ROC AUC: 0.7840
# Epoch [1/1], Step [106/936], Loss: 0.5803, Train ROC AUC: 0.7771, Val ROC AUC: 0.8015
# Epoch [1/1], Step [107/936], Loss: 0.5867, Train ROC AUC: 0.7550, Val ROC AUC: 0.8127
# Epoch [1/1], Step [108/936], Loss: 0.5525, Train ROC AUC: 0.8087, Val ROC AUC: 0.7851
# Epoch [1/1], Step [109/936], Loss: 0.5901, Train ROC AUC: 0.7480, Val ROC AUC: 0.8107
# Epoch [1/1], Step [110/936], Loss: 0.4512, Train ROC AUC: 0.9339, Val ROC AUC: 0.7909
# Epoch [1/1], Step [111/936], Loss: 0.5036, Train ROC AUC: 0.8621, Val ROC AUC: 0.7995
# Epoch [1/1], Step [112/936], Loss: 0.5623, Train ROC AUC: 0.7948, Val ROC AUC: 0.7855
# Epoch [1/1], Step [113/936], Loss: 0.5211, Train ROC AUC: 0.8299, Val ROC AUC: 0.7827
# Epoch [1/1], Step [114/936], Loss: 0.5124, Train ROC AUC: 0.8310, Val ROC AUC: 0.8233
# Epoch [1/1], Step [115/936], Loss: 0.5834, Train ROC AUC: 0.7588, Val ROC AUC: 0.8556
# Epoch [1/1], Step [116/936], Loss: 0.5490, Train ROC AUC: 0.7949, Val ROC AUC: 0.7767
# Epoch [1/1], Step [117/936], Loss: 0.5274, Train ROC AUC: 0.8300, Val ROC AUC: 0.8070
# Epoch [1/1], Step [118/936], Loss: 0.5108, Train ROC AUC: 0.8529, Val ROC AUC: 0.8001
# Epoch [1/1], Step [119/936], Loss: 0.5163, Train ROC AUC: 0.8286, Val ROC AUC: 0.7798
# Epoch [1/1], Step [120/936], Loss: 0.5299, Train ROC AUC: 0.8250, Val ROC AUC: 0.7983
# Epoch [1/1], Step [121/936], Loss: 0.4846, Train ROC AUC: 0.8983, Val ROC AUC: 0.7661
# Epoch [1/1], Step [122/936], Loss: 0.5371, Train ROC AUC: 0.8211, Val ROC AUC: 0.8177
# Epoch [1/1], Step [123/936], Loss: 0.4873, Train ROC AUC: 0.8671, Val ROC AUC: 0.8181
# Epoch [1/1], Step [124/936], Loss: 0.5503, Train ROC AUC: 0.8045, Val ROC AUC: 0.8144
# Epoch [1/1], Step [125/936], Loss: 0.5128, Train ROC AUC: 0.8452, Val ROC AUC: 0.8299
# Epoch [1/1], Step [126/936], Loss: 0.5964, Train ROC AUC: 0.7312, Val ROC AUC: 0.8300
# Epoch [1/1], Step [127/936], Loss: 0.5294, Train ROC AUC: 0.8453, Val ROC AUC: 0.7951
# Epoch [1/1], Step [128/936], Loss: 0.4761, Train ROC AUC: 0.8945, Val ROC AUC: 0.8107
# Epoch [1/1], Step [129/936], Loss: 0.4673, Train ROC AUC: 0.9005, Val ROC AUC: 0.8027
# Epoch [1/1], Step [130/936], Loss: 0.4688, Train ROC AUC: 0.8853, Val ROC AUC: 0.7986
# Epoch [1/1], Step [131/936], Loss: 0.5496, Train ROC AUC: 0.8008, Val ROC AUC: 0.7972
# Epoch [1/1], Step [132/936], Loss: 0.5545, Train ROC AUC: 0.7642, Val ROC AUC: 0.7909
# Epoch [1/1], Step [133/936], Loss: 0.5483, Train ROC AUC: 0.8198, Val ROC AUC: 0.8410
# Epoch [1/1], Step [134/936], Loss: 0.5489, Train ROC AUC: 0.8088, Val ROC AUC: 0.7909
# Epoch [1/1], Step [135/936], Loss: 0.5790, Train ROC AUC: 0.7659, Val ROC AUC: 0.7915
# Epoch [1/1], Step [136/936], Loss: 0.5718, Train ROC AUC: 0.7713, Val ROC AUC: 0.7585
# Epoch [1/1], Step [137/936], Loss: 0.5512, Train ROC AUC: 0.8089, Val ROC AUC: 0.8114
# Epoch [1/1], Step [138/936], Loss: 0.5410, Train ROC AUC: 0.8367, Val ROC AUC: 0.8512
# Epoch [1/1], Step [139/936], Loss: 0.4970, Train ROC AUC: 0.8591, Val ROC AUC: 0.7726
# Epoch [1/1], Step [140/936], Loss: 0.5652, Train ROC AUC: 0.7724, Val ROC AUC: 0.7983
# Epoch [1/1], Step [141/936], Loss: 0.5919, Train ROC AUC: 0.7556, Val ROC AUC: 0.7903
# Epoch [1/1], Step [142/936], Loss: 0.5322, Train ROC AUC: 0.8208, Val ROC AUC: 0.7974
# Epoch [1/1], Step [143/936], Loss: 0.5418, Train ROC AUC: 0.8138, Val ROC AUC: 0.8273
# Epoch [1/1], Step [144/936], Loss: 0.5236, Train ROC AUC: 0.8229, Val ROC AUC: 0.8003
# Epoch [1/1], Step [145/936], Loss: 0.5491, Train ROC AUC: 0.7961, Val ROC AUC: 0.8226
# Epoch [1/1], Step [146/936], Loss: 0.5590, Train ROC AUC: 0.7918, Val ROC AUC: 0.8425
# Epoch [1/1], Step [147/936], Loss: 0.5312, Train ROC AUC: 0.8135, Val ROC AUC: 0.8235
# Epoch [1/1], Step [148/936], Loss: 0.5054, Train ROC AUC: 0.8350, Val ROC AUC: 0.8162
# Epoch [1/1], Step [149/936], Loss: 0.5020, Train ROC AUC: 0.8368, Val ROC AUC: 0.7862
# Epoch [1/1], Step [150/936], Loss: 0.4537, Train ROC AUC: 0.9008, Val ROC AUC: 0.8212
# Epoch [1/1], Step [151/936], Loss: 0.5763, Train ROC AUC: 0.7566, Val ROC AUC: 0.8420
# Epoch [1/1], Step [152/936], Loss: 0.5194, Train ROC AUC: 0.8324, Val ROC AUC: 0.8226
# Epoch [1/1], Step [153/936], Loss: 0.5294, Train ROC AUC: 0.8068, Val ROC AUC: 0.8022
# Epoch [1/1], Step [154/936], Loss: 0.5335, Train ROC AUC: 0.8197, Val ROC AUC: 0.8176
# Epoch [1/1], Step [155/936], Loss: 0.5252, Train ROC AUC: 0.8308, Val ROC AUC: 0.8033
# Epoch [1/1], Step [156/936], Loss: 0.4851, Train ROC AUC: 0.8676, Val ROC AUC: 0.8171
# Epoch [1/1], Step [157/936], Loss: 0.4887, Train ROC AUC: 0.8728, Val ROC AUC: 0.7918
# Epoch [1/1], Step [158/936], Loss: 0.5467, Train ROC AUC: 0.7941, Val ROC AUC: 0.7861
# Epoch [1/1], Step [159/936], Loss: 0.5349, Train ROC AUC: 0.8244, Val ROC AUC: 0.8174
# Epoch [1/1], Step [160/936], Loss: 0.4699, Train ROC AUC: 0.8739, Val ROC AUC: 0.7851
# Epoch [1/1], Step [161/936], Loss: 0.5128, Train ROC AUC: 0.8404, Val ROC AUC: 0.7742
# Epoch [1/1], Step [162/936], Loss: 0.5261, Train ROC AUC: 0.8113, Val ROC AUC: 0.8251
# Epoch [1/1], Step [163/936], Loss: 0.5048, Train ROC AUC: 0.8740, Val ROC AUC: 0.8020
# Epoch [1/1], Step [164/936], Loss: 0.5004, Train ROC AUC: 0.9010, Val ROC AUC: 0.8080
# Epoch [1/1], Step [165/936], Loss: 0.5558, Train ROC AUC: 0.7907, Val ROC AUC: 0.8269
# Epoch [1/1], Step [166/936], Loss: 0.5467, Train ROC AUC: 0.8157, Val ROC AUC: 0.7992
# Epoch [1/1], Step [167/936], Loss: 0.4942, Train ROC AUC: 0.8552, Val ROC AUC: 0.8163
# Epoch [1/1], Step [168/936], Loss: 0.5396, Train ROC AUC: 0.8158, Val ROC AUC: 0.7837
# Epoch [1/1], Step [169/936], Loss: 0.5370, Train ROC AUC: 0.7996, Val ROC AUC: 0.8199
# Epoch [1/1], Step [170/936], Loss: 0.4730, Train ROC AUC: 0.8846, Val ROC AUC: 0.7925
# Epoch [1/1], Step [171/936], Loss: 0.5729, Train ROC AUC: 0.7676, Val ROC AUC: 0.8354
# Epoch [1/1], Step [172/936], Loss: 0.5695, Train ROC AUC: 0.7827, Val ROC AUC: 0.8316
# Epoch [1/1], Step [173/936], Loss: 0.4817, Train ROC AUC: 0.8671, Val ROC AUC: 0.8311
# Epoch [1/1], Step [174/936], Loss: 0.4597, Train ROC AUC: 0.8859, Val ROC AUC: 0.8263
# Epoch [1/1], Step [175/936], Loss: 0.4114, Train ROC AUC: 0.9342, Val ROC AUC: 0.8280
# Epoch [1/1], Step [176/936], Loss: 0.5029, Train ROC AUC: 0.8574, Val ROC AUC: 0.8254
# Epoch [1/1], Step [177/936], Loss: 0.4875, Train ROC AUC: 0.8806, Val ROC AUC: 0.8223
# Epoch [1/1], Step [178/936], Loss: 0.5181, Train ROC AUC: 0.8502, Val ROC AUC: 0.8575
# Epoch [1/1], Step [179/936], Loss: 0.5418, Train ROC AUC: 0.7922, Val ROC AUC: 0.8250
# Epoch [1/1], Step [180/936], Loss: 0.4499, Train ROC AUC: 0.8929, Val ROC AUC: 0.8352
# Epoch [1/1], Step [181/936], Loss: 0.5688, Train ROC AUC: 0.7654, Val ROC AUC: 0.7855
# Epoch [1/1], Step [182/936], Loss: 0.5142, Train ROC AUC: 0.8216, Val ROC AUC: 0.7901
# Epoch [1/1], Step [183/936], Loss: 0.5834, Train ROC AUC: 0.7582, Val ROC AUC: 0.7852
# Epoch [1/1], Step [184/936], Loss: 0.6065, Train ROC AUC: 0.7237, Val ROC AUC: 0.7718
# Epoch [1/1], Step [185/936], Loss: 0.5752, Train ROC AUC: 0.7630, Val ROC AUC: 0.8243
# Epoch [1/1], Step [186/936], Loss: 0.5439, Train ROC AUC: 0.7969, Val ROC AUC: 0.8185
# Epoch [1/1], Step [187/936], Loss: 0.5424, Train ROC AUC: 0.8197, Val ROC AUC: 0.8127
# Epoch [1/1], Step [188/936], Loss: 0.5692, Train ROC AUC: 0.7761, Val ROC AUC: 0.7978
# Epoch [1/1], Step [189/936], Loss: 0.5396, Train ROC AUC: 0.8029, Val ROC AUC: 0.7930
# Epoch [1/1], Step [190/936], Loss: 0.5424, Train ROC AUC: 0.8143, Val ROC AUC: 0.8232
# Epoch [1/1], Step [191/936], Loss: 0.5182, Train ROC AUC: 0.8250, Val ROC AUC: 0.8104
# Epoch [1/1], Step [192/936], Loss: 0.4523, Train ROC AUC: 0.8985, Val ROC AUC: 0.8261
# Epoch [1/1], Step [193/936], Loss: 0.4569, Train ROC AUC: 0.8839, Val ROC AUC: 0.8057
# Epoch [1/1], Step [194/936], Loss: 0.4705, Train ROC AUC: 0.8709, Val ROC AUC: 0.7921
# Epoch [1/1], Step [195/936], Loss: 0.4651, Train ROC AUC: 0.8809, Val ROC AUC: 0.8004
# Epoch [1/1], Step [196/936], Loss: 0.4963, Train ROC AUC: 0.8649, Val ROC AUC: 0.8305
# Epoch [1/1], Step [197/936], Loss: 0.4559, Train ROC AUC: 0.8779, Val ROC AUC: 0.8294
# Epoch [1/1], Step [198/936], Loss: 0.5597, Train ROC AUC: 0.7988, Val ROC AUC: 0.8181
# Epoch [1/1], Step [199/936], Loss: 0.5093, Train ROC AUC: 0.8423, Val ROC AUC: 0.8034
# Epoch [1/1], Step [200/936], Loss: 0.5712, Train ROC AUC: 0.8205, Val ROC AUC: 0.8046
# Epoch [1/1], Step [201/936], Loss: 0.5616, Train ROC AUC: 0.7842, Val ROC AUC: 0.8106
# Epoch [1/1], Step [202/936], Loss: 0.5806, Train ROC AUC: 0.7637, Val ROC AUC: 0.7704
# Epoch [1/1], Step [203/936], Loss: 0.5625, Train ROC AUC: 0.7768, Val ROC AUC: 0.7941
# Epoch [1/1], Step [204/936], Loss: 0.4834, Train ROC AUC: 0.8716, Val ROC AUC: 0.7772
# Epoch [1/1], Step [205/936], Loss: 0.6088, Train ROC AUC: 0.7561, Val ROC AUC: 0.8064
# Epoch [1/1], Step [206/936], Loss: 0.5618, Train ROC AUC: 0.7773, Val ROC AUC: 0.7842
# Epoch [1/1], Step [207/936], Loss: 0.5561, Train ROC AUC: 0.8036, Val ROC AUC: 0.8028
# Epoch [1/1], Step [208/936], Loss: 0.5660, Train ROC AUC: 0.7692, Val ROC AUC: 0.7872
# Epoch [1/1], Step [209/936], Loss: 0.5062, Train ROC AUC: 0.8463, Val ROC AUC: 0.7976
# Epoch [1/1], Step [210/936], Loss: 0.4938, Train ROC AUC: 0.8574, Val ROC AUC: 0.7837
# Epoch [1/1], Step [211/936], Loss: 0.5634, Train ROC AUC: 0.7998, Val ROC AUC: 0.8260
# Epoch [1/1], Step [212/936], Loss: 0.5337, Train ROC AUC: 0.7970, Val ROC AUC: 0.8066
# Epoch [1/1], Step [213/936], Loss: 0.5590, Train ROC AUC: 0.7745, Val ROC AUC: 0.8348
# Epoch [1/1], Step [214/936], Loss: 0.5810, Train ROC AUC: 0.7616, Val ROC AUC: 0.8246
# Epoch [1/1], Step [215/936], Loss: 0.4966, Train ROC AUC: 0.8552, Val ROC AUC: 0.8334
# Epoch [1/1], Step [216/936], Loss: 0.4507, Train ROC AUC: 0.8650, Val ROC AUC: 0.8232
# Epoch [1/1], Step [217/936], Loss: 0.4314, Train ROC AUC: 0.9052, Val ROC AUC: 0.7983
# Epoch [1/1], Step [218/936], Loss: 0.4441, Train ROC AUC: 0.8828, Val ROC AUC: 0.8345
# Epoch [1/1], Step [219/936], Loss: 0.5335, Train ROC AUC: 0.8018, Val ROC AUC: 0.8248
# Epoch [1/1], Step [220/936], Loss: 0.4819, Train ROC AUC: 0.8637, Val ROC AUC: 0.8234
# Epoch [1/1], Step [221/936], Loss: 0.5670, Train ROC AUC: 0.7935, Val ROC AUC: 0.8088
# Epoch [1/1], Step [222/936], Loss: 0.4609, Train ROC AUC: 0.8837, Val ROC AUC: 0.8030
# Epoch [1/1], Step [223/936], Loss: 0.5108, Train ROC AUC: 0.8404, Val ROC AUC: 0.8257
# Epoch [1/1], Step [224/936], Loss: 0.4951, Train ROC AUC: 0.8421, Val ROC AUC: 0.8380
# Epoch [1/1], Step [225/936], Loss: 0.5304, Train ROC AUC: 0.8018, Val ROC AUC: 0.8045
# Epoch [1/1], Step [226/936], Loss: 0.4309, Train ROC AUC: 0.9064, Val ROC AUC: 0.8096
# Epoch [1/1], Step [227/936], Loss: 0.5793, Train ROC AUC: 0.7627, Val ROC AUC: 0.8171
# Epoch [1/1], Step [228/936], Loss: 0.4528, Train ROC AUC: 0.8954, Val ROC AUC: 0.8539
# Epoch [1/1], Step [229/936], Loss: 0.4781, Train ROC AUC: 0.8623, Val ROC AUC: 0.7832
# Epoch [1/1], Step [230/936], Loss: 0.6385, Train ROC AUC: 0.7188, Val ROC AUC: 0.8194
# Epoch [1/1], Step [231/936], Loss: 0.4585, Train ROC AUC: 0.9215, Val ROC AUC: 0.7882
# Epoch [1/1], Step [232/936], Loss: 0.4965, Train ROC AUC: 0.8374, Val ROC AUC: 0.8280
# Epoch [1/1], Step [233/936], Loss: 0.5211, Train ROC AUC: 0.8388, Val ROC AUC: 0.8249
# Epoch [1/1], Step [234/936], Loss: 0.5259, Train ROC AUC: 0.8318, Val ROC AUC: 0.8668
# Epoch [1/1], Step [235/936], Loss: 0.4124, Train ROC AUC: 0.9209, Val ROC AUC: 0.8401
# Epoch [1/1], Step [236/936], Loss: 0.5415, Train ROC AUC: 0.7881, Val ROC AUC: 0.8362
# Epoch [1/1], Step [237/936], Loss: 0.4653, Train ROC AUC: 0.8750, Val ROC AUC: 0.8265
# Epoch [1/1], Step [238/936], Loss: 0.4762, Train ROC AUC: 0.8452, Val ROC AUC: 0.8255
# Epoch [1/1], Step [239/936], Loss: 0.5003, Train ROC AUC: 0.8533, Val ROC AUC: 0.8088
# Epoch [1/1], Step [240/936], Loss: 0.4577, Train ROC AUC: 0.8913, Val ROC AUC: 0.7904
# Epoch [1/1], Step [241/936], Loss: 0.5454, Train ROC AUC: 0.8075, Val ROC AUC: 0.7910
# Epoch [1/1], Step [242/936], Loss: 0.5377, Train ROC AUC: 0.8217, Val ROC AUC: 0.7876
# Epoch [1/1], Step [243/936], Loss: 0.5364, Train ROC AUC: 0.8039, Val ROC AUC: 0.8289
# Epoch [1/1], Step [244/936], Loss: 0.5729, Train ROC AUC: 0.7665, Val ROC AUC: 0.8251
# Epoch [1/1], Step [245/936], Loss: 0.6164, Train ROC AUC: 0.7165, Val ROC AUC: 0.8179
# Epoch [1/1], Step [246/936], Loss: 0.4362, Train ROC AUC: 0.8892, Val ROC AUC: 0.8189
# Epoch [1/1], Step [247/936], Loss: 0.5591, Train ROC AUC: 0.7752, Val ROC AUC: 0.8477
# Epoch [1/1], Step [248/936], Loss: 0.5253, Train ROC AUC: 0.8248, Val ROC AUC: 0.8660
# Epoch [1/1], Step [249/936], Loss: 0.4349, Train ROC AUC: 0.9218, Val ROC AUC: 0.8379
# Epoch [1/1], Step [250/936], Loss: 0.4362, Train ROC AUC: 0.8944, Val ROC AUC: 0.8319
# Epoch [1/1], Step [251/936], Loss: 0.5404, Train ROC AUC: 0.8261, Val ROC AUC: 0.8583
# Epoch [1/1], Step [252/936], Loss: 0.4999, Train ROC AUC: 0.8369, Val ROC AUC: 0.8301
# Epoch [1/1], Step [253/936], Loss: 0.4548, Train ROC AUC: 0.8847, Val ROC AUC: 0.8600
# Epoch [1/1], Step [254/936], Loss: 0.6016, Train ROC AUC: 0.7507, Val ROC AUC: 0.8505
# Epoch [1/1], Step [255/936], Loss: 0.6235, Train ROC AUC: 0.7402, Val ROC AUC: 0.8494
# Epoch [1/1], Step [256/936], Loss: 0.5609, Train ROC AUC: 0.7849, Val ROC AUC: 0.8420
# Epoch [1/1], Step [257/936], Loss: 0.4963, Train ROC AUC: 0.8402, Val ROC AUC: 0.8349
# Epoch [1/1], Step [258/936], Loss: 0.4159, Train ROC AUC: 0.8804, Val ROC AUC: 0.8313
# Epoch [1/1], Step [259/936], Loss: 0.5560, Train ROC AUC: 0.7676, Val ROC AUC: 0.8363
# Epoch [1/1], Step [260/936], Loss: 0.4911, Train ROC AUC: 0.8717, Val ROC AUC: 0.8225
# Epoch [1/1], Step [261/936], Loss: 0.4780, Train ROC AUC: 0.8549, Val ROC AUC: 0.8209
# Epoch [1/1], Step [262/936], Loss: 0.5161, Train ROC AUC: 0.8333, Val ROC AUC: 0.8135
# Epoch [1/1], Step [263/936], Loss: 0.4736, Train ROC AUC: 0.8651, Val ROC AUC: 0.8106
# Epoch [1/1], Step [264/936], Loss: 0.6111, Train ROC AUC: 0.7731, Val ROC AUC: 0.8327
# Epoch [1/1], Step [265/936], Loss: 0.5229, Train ROC AUC: 0.8407, Val ROC AUC: 0.8281
# Epoch [1/1], Step [266/936], Loss: 0.5081, Train ROC AUC: 0.8255, Val ROC AUC: 0.8028
# Epoch [1/1], Step [267/936], Loss: 0.5135, Train ROC AUC: 0.8145, Val ROC AUC: 0.8237
# Epoch [1/1], Step [268/936], Loss: 0.5914, Train ROC AUC: 0.7852, Val ROC AUC: 0.8070
# Epoch [1/1], Step [269/936], Loss: 0.5997, Train ROC AUC: 0.7507, Val ROC AUC: 0.8198
# Epoch [1/1], Step [270/936], Loss: 0.4006, Train ROC AUC: 0.9267, Val ROC AUC: 0.8282
# Epoch [1/1], Step [271/936], Loss: 0.4785, Train ROC AUC: 0.8699, Val ROC AUC: 0.8352
# Epoch [1/1], Step [272/936], Loss: 0.5291, Train ROC AUC: 0.8197, Val ROC AUC: 0.8484
# Epoch [1/1], Step [273/936], Loss: 0.4963, Train ROC AUC: 0.8348, Val ROC AUC: 0.8477
# Epoch [1/1], Step [274/936], Loss: 0.5215, Train ROC AUC: 0.8108, Val ROC AUC: 0.8337
# Epoch [1/1], Step [275/936], Loss: 0.4451, Train ROC AUC: 0.8817, Val ROC AUC: 0.8145
# Epoch [1/1], Step [276/936], Loss: 0.5278, Train ROC AUC: 0.8308, Val ROC AUC: 0.8147
# Epoch [1/1], Step [277/936], Loss: 0.4730, Train ROC AUC: 0.8727, Val ROC AUC: 0.8323
# Epoch [1/1], Step [278/936], Loss: 0.4876, Train ROC AUC: 0.8632, Val ROC AUC: 0.8129
# Epoch [1/1], Step [279/936], Loss: 0.4431, Train ROC AUC: 0.8978, Val ROC AUC: 0.8308
# Epoch [1/1], Step [280/936], Loss: 0.4848, Train ROC AUC: 0.8451, Val ROC AUC: 0.8207
# Epoch [1/1], Step [281/936], Loss: 0.4810, Train ROC AUC: 0.8740, Val ROC AUC: 0.8281
# Epoch [1/1], Step [282/936], Loss: 0.4606, Train ROC AUC: 0.8749, Val ROC AUC: 0.8360
# Epoch [1/1], Step [283/936], Loss: 0.5583, Train ROC AUC: 0.7784, Val ROC AUC: 0.8231
# Epoch [1/1], Step [284/936], Loss: 0.5603, Train ROC AUC: 0.7748, Val ROC AUC: 0.8038
# Epoch [1/1], Step [285/936], Loss: 0.5520, Train ROC AUC: 0.7956, Val ROC AUC: 0.8269
# Epoch [1/1], Step [286/936], Loss: 0.5186, Train ROC AUC: 0.8270, Val ROC AUC: 0.8316
# Epoch [1/1], Step [287/936], Loss: 0.5422, Train ROC AUC: 0.7859, Val ROC AUC: 0.8325
# Epoch [1/1], Step [288/936], Loss: 0.4359, Train ROC AUC: 0.9159, Val ROC AUC: 0.8263
# Epoch [1/1], Step [289/936], Loss: 0.5050, Train ROC AUC: 0.8418, Val ROC AUC: 0.8275
# Epoch [1/1], Step [290/936], Loss: 0.4095, Train ROC AUC: 0.9228, Val ROC AUC: 0.8122
# Epoch [1/1], Step [291/936], Loss: 0.5540, Train ROC AUC: 0.7808, Val ROC AUC: 0.8366
# Epoch [1/1], Step [292/936], Loss: 0.4671, Train ROC AUC: 0.9104, Val ROC AUC: 0.8071
# Epoch [1/1], Step [293/936], Loss: 0.4455, Train ROC AUC: 0.8848, Val ROC AUC: 0.8404
# Epoch [1/1], Step [294/936], Loss: 0.4889, Train ROC AUC: 0.8619, Val ROC AUC: 0.8209
# Epoch [1/1], Step [295/936], Loss: 0.4800, Train ROC AUC: 0.8345, Val ROC AUC: 0.8355
# Epoch [1/1], Step [296/936], Loss: 0.5340, Train ROC AUC: 0.7986, Val ROC AUC: 0.8507
# Epoch [1/1], Step [297/936], Loss: 0.5103, Train ROC AUC: 0.8282, Val ROC AUC: 0.8159
# Epoch [1/1], Step [298/936], Loss: 0.4662, Train ROC AUC: 0.8725, Val ROC AUC: 0.8183
# Epoch [1/1], Step [299/936], Loss: 0.4754, Train ROC AUC: 0.8690, Val ROC AUC: 0.8123
# Epoch [1/1], Step [300/936], Loss: 0.5321, Train ROC AUC: 0.8340, Val ROC AUC: 0.7928
# Epoch [1/1], Step [301/936], Loss: 0.5181, Train ROC AUC: 0.8167, Val ROC AUC: 0.8089
# Epoch [1/1], Step [302/936], Loss: 0.5552, Train ROC AUC: 0.7704, Val ROC AUC: 0.8531
# Epoch [1/1], Step [303/936], Loss: 0.4931, Train ROC AUC: 0.8500, Val ROC AUC: 0.8150
# Epoch [1/1], Step [304/936], Loss: 0.4776, Train ROC AUC: 0.8729, Val ROC AUC: 0.7817
# Epoch [1/1], Step [305/936], Loss: 0.5195, Train ROC AUC: 0.8118, Val ROC AUC: 0.8382
# Epoch [1/1], Step [306/936], Loss: 0.5613, Train ROC AUC: 0.7874, Val ROC AUC: 0.8499
# Epoch [1/1], Step [307/936], Loss: 0.4886, Train ROC AUC: 0.8441, Val ROC AUC: 0.8348
# Epoch [1/1], Step [308/936], Loss: 0.4910, Train ROC AUC: 0.8514, Val ROC AUC: 0.8196
# Epoch [1/1], Step [309/936], Loss: 0.4739, Train ROC AUC: 0.8397, Val ROC AUC: 0.8208
# Epoch [1/1], Step [310/936], Loss: 0.4633, Train ROC AUC: 0.8618, Val ROC AUC: 0.8176
# Epoch [1/1], Step [311/936], Loss: 0.4301, Train ROC AUC: 0.9025, Val ROC AUC: 0.7886
# Epoch [1/1], Step [312/936], Loss: 0.5290, Train ROC AUC: 0.7976, Val ROC AUC: 0.8037
# Epoch [1/1], Step [313/936], Loss: 0.4632, Train ROC AUC: 0.8719, Val ROC AUC: 0.7927
# Epoch [1/1], Step [314/936], Loss: 0.5509, Train ROC AUC: 0.7833, Val ROC AUC: 0.8158
# Epoch [1/1], Step [315/936], Loss: 0.5274, Train ROC AUC: 0.8204, Val ROC AUC: 0.8191
# Epoch [1/1], Step [316/936], Loss: 0.4917, Train ROC AUC: 0.8485, Val ROC AUC: 0.8523
# Epoch [1/1], Step [317/936], Loss: 0.5960, Train ROC AUC: 0.7817, Val ROC AUC: 0.8306
# Epoch [1/1], Step [318/936], Loss: 0.5805, Train ROC AUC: 0.7768, Val ROC AUC: 0.8679
# Epoch [1/1], Step [319/936], Loss: 0.6010, Train ROC AUC: 0.7718, Val ROC AUC: 0.8460
# Epoch [1/1], Step [320/936], Loss: 0.3575, Train ROC AUC: 0.9570, Val ROC AUC: 0.8180
# Epoch [1/1], Step [321/936], Loss: 0.6141, Train ROC AUC: 0.7508, Val ROC AUC: 0.8399
# Epoch [1/1], Step [322/936], Loss: 0.5020, Train ROC AUC: 0.8162, Val ROC AUC: 0.8111
# Epoch [1/1], Step [323/936], Loss: 0.4986, Train ROC AUC: 0.8396, Val ROC AUC: 0.8231
# Epoch [1/1], Step [324/936], Loss: 0.3845, Train ROC AUC: 0.9306, Val ROC AUC: 0.8409
# Epoch [1/1], Step [325/936], Loss: 0.5279, Train ROC AUC: 0.8018, Val ROC AUC: 0.8584
# Epoch [1/1], Step [326/936], Loss: 0.6430, Train ROC AUC: 0.6828, Val ROC AUC: 0.8485
# Epoch [1/1], Step [327/936], Loss: 0.5955, Train ROC AUC: 0.7400, Val ROC AUC: 0.8097
# Epoch [1/1], Step [328/936], Loss: 0.3855, Train ROC AUC: 0.9458, Val ROC AUC: 0.8500
# Epoch [1/1], Step [329/936], Loss: 0.4857, Train ROC AUC: 0.8542, Val ROC AUC: 0.8491
# Epoch [1/1], Step [330/936], Loss: 0.5466, Train ROC AUC: 0.7959, Val ROC AUC: 0.8350
# Epoch [1/1], Step [331/936], Loss: 0.4667, Train ROC AUC: 0.8700, Val ROC AUC: 0.8003
# Epoch [1/1], Step [332/936], Loss: 0.5374, Train ROC AUC: 0.8010, Val ROC AUC: 0.7939
# Epoch [1/1], Step [333/936], Loss: 0.4595, Train ROC AUC: 0.8340, Val ROC AUC: 0.8210
# Epoch [1/1], Step [334/936], Loss: 0.4242, Train ROC AUC: 0.8975, Val ROC AUC: 0.7649
# Epoch [1/1], Step [335/936], Loss: 0.4316, Train ROC AUC: 0.8892, Val ROC AUC: 0.7878
# Epoch [1/1], Step [336/936], Loss: 0.5669, Train ROC AUC: 0.7853, Val ROC AUC: 0.7923
# Epoch [1/1], Step [337/936], Loss: 0.4801, Train ROC AUC: 0.8446, Val ROC AUC: 0.8005
# Epoch [1/1], Step [338/936], Loss: 0.5489, Train ROC AUC: 0.7975, Val ROC AUC: 0.8009
# Epoch [1/1], Step [339/936], Loss: 0.6409, Train ROC AUC: 0.7126, Val ROC AUC: 0.7964
# Epoch [1/1], Step [340/936], Loss: 0.5310, Train ROC AUC: 0.8323, Val ROC AUC: 0.8104
# Epoch [1/1], Step [341/936], Loss: 0.4649, Train ROC AUC: 0.8669, Val ROC AUC: 0.8345
# Epoch [1/1], Step [342/936], Loss: 0.5090, Train ROC AUC: 0.8167, Val ROC AUC: 0.8263
# Epoch [1/1], Step [343/936], Loss: 0.5524, Train ROC AUC: 0.7922, Val ROC AUC: 0.8614
# Epoch [1/1], Step [344/936], Loss: 0.4921, Train ROC AUC: 0.8304, Val ROC AUC: 0.8391
# Epoch [1/1], Step [345/936], Loss: 0.6041, Train ROC AUC: 0.7879, Val ROC AUC: 0.8462
# Epoch [1/1], Step [346/936], Loss: 0.5972, Train ROC AUC: 0.7175, Val ROC AUC: 0.8595
# Epoch [1/1], Step [347/936], Loss: 0.4803, Train ROC AUC: 0.8271, Val ROC AUC: 0.8453
# Epoch [1/1], Step [348/936], Loss: 0.6149, Train ROC AUC: 0.7477, Val ROC AUC: 0.7804
# Epoch [1/1], Step [349/936], Loss: 0.5882, Train ROC AUC: 0.7576, Val ROC AUC: 0.8481
# Epoch [1/1], Step [350/936], Loss: 0.5308, Train ROC AUC: 0.8076, Val ROC AUC: 0.8188
# Epoch [1/1], Step [351/936], Loss: 0.5379, Train ROC AUC: 0.7996, Val ROC AUC: 0.8431
# Epoch [1/1], Step [352/936], Loss: 0.4949, Train ROC AUC: 0.8384, Val ROC AUC: 0.8162
# Epoch [1/1], Step [353/936], Loss: 0.4109, Train ROC AUC: 0.9451, Val ROC AUC: 0.8241
# Epoch [1/1], Step [354/936], Loss: 0.4851, Train ROC AUC: 0.8512, Val ROC AUC: 0.8335
# Epoch [1/1], Step [355/936], Loss: 0.5060, Train ROC AUC: 0.8304, Val ROC AUC: 0.8354
# Epoch [1/1], Step [356/936], Loss: 0.5360, Train ROC AUC: 0.7852, Val ROC AUC: 0.8577
# Epoch [1/1], Step [357/936], Loss: 0.5031, Train ROC AUC: 0.8467, Val ROC AUC: 0.8263
# Epoch [1/1], Step [358/936], Loss: 0.5004, Train ROC AUC: 0.8335, Val ROC AUC: 0.8055
# Epoch [1/1], Step [359/936], Loss: 0.4910, Train ROC AUC: 0.8690, Val ROC AUC: 0.8224
# Epoch [1/1], Step [360/936], Loss: 0.4564, Train ROC AUC: 0.8735, Val ROC AUC: 0.8166
# Epoch [1/1], Step [361/936], Loss: 0.4905, Train ROC AUC: 0.8384, Val ROC AUC: 0.8208
# Epoch [1/1], Step [362/936], Loss: 0.5322, Train ROC AUC: 0.8035, Val ROC AUC: 0.8203
# Epoch [1/1], Step [363/936], Loss: 0.5691, Train ROC AUC: 0.7824, Val ROC AUC: 0.8340
# Epoch [1/1], Step [364/936], Loss: 0.5849, Train ROC AUC: 0.7419, Val ROC AUC: 0.8498
# Epoch [1/1], Step [365/936], Loss: 0.4180, Train ROC AUC: 0.9222, Val ROC AUC: 0.8402
# Epoch [1/1], Step [366/936], Loss: 0.5038, Train ROC AUC: 0.8453, Val ROC AUC: 0.8274
# Epoch [1/1], Step [367/936], Loss: 0.4304, Train ROC AUC: 0.8979, Val ROC AUC: 0.8509
# Epoch [1/1], Step [368/936], Loss: 0.4401, Train ROC AUC: 0.8909, Val ROC AUC: 0.8113
# Epoch [1/1], Step [369/936], Loss: 0.5025, Train ROC AUC: 0.8201, Val ROC AUC: 0.8405
# Epoch [1/1], Step [370/936], Loss: 0.5935, Train ROC AUC: 0.7615, Val ROC AUC: 0.8573
# Epoch [1/1], Step [371/936], Loss: 0.5439, Train ROC AUC: 0.8008, Val ROC AUC: 0.8442
# Epoch [1/1], Step [372/936], Loss: 0.4977, Train ROC AUC: 0.8213, Val ROC AUC: 0.8346
# Epoch [1/1], Step [373/936], Loss: 0.5942, Train ROC AUC: 0.7686, Val ROC AUC: 0.7978
# Epoch [1/1], Step [374/936], Loss: 0.4409, Train ROC AUC: 0.8837, Val ROC AUC: 0.8471
# Epoch [1/1], Step [375/936], Loss: 0.6224, Train ROC AUC: 0.7069, Val ROC AUC: 0.8224
# Epoch [1/1], Step [376/936], Loss: 0.6144, Train ROC AUC: 0.7527, Val ROC AUC: 0.8424
# Epoch [1/1], Step [377/936], Loss: 0.4388, Train ROC AUC: 0.8887, Val ROC AUC: 0.8431
# Epoch [1/1], Step [378/936], Loss: 0.4715, Train ROC AUC: 0.8729, Val ROC AUC: 0.8077
# Epoch [1/1], Step [379/936], Loss: 0.4595, Train ROC AUC: 0.8788, Val ROC AUC: 0.8134
# Epoch [1/1], Step [380/936], Loss: 0.6007, Train ROC AUC: 0.7360, Val ROC AUC: 0.8100
# Epoch [1/1], Step [381/936], Loss: 0.4695, Train ROC AUC: 0.8745, Val ROC AUC: 0.8334
# Epoch [1/1], Step [382/936], Loss: 0.4360, Train ROC AUC: 0.8867, Val ROC AUC: 0.8410
# Epoch [1/1], Step [383/936], Loss: 0.4449, Train ROC AUC: 0.8798, Val ROC AUC: 0.8215
# Epoch [1/1], Step [384/936], Loss: 0.5200, Train ROC AUC: 0.8152, Val ROC AUC: 0.8555
# Epoch [1/1], Step [385/936], Loss: 0.5093, Train ROC AUC: 0.8235, Val ROC AUC: 0.8131
# Epoch [1/1], Step [386/936], Loss: 0.5337, Train ROC AUC: 0.8039, Val ROC AUC: 0.8518
# Epoch [1/1], Step [387/936], Loss: 0.5426, Train ROC AUC: 0.8056, Val ROC AUC: 0.8527
# Epoch [1/1], Step [388/936], Loss: 0.5449, Train ROC AUC: 0.7976, Val ROC AUC: 0.8473
# Epoch [1/1], Step [389/936], Loss: 0.4665, Train ROC AUC: 0.8661, Val ROC AUC: 0.8537
# Epoch [1/1], Step [390/936], Loss: 0.5428, Train ROC AUC: 0.8067, Val ROC AUC: 0.8260
# Epoch [1/1], Step [391/936], Loss: 0.3698, Train ROC AUC: 0.9375, Val ROC AUC: 0.8065
# Epoch [1/1], Step [392/936], Loss: 0.4850, Train ROC AUC: 0.8504, Val ROC AUC: 0.8220
# Epoch [1/1], Step [393/936], Loss: 0.4672, Train ROC AUC: 0.8667, Val ROC AUC: 0.8271
# Epoch [1/1], Step [394/936], Loss: 0.4484, Train ROC AUC: 0.8765, Val ROC AUC: 0.8486
# Epoch [1/1], Step [395/936], Loss: 0.5200, Train ROC AUC: 0.8118, Val ROC AUC: 0.8500
# Epoch [1/1], Step [396/936], Loss: 0.4596, Train ROC AUC: 0.8661, Val ROC AUC: 0.8098
# Epoch [1/1], Step [397/936], Loss: 0.5472, Train ROC AUC: 0.7813, Val ROC AUC: 0.8176
# Epoch [1/1], Step [398/936], Loss: 0.4256, Train ROC AUC: 0.8984, Val ROC AUC: 0.8126
# Epoch [1/1], Step [399/936], Loss: 0.5841, Train ROC AUC: 0.7468, Val ROC AUC: 0.7662
# Epoch [1/1], Step [400/936], Loss: 0.5604, Train ROC AUC: 0.7867, Val ROC AUC: 0.8038
# Epoch [1/1], Step [401/936], Loss: 0.4026, Train ROC AUC: 0.9108, Val ROC AUC: 0.8031
# Epoch [1/1], Step [402/936], Loss: 0.5435, Train ROC AUC: 0.8063, Val ROC AUC: 0.8061
# Epoch [1/1], Step [403/936], Loss: 0.5497, Train ROC AUC: 0.7744, Val ROC AUC: 0.8097
# Epoch [1/1], Step [404/936], Loss: 0.4937, Train ROC AUC: 0.8398, Val ROC AUC: 0.8417
# Epoch [1/1], Step [405/936], Loss: 0.4987, Train ROC AUC: 0.8345, Val ROC AUC: 0.7865
# Epoch [1/1], Step [406/936], Loss: 0.5400, Train ROC AUC: 0.7752, Val ROC AUC: 0.8079
# Epoch [1/1], Step [407/936], Loss: 0.5068, Train ROC AUC: 0.8274, Val ROC AUC: 0.8125
# Epoch [1/1], Step [408/936], Loss: 0.4393, Train ROC AUC: 0.8856, Val ROC AUC: 0.8433
# Epoch [1/1], Step [409/936], Loss: 0.4714, Train ROC AUC: 0.8529, Val ROC AUC: 0.8138
# Epoch [1/1], Step [410/936], Loss: 0.5136, Train ROC AUC: 0.8393, Val ROC AUC: 0.7919
# Epoch [1/1], Step [411/936], Loss: 0.6240, Train ROC AUC: 0.7129, Val ROC AUC: 0.7501
# Epoch [1/1], Step [412/936], Loss: 0.5299, Train ROC AUC: 0.8049, Val ROC AUC: 0.7011
# Epoch [1/1], Step [413/936], Loss: 0.5740, Train ROC AUC: 0.7723, Val ROC AUC: 0.7122
# Epoch [1/1], Step [414/936], Loss: 0.5206, Train ROC AUC: 0.8240, Val ROC AUC: 0.7565
# Epoch [1/1], Step [415/936], Loss: 0.4614, Train ROC AUC: 0.8697, Val ROC AUC: 0.8039
# Epoch [1/1], Step [416/936], Loss: 0.4692, Train ROC AUC: 0.8679, Val ROC AUC: 0.8136
# Epoch [1/1], Step [417/936], Loss: 0.4855, Train ROC AUC: 0.8506, Val ROC AUC: 0.8478
# Epoch [1/1], Step [418/936], Loss: 0.5043, Train ROC AUC: 0.8223, Val ROC AUC: 0.8545
# Epoch [1/1], Step [419/936], Loss: 0.4444, Train ROC AUC: 0.8925, Val ROC AUC: 0.8145
# Epoch [1/1], Step [420/936], Loss: 0.5376, Train ROC AUC: 0.8078, Val ROC AUC: 0.8449
# Epoch [1/1], Step [421/936], Loss: 0.4942, Train ROC AUC: 0.8719, Val ROC AUC: 0.8764
# Epoch [1/1], Step [422/936], Loss: 0.4850, Train ROC AUC: 0.8544, Val ROC AUC: 0.8618
# Epoch [1/1], Step [423/936], Loss: 0.4814, Train ROC AUC: 0.8671, Val ROC AUC: 0.8366
# Epoch [1/1], Step [424/936], Loss: 0.4892, Train ROC AUC: 0.8384, Val ROC AUC: 0.8380
# Epoch [1/1], Step [425/936], Loss: 0.4584, Train ROC AUC: 0.8671, Val ROC AUC: 0.8410
# Epoch [1/1], Step [426/936], Loss: 0.5140, Train ROC AUC: 0.8354, Val ROC AUC: 0.8379
# Epoch [1/1], Step [427/936], Loss: 0.4901, Train ROC AUC: 0.8621, Val ROC AUC: 0.8335
# Epoch [1/1], Step [428/936], Loss: 0.5361, Train ROC AUC: 0.8287, Val ROC AUC: 0.8320
# Epoch [1/1], Step [429/936], Loss: 0.4109, Train ROC AUC: 0.9010, Val ROC AUC: 0.8389
# Epoch [1/1], Step [430/936], Loss: 0.4160, Train ROC AUC: 0.9127, Val ROC AUC: 0.8586
# Epoch [1/1], Step [431/936], Loss: 0.4192, Train ROC AUC: 0.9053, Val ROC AUC: 0.8387
# Epoch [1/1], Step [432/936], Loss: 0.5382, Train ROC AUC: 0.8195, Val ROC AUC: 0.8398
# Epoch [1/1], Step [433/936], Loss: 0.5487, Train ROC AUC: 0.7990, Val ROC AUC: 0.8282
# Epoch [1/1], Step [434/936], Loss: 0.4655, Train ROC AUC: 0.8618, Val ROC AUC: 0.8608
# Epoch [1/1], Step [435/936], Loss: 0.4264, Train ROC AUC: 0.9010, Val ROC AUC: 0.7981
# Epoch [1/1], Step [436/936], Loss: 0.5629, Train ROC AUC: 0.8010, Val ROC AUC: 0.7973
# Epoch [1/1], Step [437/936], Loss: 0.5557, Train ROC AUC: 0.7976, Val ROC AUC: 0.7883
# Epoch [1/1], Step [438/936], Loss: 0.5063, Train ROC AUC: 0.8406, Val ROC AUC: 0.8066
# Epoch [1/1], Step [439/936], Loss: 0.4127, Train ROC AUC: 0.9088, Val ROC AUC: 0.8523
# Epoch [1/1], Step [440/936], Loss: 0.4876, Train ROC AUC: 0.8543, Val ROC AUC: 0.8294
# Epoch [1/1], Step [441/936], Loss: 0.4867, Train ROC AUC: 0.8490, Val ROC AUC: 0.8287
# Epoch [1/1], Step [442/936], Loss: 0.4845, Train ROC AUC: 0.8414, Val ROC AUC: 0.8411
# Epoch [1/1], Step [443/936], Loss: 0.5323, Train ROC AUC: 0.8115, Val ROC AUC: 0.8471
# Epoch [1/1], Step [444/936], Loss: 0.4433, Train ROC AUC: 0.8808, Val ROC AUC: 0.8207
# Epoch [1/1], Step [445/936], Loss: 0.4016, Train ROC AUC: 0.9081, Val ROC AUC: 0.8412
# Epoch [1/1], Step [446/936], Loss: 0.5013, Train ROC AUC: 0.8485, Val ROC AUC: 0.8128
# Epoch [1/1], Step [447/936], Loss: 0.5938, Train ROC AUC: 0.7615, Val ROC AUC: 0.8336
# Epoch [1/1], Step [448/936], Loss: 0.4645, Train ROC AUC: 0.8543, Val ROC AUC: 0.8570
# Epoch [1/1], Step [449/936], Loss: 0.4605, Train ROC AUC: 0.8711, Val ROC AUC: 0.8509
# Epoch [1/1], Step [450/936], Loss: 0.4738, Train ROC AUC: 0.8424, Val ROC AUC: 0.8507
# Epoch [1/1], Step [451/936], Loss: 0.4971, Train ROC AUC: 0.8240, Val ROC AUC: 0.8602
# Epoch [1/1], Step [452/936], Loss: 0.4785, Train ROC AUC: 0.8771, Val ROC AUC: 0.8394
# Epoch [1/1], Step [453/936], Loss: 0.3899, Train ROC AUC: 0.9241, Val ROC AUC: 0.8439
# Epoch [1/1], Step [454/936], Loss: 0.4474, Train ROC AUC: 0.8623, Val ROC AUC: 0.8521
# Epoch [1/1], Step [455/936], Loss: 0.5303, Train ROC AUC: 0.7961, Val ROC AUC: 0.8436
# Epoch [1/1], Step [456/936], Loss: 0.4426, Train ROC AUC: 0.8725, Val ROC AUC: 0.8277
# Epoch [1/1], Step [457/936], Loss: 0.4518, Train ROC AUC: 0.8735, Val ROC AUC: 0.8358
# Epoch [1/1], Step [458/936], Loss: 0.4779, Train ROC AUC: 0.8520, Val ROC AUC: 0.8241
# Epoch [1/1], Step [459/936], Loss: 0.5149, Train ROC AUC: 0.8147, Val ROC AUC: 0.8579
# Epoch [1/1], Step [460/936], Loss: 0.4334, Train ROC AUC: 0.8676, Val ROC AUC: 0.8147
# Epoch [1/1], Step [461/936], Loss: 0.5268, Train ROC AUC: 0.8006, Val ROC AUC: 0.8418
# Epoch [1/1], Step [462/936], Loss: 0.6255, Train ROC AUC: 0.7281, Val ROC AUC: 0.8585
# Epoch [1/1], Step [463/936], Loss: 0.6519, Train ROC AUC: 0.7389, Val ROC AUC: 0.8597
# Epoch [1/1], Step [464/936], Loss: 0.4809, Train ROC AUC: 0.8562, Val ROC AUC: 0.8212
# Epoch [1/1], Step [465/936], Loss: 0.5771, Train ROC AUC: 0.7626, Val ROC AUC: 0.8347
# Epoch [1/1], Step [466/936], Loss: 0.6078, Train ROC AUC: 0.7450, Val ROC AUC: 0.8607
# Epoch [1/1], Step [467/936], Loss: 0.4686, Train ROC AUC: 0.8498, Val ROC AUC: 0.7875
# Epoch [1/1], Step [468/936], Loss: 0.4630, Train ROC AUC: 0.8769, Val ROC AUC: 0.8161
# Epoch [1/1], Step [469/936], Loss: 0.4973, Train ROC AUC: 0.8305, Val ROC AUC: 0.8542
# Epoch [1/1], Step [470/936], Loss: 0.4538, Train ROC AUC: 0.8725, Val ROC AUC: 0.8438
# Epoch [1/1], Step [471/936], Loss: 0.4687, Train ROC AUC: 0.8627, Val ROC AUC: 0.8667
# Epoch [1/1], Step [472/936], Loss: 0.4223, Train ROC AUC: 0.8866, Val ROC AUC: 0.8128
# Epoch [1/1], Step [473/936], Loss: 0.4695, Train ROC AUC: 0.8578, Val ROC AUC: 0.8073
# Epoch [1/1], Step [474/936], Loss: 0.4984, Train ROC AUC: 0.8478, Val ROC AUC: 0.8145
# Epoch [1/1], Step [475/936], Loss: 0.5348, Train ROC AUC: 0.8401, Val ROC AUC: 0.8631
# Epoch [1/1], Step [476/936], Loss: 0.6551, Train ROC AUC: 0.7153, Val ROC AUC: 0.8430
# Epoch [1/1], Step [477/936], Loss: 0.6445, Train ROC AUC: 0.7361, Val ROC AUC: 0.8613
# Epoch [1/1], Step [478/936], Loss: 0.6315, Train ROC AUC: 0.7399, Val ROC AUC: 0.7943
# Epoch [1/1], Step [479/936], Loss: 0.5095, Train ROC AUC: 0.8382, Val ROC AUC: 0.8345
# Epoch [1/1], Step [480/936], Loss: 0.5746, Train ROC AUC: 0.7812, Val ROC AUC: 0.8471
# Epoch [1/1], Step [481/936], Loss: 0.5463, Train ROC AUC: 0.8052, Val ROC AUC: 0.8332
# Epoch [1/1], Step [482/936], Loss: 0.4360, Train ROC AUC: 0.8958, Val ROC AUC: 0.8347
# Epoch [1/1], Step [483/936], Loss: 0.4473, Train ROC AUC: 0.8794, Val ROC AUC: 0.8365
# Epoch [1/1], Step [484/936], Loss: 0.3647, Train ROC AUC: 0.9384, Val ROC AUC: 0.8194
# Epoch [1/1], Step [485/936], Loss: 0.5025, Train ROC AUC: 0.8373, Val ROC AUC: 0.8347
# Epoch [1/1], Step [486/936], Loss: 0.4820, Train ROC AUC: 0.8416, Val ROC AUC: 0.8339
# Epoch [1/1], Step [487/936], Loss: 0.6201, Train ROC AUC: 0.7390, Val ROC AUC: 0.8166
# Epoch [1/1], Step [488/936], Loss: 0.5863, Train ROC AUC: 0.7637, Val ROC AUC: 0.8295
# Epoch [1/1], Step [489/936], Loss: 0.4916, Train ROC AUC: 0.8471, Val ROC AUC: 0.8241
# Epoch [1/1], Step [490/936], Loss: 0.4517, Train ROC AUC: 0.8730, Val ROC AUC: 0.7907
# Epoch [1/1], Step [491/936], Loss: 0.5822, Train ROC AUC: 0.7350, Val ROC AUC: 0.8348
# Epoch [1/1], Step [492/936], Loss: 0.4710, Train ROC AUC: 0.8493, Val ROC AUC: 0.8333
# Epoch [1/1], Step [493/936], Loss: 0.6023, Train ROC AUC: 0.7706, Val ROC AUC: 0.8191
# Epoch [1/1], Step [494/936], Loss: 0.5261, Train ROC AUC: 0.8318, Val ROC AUC: 0.8405
# Epoch [1/1], Step [495/936], Loss: 0.6366, Train ROC AUC: 0.7126, Val ROC AUC: 0.8474
# Epoch [1/1], Step [496/936], Loss: 0.5265, Train ROC AUC: 0.8045, Val ROC AUC: 0.8319
# Epoch [1/1], Step [497/936], Loss: 0.6065, Train ROC AUC: 0.7461, Val ROC AUC: 0.8168
# Epoch [1/1], Step [498/936], Loss: 0.5035, Train ROC AUC: 0.8345, Val ROC AUC: 0.8738
# Epoch [1/1], Step [499/936], Loss: 0.5258, Train ROC AUC: 0.8177, Val ROC AUC: 0.8310
# Epoch [1/1], Step [500/936], Loss: 0.4851, Train ROC AUC: 0.8579, Val ROC AUC: 0.8369
# Epoch [1/1], Step [501/936], Loss: 0.5306, Train ROC AUC: 0.8211, Val ROC AUC: 0.8150
# Epoch [1/1], Step [502/936], Loss: 0.4448, Train ROC AUC: 0.8859, Val ROC AUC: 0.8361
# Epoch [1/1], Step [503/936], Loss: 0.5929, Train ROC AUC: 0.7601, Val ROC AUC: 0.8519
# Epoch [1/1], Step [504/936], Loss: 0.4602, Train ROC AUC: 0.8816, Val ROC AUC: 0.7980
# Epoch [1/1], Step [505/936], Loss: 0.4929, Train ROC AUC: 0.8441, Val ROC AUC: 0.8344
# Epoch [1/1], Step [506/936], Loss: 0.6063, Train ROC AUC: 0.7698, Val ROC AUC: 0.7760
# Epoch [1/1], Step [507/936], Loss: 0.5587, Train ROC AUC: 0.7986, Val ROC AUC: 0.7980
# Epoch [1/1], Step [508/936], Loss: 0.4934, Train ROC AUC: 0.8562, Val ROC AUC: 0.7613
# Epoch [1/1], Step [509/936], Loss: 0.4709, Train ROC AUC: 0.8532, Val ROC AUC: 0.7480
# Epoch [1/1], Step [510/936], Loss: 0.4691, Train ROC AUC: 0.8604, Val ROC AUC: 0.8190
# Epoch [1/1], Step [511/936], Loss: 0.4270, Train ROC AUC: 0.8985, Val ROC AUC: 0.7979
# Epoch [1/1], Step [512/936], Loss: 0.4580, Train ROC AUC: 0.8698, Val ROC AUC: 0.8074
# Epoch [1/1], Step [513/936], Loss: 0.5347, Train ROC AUC: 0.8127, Val ROC AUC: 0.8360
# Epoch [1/1], Step [514/936], Loss: 0.4670, Train ROC AUC: 0.8573, Val ROC AUC: 0.8140
# Epoch [1/1], Step [515/936], Loss: 0.5163, Train ROC AUC: 0.8201, Val ROC AUC: 0.8450
# Epoch [1/1], Step [516/936], Loss: 0.5545, Train ROC AUC: 0.7875, Val ROC AUC: 0.8552
# Epoch [1/1], Step [517/936], Loss: 0.4507, Train ROC AUC: 0.8784, Val ROC AUC: 0.8108
# Epoch [1/1], Step [518/936], Loss: 0.5627, Train ROC AUC: 0.7979, Val ROC AUC: 0.8432
# Epoch [1/1], Step [519/936], Loss: 0.4575, Train ROC AUC: 0.8760, Val ROC AUC: 0.8254
# Epoch [1/1], Step [520/936], Loss: 0.3776, Train ROC AUC: 0.9248, Val ROC AUC: 0.8284
# Epoch [1/1], Step [521/936], Loss: 0.5221, Train ROC AUC: 0.8206, Val ROC AUC: 0.8446
# Epoch [1/1], Step [522/936], Loss: 0.5554, Train ROC AUC: 0.7820, Val ROC AUC: 0.8330
# Epoch [1/1], Step [523/936], Loss: 0.5492, Train ROC AUC: 0.8383, Val ROC AUC: 0.8521
# Epoch [1/1], Step [524/936], Loss: 0.4210, Train ROC AUC: 0.9025, Val ROC AUC: 0.8141
# Epoch [1/1], Step [525/936], Loss: 0.4747, Train ROC AUC: 0.8578, Val ROC AUC: 0.8662
# Epoch [1/1], Step [526/936], Loss: 0.5994, Train ROC AUC: 0.7357, Val ROC AUC: 0.8252
# Epoch [1/1], Step [527/936], Loss: 0.4895, Train ROC AUC: 0.8483, Val ROC AUC: 0.8506
# Epoch [1/1], Step [528/936], Loss: 0.4372, Train ROC AUC: 0.8814, Val ROC AUC: 0.8417
# Epoch [1/1], Step [529/936], Loss: 0.5096, Train ROC AUC: 0.8363, Val ROC AUC: 0.8293
# Epoch [1/1], Step [530/936], Loss: 0.5703, Train ROC AUC: 0.7791, Val ROC AUC: 0.8296
# Epoch [1/1], Step [531/936], Loss: 0.5590, Train ROC AUC: 0.7748, Val ROC AUC: 0.8454
# Epoch [1/1], Step [532/936], Loss: 0.6078, Train ROC AUC: 0.7389, Val ROC AUC: 0.8612
# Epoch [1/1], Step [533/936], Loss: 0.4980, Train ROC AUC: 0.8431, Val ROC AUC: 0.8377
# Epoch [1/1], Step [534/936], Loss: 0.5134, Train ROC AUC: 0.8089, Val ROC AUC: 0.8418
# Epoch [1/1], Step [535/936], Loss: 0.5478, Train ROC AUC: 0.7853, Val ROC AUC: 0.8515
# Epoch [1/1], Step [536/936], Loss: 0.5459, Train ROC AUC: 0.7824, Val ROC AUC: 0.8318
# Epoch [1/1], Step [537/936], Loss: 0.4985, Train ROC AUC: 0.8192, Val ROC AUC: 0.8433
# Epoch [1/1], Step [538/936], Loss: 0.4702, Train ROC AUC: 0.8799, Val ROC AUC: 0.8339
# Epoch [1/1], Step [539/936], Loss: 0.4641, Train ROC AUC: 0.8661, Val ROC AUC: 0.8475
# Epoch [1/1], Step [540/936], Loss: 0.4973, Train ROC AUC: 0.8623, Val ROC AUC: 0.8737
# Epoch [1/1], Step [541/936], Loss: 0.5184, Train ROC AUC: 0.8277, Val ROC AUC: 0.8477
# Epoch [1/1], Step [542/936], Loss: 0.4346, Train ROC AUC: 0.8849, Val ROC AUC: 0.8515
# Epoch [1/1], Step [543/936], Loss: 0.4852, Train ROC AUC: 0.8473, Val ROC AUC: 0.8337
# Epoch [1/1], Step [544/936], Loss: 0.3708, Train ROC AUC: 0.9238, Val ROC AUC: 0.8485
# Epoch [1/1], Step [545/936], Loss: 0.5862, Train ROC AUC: 0.7783, Val ROC AUC: 0.8433
# Epoch [1/1], Step [546/936], Loss: 0.5667, Train ROC AUC: 0.7598, Val ROC AUC: 0.8433
# Epoch [1/1], Step [547/936], Loss: 0.4625, Train ROC AUC: 0.8680, Val ROC AUC: 0.8567
# Epoch [1/1], Step [548/936], Loss: 0.4647, Train ROC AUC: 0.8534, Val ROC AUC: 0.8261
# Epoch [1/1], Step [549/936], Loss: 0.4761, Train ROC AUC: 0.8520, Val ROC AUC: 0.8469
# Epoch [1/1], Step [550/936], Loss: 0.4693, Train ROC AUC: 0.8524, Val ROC AUC: 0.8243
# Epoch [1/1], Step [551/936], Loss: 0.3625, Train ROC AUC: 0.9333, Val ROC AUC: 0.8232
# Epoch [1/1], Step [552/936], Loss: 0.5451, Train ROC AUC: 0.8177, Val ROC AUC: 0.8235
# Epoch [1/1], Step [553/936], Loss: 0.6235, Train ROC AUC: 0.7344, Val ROC AUC: 0.8087
# Epoch [1/1], Step [554/936], Loss: 0.5268, Train ROC AUC: 0.8248, Val ROC AUC: 0.7620
# Epoch [1/1], Step [555/936], Loss: 0.5541, Train ROC AUC: 0.7849, Val ROC AUC: 0.7797
# Epoch [1/1], Step [556/936], Loss: 0.6482, Train ROC AUC: 0.7133, Val ROC AUC: 0.7646
# Epoch [1/1], Step [557/936], Loss: 0.6240, Train ROC AUC: 0.7833, Val ROC AUC: 0.7957
# Epoch [1/1], Step [558/936], Loss: 0.4329, Train ROC AUC: 0.9028, Val ROC AUC: 0.8385
# Epoch [1/1], Step [559/936], Loss: 0.4216, Train ROC AUC: 0.9241, Val ROC AUC: 0.8543
# ...
# Epoch [1/1], Step [751/936], Loss: 0.5154, Train ROC AUC: 0.7937, Val ROC AUC: 0.7776
# Epoch [1/1], Step [752/936], Loss: 0.4226, Train ROC AUC: 0.8915, Val ROC AUC: 0.7562
# Epoch [1/1], Step [753/936], Loss: 0.4342, Train ROC AUC: 0.8859, Val ROC AUC: 0.7818
# Epoch [1/1], Step [754/936], Loss: 0.4779, Train ROC AUC: 0.8539, Val ROC AUC: 0.7296
# Epoch [1/1], Step [755/936], Loss: 0.5736, Train ROC AUC: 0.7958, Val ROC AUC: 0.7107
# Epoch [1/1], Step [756/936], Loss: 0.4593, Train ROC AUC: 0.8618, Val ROC AUC: 0.7448
# Epoch [1/1], Step [757/936], Loss: 0.5797, Train ROC AUC: 0.7842, Val ROC AUC: 0.7918
# Epoch [1/1], Step [758/936], Loss: 0.5357, Train ROC AUC: 0.7967, Val ROC AUC: 0.8114
# Epoch [1/1], Step [759/936], Loss: 0.5550, Train ROC AUC: 0.7908, Val ROC AUC: 0.7985
# Epoch [1/1], Step [760/936], Loss: 0.4942, Train ROC AUC: 0.8403, Val ROC AUC: 0.8338
# Epoch [1/1], Step [761/936], Loss: 0.4879, Train ROC AUC: 0.8833, Val ROC AUC: 0.8317
# Epoch [1/1], Step [762/936], Loss: 0.4229, Train ROC AUC: 0.8682, Val ROC AUC: 0.8177
# Epoch [1/1], Step [763/936], Loss: 0.4828, Train ROC AUC: 0.8284, Val ROC AUC: 0.8553
# Epoch [1/1], Step [764/936], Loss: 0.4413, Train ROC AUC: 0.8768, Val ROC AUC: 0.8165
# Epoch [1/1], Step [765/936], Loss: 0.4935, Train ROC AUC: 0.8524, Val ROC AUC: 0.8156
# Epoch [1/1], Step [766/936], Loss: 0.4649, Train ROC AUC: 0.8740, Val ROC AUC: 0.8438
# Epoch [1/1], Step [767/936], Loss: 0.4875, Train ROC AUC: 0.8564, Val ROC AUC: 0.8267
# Epoch [1/1], Step [768/936], Loss: 0.3889, Train ROC AUC: 0.9176, Val ROC AUC: 0.8442
# Epoch [1/1], Step [769/936], Loss: 0.6306, Train ROC AUC: 0.7675, Val ROC AUC: 0.8519
# Epoch [1/1], Step [770/936], Loss: 0.4640, Train ROC AUC: 0.8569, Val ROC AUC: 0.8051
# Epoch [1/1], Step [771/936], Loss: 0.5440, Train ROC AUC: 0.7937, Val ROC AUC: 0.8328
# Epoch [1/1], Step [772/936], Loss: 0.5685, Train ROC AUC: 0.7784, Val ROC AUC: 0.8292
# Epoch [1/1], Step [773/936], Loss: 0.5045, Train ROC AUC: 0.8087, Val ROC AUC: 0.8306
# Epoch [1/1], Step [774/936], Loss: 0.4917, Train ROC AUC: 0.8368, Val ROC AUC: 0.8302
# Epoch [1/1], Step [775/936], Loss: 0.5254, Train ROC AUC: 0.8137, Val ROC AUC: 0.8176
# Epoch [1/1], Step [776/936], Loss: 0.5061, Train ROC AUC: 0.8260, Val ROC AUC: 0.8649
# Epoch [1/1], Step [777/936], Loss: 0.5106, Train ROC AUC: 0.8492, Val ROC AUC: 0.8374
# Epoch [1/1], Step [778/936], Loss: 0.5272, Train ROC AUC: 0.8046, Val ROC AUC: 0.8469
# Epoch [1/1], Step [779/936], Loss: 0.4605, Train ROC AUC: 0.8552, Val ROC AUC: 0.8114
# Epoch [1/1], Step [780/936], Loss: 0.4409, Train ROC AUC: 0.8790, Val ROC AUC: 0.8375
# Epoch [1/1], Step [781/936], Loss: 0.5852, Train ROC AUC: 0.7718, Val ROC AUC: 0.8311
# Epoch [1/1], Step [782/936], Loss: 0.5074, Train ROC AUC: 0.8294, Val ROC AUC: 0.8471
# Epoch [1/1], Step [783/936], Loss: 0.5875, Train ROC AUC: 0.7517, Val ROC AUC: 0.8422
# Epoch [1/1], Step [784/936], Loss: 0.5816, Train ROC AUC: 0.7632, Val ROC AUC: 0.8523
# Epoch [1/1], Step [785/936], Loss: 0.5144, Train ROC AUC: 0.8305, Val ROC AUC: 0.8451
# Epoch [1/1], Step [786/936], Loss: 0.4159, Train ROC AUC: 0.8824, Val ROC AUC: 0.8703
# Epoch [1/1], Step [787/936], Loss: 0.4779, Train ROC AUC: 0.8477, Val ROC AUC: 0.8447
# Epoch [1/1], Step [788/936], Loss: 0.5997, Train ROC AUC: 0.7488, Val ROC AUC: 0.8626
# Epoch [1/1], Step [789/936], Loss: 0.4459, Train ROC AUC: 0.8690, Val ROC AUC: 0.8195
# Epoch [1/1], Step [790/936], Loss: 0.4491, Train ROC AUC: 0.8998, Val ROC AUC: 0.8419
# Epoch [1/1], Step [791/936], Loss: 0.5778, Train ROC AUC: 0.7817, Val ROC AUC: 0.8239
# Epoch [1/1], Step [792/936], Loss: 0.5061, Train ROC AUC: 0.8158, Val ROC AUC: 0.8235
# Epoch [1/1], Step [793/936], Loss: 0.4162, Train ROC AUC: 0.8959, Val ROC AUC: 0.7869
# Epoch [1/1], Step [794/936], Loss: 0.5001, Train ROC AUC: 0.8478, Val ROC AUC: 0.7989
# Epoch [1/1], Step [795/936], Loss: 0.5080, Train ROC AUC: 0.8685, Val ROC AUC: 0.8220
# Epoch [1/1], Step [796/936], Loss: 0.4725, Train ROC AUC: 0.8359, Val ROC AUC: 0.8271
# Epoch [1/1], Step [797/936], Loss: 0.5400, Train ROC AUC: 0.8227, Val ROC AUC: 0.8367
# Epoch [1/1], Step [798/936], Loss: 0.4577, Train ROC AUC: 0.8633, Val ROC AUC: 0.8190
# Epoch [1/1], Step [799/936], Loss: 0.4543, Train ROC AUC: 0.8704, Val ROC AUC: 0.8424
# Epoch [1/1], Step [800/936], Loss: 0.4787, Train ROC AUC: 0.8543, Val ROC AUC: 0.8445
# Epoch [1/1], Step [801/936], Loss: 0.4514, Train ROC AUC: 0.8680, Val ROC AUC: 0.8349
# Epoch [1/1], Step [802/936], Loss: 0.5036, Train ROC AUC: 0.8374, Val ROC AUC: 0.8171
# Epoch [1/1], Step [803/936], Loss: 0.4360, Train ROC AUC: 0.8877, Val ROC AUC: 0.8494
# Epoch [1/1], Step [804/936], Loss: 0.4976, Train ROC AUC: 0.8315, Val ROC AUC: 0.8365
# Epoch [1/1], Step [805/936], Loss: 0.4704, Train ROC AUC: 0.8330, Val ROC AUC: 0.8522
# Epoch [1/1], Step [806/936], Loss: 0.4804, Train ROC AUC: 0.8639, Val ROC AUC: 0.8395
# Epoch [1/1], Step [807/936], Loss: 0.4171, Train ROC AUC: 0.8965, Val ROC AUC: 0.8337
# Epoch [1/1], Step [808/936], Loss: 0.5261, Train ROC AUC: 0.8113, Val ROC AUC: 0.8462
# Epoch [1/1], Step [809/936], Loss: 0.6300, Train ROC AUC: 0.7327, Val ROC AUC: 0.8391
# Epoch [1/1], Step [810/936], Loss: 0.5354, Train ROC AUC: 0.8187, Val ROC AUC: 0.8542
# Epoch [1/1], Step [811/936], Loss: 0.5585, Train ROC AUC: 0.8063, Val ROC AUC: 0.8064
# Epoch [1/1], Step [812/936], Loss: 0.5177, Train ROC AUC: 0.8096, Val ROC AUC: 0.8467
# Epoch [1/1], Step [813/936], Loss: 0.5612, Train ROC AUC: 0.8026, Val ROC AUC: 0.8483
# Epoch [1/1], Step [814/936], Loss: 0.4886, Train ROC AUC: 0.8456, Val ROC AUC: 0.8840
# Epoch [1/1], Step [815/936], Loss: 0.4657, Train ROC AUC: 0.8490, Val ROC AUC: 0.8173
# Epoch [1/1], Step [816/936], Loss: 0.4849, Train ROC AUC: 0.8485, Val ROC AUC: 0.8448
# Epoch [1/1], Step [817/936], Loss: 0.3983, Train ROC AUC: 0.9163, Val ROC AUC: 0.8250
# Epoch [1/1], Step [818/936], Loss: 0.4929, Train ROC AUC: 0.8443, Val ROC AUC: 0.8666
# Epoch [1/1], Step [819/936], Loss: 0.4876, Train ROC AUC: 0.8543, Val ROC AUC: 0.8459
# Epoch [1/1], Step [820/936], Loss: 0.3973, Train ROC AUC: 0.9182, Val ROC AUC: 0.8389
# Epoch [1/1], Step [821/936], Loss: 0.4383, Train ROC AUC: 0.8895, Val ROC AUC: 0.8494
# Epoch [1/1], Step [822/936], Loss: 0.4694, Train ROC AUC: 0.8601, Val ROC AUC: 0.8418
# Epoch [1/1], Step [823/936], Loss: 0.4967, Train ROC AUC: 0.8365, Val ROC AUC: 0.8293
# Epoch [1/1], Step [824/936], Loss: 0.4771, Train ROC AUC: 0.8569, Val ROC AUC: 0.8347
# Epoch [1/1], Step [825/936], Loss: 0.4607, Train ROC AUC: 0.8641, Val ROC AUC: 0.8322
# Epoch [1/1], Step [826/936], Loss: 0.3773, Train ROC AUC: 0.9117, Val ROC AUC: 0.8370
# Epoch [1/1], Step [827/936], Loss: 0.5390, Train ROC AUC: 0.8104, Val ROC AUC: 0.8490
# Epoch [1/1], Step [828/936], Loss: 0.4028, Train ROC AUC: 0.9010, Val ROC AUC: 0.8243
# Epoch [1/1], Step [829/936], Loss: 0.5322, Train ROC AUC: 0.7961, Val ROC AUC: 0.8244
# Epoch [1/1], Step [830/936], Loss: 0.4946, Train ROC AUC: 0.8018, Val ROC AUC: 0.8137
# Epoch [1/1], Step [831/936], Loss: 0.4327, Train ROC AUC: 0.8889, Val ROC AUC: 0.8495
# Epoch [1/1], Step [832/936], Loss: 0.4174, Train ROC AUC: 0.9059, Val ROC AUC: 0.8213
# Epoch [1/1], Step [833/936], Loss: 0.4985, Train ROC AUC: 0.8488, Val ROC AUC: 0.8412
# Epoch [1/1], Step [834/936], Loss: 0.5345, Train ROC AUC: 0.8158, Val ROC AUC: 0.8267
# Epoch [1/1], Step [835/936], Loss: 0.5413, Train ROC AUC: 0.8066, Val ROC AUC: 0.8322
# Epoch [1/1], Step [836/936], Loss: 0.5561, Train ROC AUC: 0.7745, Val ROC AUC: 0.8372
# Epoch [1/1], Step [837/936], Loss: 0.5360, Train ROC AUC: 0.7996, Val ROC AUC: 0.8721
# Epoch [1/1], Step [838/936], Loss: 0.5152, Train ROC AUC: 0.8318, Val ROC AUC: 0.8418
# Epoch [1/1], Step [839/936], Loss: 0.4434, Train ROC AUC: 0.8839, Val ROC AUC: 0.8454
# Epoch [1/1], Step [840/936], Loss: 0.4975, Train ROC AUC: 0.8291, Val ROC AUC: 0.8330
# Epoch [1/1], Step [841/936], Loss: 0.3719, Train ROC AUC: 0.9271, Val ROC AUC: 0.8296
# Epoch [1/1], Step [842/936], Loss: 0.4365, Train ROC AUC: 0.8879, Val ROC AUC: 0.8464
# Epoch [1/1], Step [843/936], Loss: 0.4604, Train ROC AUC: 0.8559, Val ROC AUC: 0.8609
# Epoch [1/1], Step [844/936], Loss: 0.5273, Train ROC AUC: 0.8152, Val ROC AUC: 0.8207
# Epoch [1/1], Step [845/936], Loss: 0.3923, Train ROC AUC: 0.9245, Val ROC AUC: 0.8233
# Epoch [1/1], Step [846/936], Loss: 0.4652, Train ROC AUC: 0.8389, Val ROC AUC: 0.8265
# Epoch [1/1], Step [847/936], Loss: 0.5219, Train ROC AUC: 0.8097, Val ROC AUC: 0.8710
# Epoch [1/1], Step [848/936], Loss: 0.3986, Train ROC AUC: 0.9049, Val ROC AUC: 0.8519
# Epoch [1/1], Step [849/936], Loss: 0.4837, Train ROC AUC: 0.8495, Val ROC AUC: 0.8441
# Epoch [1/1], Step [850/936], Loss: 0.4868, Train ROC AUC: 0.8428, Val ROC AUC: 0.8319
# Epoch [1/1], Step [851/936], Loss: 0.5719, Train ROC AUC: 0.7706, Val ROC AUC: 0.8634
# Epoch [1/1], Step [852/936], Loss: 0.4012, Train ROC AUC: 0.9042, Val ROC AUC: 0.8292
# Epoch [1/1], Step [853/936], Loss: 0.4823, Train ROC AUC: 0.8549, Val ROC AUC: 0.7989
# Epoch [1/1], Step [854/936], Loss: 0.4142, Train ROC AUC: 0.9000, Val ROC AUC: 0.8552
# Epoch [1/1], Step [855/936], Loss: 0.4606, Train ROC AUC: 0.8601, Val ROC AUC: 0.8552
# Epoch [1/1], Step [856/936], Loss: 0.4044, Train ROC AUC: 0.9169, Val ROC AUC: 0.8243
# Epoch [1/1], Step [857/936], Loss: 0.5118, Train ROC AUC: 0.8288, Val ROC AUC: 0.8215
# Epoch [1/1], Step [858/936], Loss: 0.4639, Train ROC AUC: 0.8704, Val ROC AUC: 0.8223
# Epoch [1/1], Step [859/936], Loss: 0.4418, Train ROC AUC: 0.8944, Val ROC AUC: 0.8388
# Epoch [1/1], Step [860/936], Loss: 0.4277, Train ROC AUC: 0.8827, Val ROC AUC: 0.8257
# Epoch [1/1], Step [861/936], Loss: 0.4177, Train ROC AUC: 0.9010, Val ROC AUC: 0.8208
# Epoch [1/1], Step [862/936], Loss: 0.4888, Train ROC AUC: 0.8359, Val ROC AUC: 0.8305
# Epoch [1/1], Step [863/936], Loss: 0.5542, Train ROC AUC: 0.7742, Val ROC AUC: 0.8332
# Epoch [1/1], Step [864/936], Loss: 0.4374, Train ROC AUC: 0.9077, Val ROC AUC: 0.8668
# Epoch [1/1], Step [865/936], Loss: 0.4506, Train ROC AUC: 0.8799, Val ROC AUC: 0.8614
# Epoch [1/1], Step [866/936], Loss: 0.4606, Train ROC AUC: 0.8622, Val ROC AUC: 0.8414
# Epoch [1/1], Step [867/936], Loss: 0.5364, Train ROC AUC: 0.8196, Val ROC AUC: 0.8623
# Epoch [1/1], Step [868/936], Loss: 0.4236, Train ROC AUC: 0.8945, Val ROC AUC: 0.8565
# Epoch [1/1], Step [869/936], Loss: 0.5906, Train ROC AUC: 0.7441, Val ROC AUC: 0.8639
# Epoch [1/1], Step [870/936], Loss: 0.5522, Train ROC AUC: 0.8135, Val ROC AUC: 0.8376
# Epoch [1/1], Step [871/936], Loss: 0.4294, Train ROC AUC: 0.8781, Val ROC AUC: 0.8396
# Epoch [1/1], Step [872/936], Loss: 0.4563, Train ROC AUC: 0.8866, Val ROC AUC: 0.8253
# Epoch [1/1], Step [873/936], Loss: 0.5586, Train ROC AUC: 0.8154, Val ROC AUC: 0.8535
# Epoch [1/1], Step [874/936], Loss: 0.5358, Train ROC AUC: 0.8206, Val ROC AUC: 0.8319
# Epoch [1/1], Step [875/936], Loss: 0.4227, Train ROC AUC: 0.8867, Val ROC AUC: 0.8534
# Epoch [1/1], Step [876/936], Loss: 0.4515, Train ROC AUC: 0.8847, Val ROC AUC: 0.8144
# Epoch [1/1], Step [877/936], Loss: 0.4750, Train ROC AUC: 0.8601, Val ROC AUC: 0.8371
# Epoch [1/1], Step [878/936], Loss: 0.4135, Train ROC AUC: 0.8827, Val ROC AUC: 0.7976
# Epoch [1/1], Step [879/936], Loss: 0.4840, Train ROC AUC: 0.8719, Val ROC AUC: 0.8212
# Epoch [1/1], Step [880/936], Loss: 0.5474, Train ROC AUC: 0.8046, Val ROC AUC: 0.8062
# Epoch [1/1], Step [881/936], Loss: 0.5314, Train ROC AUC: 0.8135, Val ROC AUC: 0.7693
# Epoch [1/1], Step [882/936], Loss: 0.4425, Train ROC AUC: 0.8849, Val ROC AUC: 0.8156
# Epoch [1/1], Step [883/936], Loss: 0.4542, Train ROC AUC: 0.8438, Val ROC AUC: 0.8273
# Epoch [1/1], Step [884/936], Loss: 0.4508, Train ROC AUC: 0.8778, Val ROC AUC: 0.8130
# Epoch [1/1], Step [885/936], Loss: 0.4951, Train ROC AUC: 0.8384, Val ROC AUC: 0.7900
# Epoch [1/1], Step [886/936], Loss: 0.4282, Train ROC AUC: 0.8775, Val ROC AUC: 0.8021
# Epoch [1/1], Step [887/936], Loss: 0.4348, Train ROC AUC: 0.8729, Val ROC AUC: 0.8099
# Epoch [1/1], Step [888/936], Loss: 0.3700, Train ROC AUC: 0.9238, Val ROC AUC: 0.8550
# Epoch [1/1], Step [889/936], Loss: 0.5262, Train ROC AUC: 0.8186, Val ROC AUC: 0.8070
# Epoch [1/1], Step [890/936], Loss: 0.4784, Train ROC AUC: 0.8383, Val ROC AUC: 0.8351
# Epoch [1/1], Step [891/936], Loss: 0.4879, Train ROC AUC: 0.8443, Val ROC AUC: 0.8134
# Epoch [1/1], Step [892/936], Loss: 0.4212, Train ROC AUC: 0.8948, Val ROC AUC: 0.8061
# Epoch [1/1], Step [893/936], Loss: 0.3788, Train ROC AUC: 0.9169, Val ROC AUC: 0.7411
# Epoch [1/1], Step [894/936], Loss: 0.4417, Train ROC AUC: 0.8584, Val ROC AUC: 0.8000
# Epoch [1/1], Step [895/936], Loss: 0.6522, Train ROC AUC: 0.7281, Val ROC AUC: 0.7884
# Epoch [1/1], Step [896/936], Loss: 0.5107, Train ROC AUC: 0.8224, Val ROC AUC: 0.8359
# Epoch [1/1], Step [897/936], Loss: 0.4802, Train ROC AUC: 0.8453, Val ROC AUC: 0.8652
# Epoch [1/1], Step [898/936], Loss: 0.3020, Train ROC AUC: 0.9647, Val ROC AUC: 0.8521
# Epoch [1/1], Step [899/936], Loss: 0.4340, Train ROC AUC: 0.8729, Val ROC AUC: 0.8515
# Epoch [1/1], Step [900/936], Loss: 0.4709, Train ROC AUC: 0.8601, Val ROC AUC: 0.8655
# Epoch [1/1], Step [901/936], Loss: 0.4854, Train ROC AUC: 0.8448, Val ROC AUC: 0.8251
# Epoch [1/1], Step [902/936], Loss: 0.5920, Train ROC AUC: 0.7578, Val ROC AUC: 0.8465
# Epoch [1/1], Step [903/936], Loss: 0.3717, Train ROC AUC: 0.9225, Val ROC AUC: 0.8474
# Epoch [1/1], Step [904/936], Loss: 0.4964, Train ROC AUC: 0.8506, Val ROC AUC: 0.8494
# Epoch [1/1], Step [905/936], Loss: 0.4772, Train ROC AUC: 0.8477, Val ROC AUC: 0.8410
# Epoch [1/1], Step [906/936], Loss: 0.4285, Train ROC AUC: 0.8944, Val ROC AUC: 0.8257
# Epoch [1/1], Step [907/936], Loss: 0.4554, Train ROC AUC: 0.8651, Val ROC AUC: 0.8564
# Epoch [1/1], Step [908/936], Loss: 0.5063, Train ROC AUC: 0.8382, Val ROC AUC: 0.8581
# Epoch [1/1], Step [909/936], Loss: 0.5388, Train ROC AUC: 0.8133, Val ROC AUC: 0.8389
# Epoch [1/1], Step [910/936], Loss: 0.6056, Train ROC AUC: 0.7588, Val ROC AUC: 0.8514
# Epoch [1/1], Step [911/936], Loss: 0.3740, Train ROC AUC: 0.9405, Val ROC AUC: 0.8460
# Epoch [1/1], Step [912/936], Loss: 0.5455, Train ROC AUC: 0.8219, Val ROC AUC: 0.8679
# Epoch [1/1], Step [913/936], Loss: 0.5318, Train ROC AUC: 0.8085, Val ROC AUC: 0.8653
# Epoch [1/1], Step [914/936], Loss: 0.4248, Train ROC AUC: 0.8895, Val ROC AUC: 0.8412
# Epoch [1/1], Step [915/936], Loss: 0.5152, Train ROC AUC: 0.8568, Val ROC AUC: 0.8545
# Epoch [1/1], Step [916/936], Loss: 0.4729, Train ROC AUC: 0.8659, Val ROC AUC: 0.8321
# Epoch [1/1], Step [917/936], Loss: 0.4509, Train ROC AUC: 0.9162, Val ROC AUC: 0.8229
# Epoch [1/1], Step [918/936], Loss: 0.3740, Train ROC AUC: 0.9238, Val ROC AUC: 0.8602
# Epoch [1/1], Step [919/936], Loss: 0.4414, Train ROC AUC: 0.8759, Val ROC AUC: 0.8474
# Epoch [1/1], Step [920/936], Loss: 0.5671, Train ROC AUC: 0.7840, Val ROC AUC: 0.8410
# Epoch [1/1], Step [921/936], Loss: 0.4334, Train ROC AUC: 0.8709, Val ROC AUC: 0.8700
# Epoch [1/1], Step [922/936], Loss: 0.4597, Train ROC AUC: 0.8571, Val ROC AUC: 0.8497
# Epoch [1/1], Step [923/936], Loss: 0.3854, Train ROC AUC: 0.9062, Val ROC AUC: 0.8603
# Epoch [1/1], Step [924/936], Loss: 0.5051, Train ROC AUC: 0.8348, Val ROC AUC: 0.8188
# Epoch [1/1], Step [925/936], Loss: 0.4722, Train ROC AUC: 0.8524, Val ROC AUC: 0.8239
# Epoch [1/1], Step [926/936], Loss: 0.5099, Train ROC AUC: 0.8313, Val ROC AUC: 0.8280
# Epoch [1/1], Step [927/936], Loss: 0.5404, Train ROC AUC: 0.8104, Val ROC AUC: 0.8037
# Epoch [1/1], Step [928/936], Loss: 0.4011, Train ROC AUC: 0.9023, Val ROC AUC: 0.8246
# Epoch [1/1], Step [929/936], Loss: 0.5338, Train ROC AUC: 0.8147, Val ROC AUC: 0.8330
# Epoch [1/1], Step [930/936], Loss: 0.6116, Train ROC AUC: 0.7618, Val ROC AUC: 0.8476
# Epoch [1/1], Step [931/936], Loss: 0.5275, Train ROC AUC: 0.8133, Val ROC AUC: 0.8726
# Epoch [1/1], Step [932/936], Loss: 0.4534, Train ROC AUC: 0.8485, Val ROC AUC: 0.8162
# Epoch [1/1], Step [933/936], Loss: 0.4566, Train ROC AUC: 0.8769, Val ROC AUC: 0.8157
# Epoch [1/1], Step [934/936], Loss: 0.6182, Train ROC AUC: 0.7490, Val ROC AUC: 0.8411
# Epoch [1/1], Step [935/936], Loss: 0.3944, Train ROC AUC: 0.9108, Val ROC AUC: 0.8174
# Epoch [1/1], Step [936/936], Loss: 0.4724, Train ROC AUC: 0.8657, Val ROC AUC: 0.8335

# %%
plt.figure(figsize=(9,6))
plt.plot(losses,label='Train loss')
#plt.ylim([.4, .8])
plt.legend()
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.plot(val_roc,label='Validation accuracy')
plt.legend()
plt.show()

# %%
valid_predictions = []
valid_targets = []

valid_dataset = Dataset(val_df, path)                                             
valid_loader = torch.utils.data.DataLoader(dataset=valid_dataset, 
                                           batch_size=50, 
                                           shuffle=False) 

model.eval() # prep model for evaluation
with torch.no_grad():
    for i, (images, labels) in enumerate(valid_loader):
        images = images.to(device)

        labels = torch.reshape(labels, [len(labels), 1])
        labels = labels.to(device)

        # Forward pass
        outputs = model(images)
        valid_predictions += list(outputs.detach().cpu().numpy().ravel())
        valid_targets += list(labels.cpu().numpy().ravel()) 

fpr, tpr, _ = roc_curve(np.array(valid_targets, np.int), np.array(valid_predictions).ravel())
roc_auc = auc(fpr, tpr)

percent_tp = sum(valid_targets)/len(valid_targets) * 100 
baseline = np.max([percent_tp, 100-percent_tp])
acc = np.sum(np.round(valid_predictions) == np.array(valid_targets)) / len(valid_targets)

print('\nBaseline classification accuracy: {:.2f}'.format(baseline))
print('\nModel classification accuracy:    {:.2f}'.format(acc))

plt.style.use('seaborn-colorblind')
plt.rcParams.update({'font.size': 16, 
                     'legend.framealpha':1, 
                     'legend.edgecolor':'inherit'}) 
plt.figure(figsize=(9, 6))

lw = 2
plt.plot(fpr, tpr, 
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")

plt.tight_layout()
plt.show()
# Out:
# Baseline classification accuracy: 90.08
#
# Model classification accuracy:    0.89

# %%
confusion_matrix(np.array(valid_targets, np.int), np.round(np.array(valid_predictions).ravel()))
# Out:
# array([[527,  18],
#        [ 48,  12]])

# %%
# Save  the entire model.
train_df.to_csv("train_df.csv", index=False)
val_df.to_csv("val_df.csv", index=False)

torch.save(model.state_dict(), '../Models/model.ckpt')
