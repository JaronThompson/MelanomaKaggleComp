# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 

import torch 
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.optim.lr_scheduler import ReduceLROnPlateau

from PIL import Image
from skimage.transform import resize
from sklearn.metrics import confusion_matrix, roc_curve, auc
from efficientnet_pytorch import EfficientNet

from sklearn.utils.class_weight import compute_class_weight

from tqdm import tqdm

# %%
# Device configuration (GPU can be enabled in settings)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
#device = 'cpu'
print(device)
# Out:
# cuda:0

# %%
# upload train dataframe
train_df_allsamples = pd.read_csv("../../data-256/train.csv")
train_df_allsamples.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_2637011  IP_7279968    male        45.0                     head/neck
# 1  ISIC_0015719  IP_3075186  female        45.0               upper extremity
# 2  ISIC_0052212  IP_2842074  female        50.0               lower extremity
# 3  ISIC_0068279  IP_6890425  female        45.0                     head/neck
# 4  ISIC_0074268  IP_8723313  female        55.0               upper extremity
#
#   diagnosis benign_malignant  target  tfrecord  width  height
# 0   unknown           benign       0         0   6000    4000
# 1   unknown           benign       0         0   6000    4000
# 2     nevus           benign       0         6   1872    1053
# 3   unknown           benign       0         0   1872    1053
# 4   unknown           benign       0        11   6000    4000

# %% [markdown]
# # TFRecord describes stratified k-fold to keep counts of patient replicates evenly distributed within each fold
#
# Some patients have as many as 115 images - to keep validation more representative of a real testing scenario, training and validation should not share images from the same patient. Furthermore, the number of replicates from each patient should be similar in each fold. The tfrecord column in the data table provides a k-fold partitioning scheme that keeps replicates even distributed in each fold.

# %%
unique_patient_ids, patient_counts = np.unique(train_df_allsamples['patient_id'].values, return_counts=True)
patient_to_count = {p_id:count for p_id, count in zip(unique_patient_ids, patient_counts)}

tfrecords = train_df_allsamples['tfrecord'].values 
folds = np.arange(15)

plt.style.use('seaborn-colorblind')
plt.rcParams.update({'font.size': 16,
                     'legend.framealpha':.5,
                     'legend.edgecolor':'k',
                     'axes.edgecolor':'k'})
plt.figure(figsize=(5*5, 6*3))
k = 1 
for f in folds:
    fold_df = train_df_allsamples.iloc[tfrecords == folds[f], :]

    fold_patient_ids = fold_df['patient_id'].values 
    fold_patient_counts = [patient_to_count[p] for p in fold_patient_ids]
    fold_target = fold_df['target'].values
    fold_p_target = 100 * sum(fold_target) / len(fold_target)

    plt.subplot(5, 3, k)
    k += 1
    plt.hist(fold_patient_counts)
    plt.xlabel("Patient replicate counts")
    plt.ylabel("In-fold instances")
    plt.title("Percent of pos. target = {:.2f}".format(fold_p_target))
    
plt.tight_layout()
plt.show()

# %%
meta_features = ['sex', 'age_approx', 'anatom_site_general_challenge'] 

encoder = {}
for feature in meta_features: 
    # determine unique features  
    categories = np.unique(np.array(train_df_allsamples[feature].values, str))
    for i, category in enumerate(categories): 
        if category != 'nan':
            encoder[category] = np.float(i)
encoder['nan'] = np.nan

# define a unique transform each time a positive is resampled: 

# basic transform 
transform_1 = transforms.Compose([
    transforms.RandomRotation(degrees=5),
    transforms.ColorJitter(brightness=32. / 255.,saturation=0.5),
    #transforms.RandomResizedCrop(size=256, scale=(0.5, 1.0), ratio=(0.8, 1.2)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])])

# horizontal or vertical flip 
transform_2 = transforms.Compose([
    transforms.RandomRotation(degrees=5),
    transforms.ColorJitter(brightness=32. / 255.,saturation=0.5),
    transforms.RandomResizedCrop(size=256, scale=(0.5, 1.0), ratio=(0.8, 1.2)),
    #transforms.RandomVerticalFlip(),
    transforms.RandomHorizontalFlip(1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])])

# no flip or rotation for test/validation data 
transform_valid = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])])

def make_weights_for_balanced_classes(df, nclasses=2):   
    targets = df["target"].values
    count = [0] * nclasses                                                      
    for label in targets:                                                         
        count[label] += 1                                                     
    weight_per_class = [0.] * nclasses                                      
    N = float(sum(count))                                                   
    for i in range(nclasses):                                                   
        weight_per_class[i] = N/float(count[i])                                 
    weight = [0] * len(targets)                                              
    for idx, label in enumerate(targets):                                          
        weight[idx] = weight_per_class[label]   
        
    return np.array(weight)  

class TrainDataset(torch.utils.data.Dataset):
    def __init__(self, df, path_to_files):
        # 1. Initialize file paths or a list of file names.
        self.path = path_to_files
        self.df = df

    def __getitem__(self, index):
        # 1. Read one data from file (e.g. using numpy.fromfile, PIL.Image.open).
        
        # load X 
        img_name = self.df['image_name'].values[index]
        img_path = self.path + img_name + ".jpg"
        img = plt.imread(img_path) 
        
        # determine meta data 
        meta = self.df[meta_features].values[index]
        meta_data = np.array([encoder[str(m)] for m in meta])
        
        # load y 
        label = self.df["target"].values[index]
        label_encode = np.zeros(2)
        label_encode[label] = 1
        target = torch.tensor(label, dtype=torch.float32)
        
        # 2. Preprocess the data (e.g. torchvision.Transform).
        img = Image.fromarray(img)
        #img = img.resize((256, 256))
        img_processed = transform_1(img)
        # 3. Return a data pair (e.g. image and label).
        return img_processed, target
        
    def __len__(self):
        # total size of your dataset.
        return self.df.shape[0]

class ValidDataset(torch.utils.data.Dataset):
    def __init__(self, df, path_to_files):
        # 1. Initialize file paths or a list of file names.
        self.path = path_to_files
        self.df = df

    def __getitem__(self, index):
        # 1. Read one data from file (e.g. using numpy.fromfile, PIL.Image.open).
        
        # load X 
        img_name = self.df['image_name'].values[index]
        img_path = self.path + img_name + ".jpg"
        img = plt.imread(img_path) 
        
        # determine meta data 
        meta = self.df[meta_features].values[index]
        meta_data = np.array([encoder[str(m)] for m in meta])
        
        # load y 
        label = self.df["target"].values[index]
        label_encode = np.zeros(2)
        label_encode[label] = 1
        target = torch.tensor(label, dtype=torch.float32)
        
        # 2. Preprocess the data (e.g. torchvision.Transform).
        img = Image.fromarray(img)
        #img = img.resize((256, 256))
        img_processed = transform_valid(img)
        # 3. Return a data pair (e.g. image and label).
        return img_processed, target
        
    def __len__(self):
        # total size of your dataset.
        return self.df.shape[0]

def augment_batch(images, labels):
    # create empty array of augmented images and labels
    
    # for img, label in zip(images, labels):
    
        # if label == 1
    
            # img_aug = transform(img) 
            # append set of augmented images and labels 
            
    # append images / labels with augmented images labels 
    # shuffle 
    # return 
    return 0

# %%
images = images.detach().cpu()
labels = labels.detach().cpu()

# %%
# horizontal or vertical flip 
transform_2 = transforms.Compose([
    transforms.ToPILImage(), 
    transforms.RandomRotation(degrees=5),
    transforms.ColorJitter(brightness=32. / 255.,saturation=0.5),
    transforms.RandomResizedCrop(size=256, scale=(0.5, 1.0), ratio=(0.8, 1.2)),
    #transforms.RandomVerticalFlip(),
    transforms.RandomHorizontalFlip(1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])])

# %%
transform_2(images[])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-2b6b1f926aec> in <module>()
# ----> 1 transform_2(images)
#
# ~/anaconda3/lib/python3.5/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      59     def __call__(self, img):
#      60         for t in self.transforms:
# ---> 61             img = t(img)
#      62         return img
#      63
#
# ~/anaconda3/lib/python3.5/site-packages/torchvision/transforms/transforms.py in __call__(self, pic)
#     125
#     126         """
# --> 127         return F.to_pil_image(pic, self.mode)
#     128
#     129     def __repr__(self):
#
# ~/anaconda3/lib/python3.5/site-packages/torchvision/transforms/functional.py in to_pil_image(pic, mode)
#     102     elif isinstance(pic, torch.Tensor):
#     103         if pic.ndimension() not in {2, 3}:
# --> 104             raise ValueError('pic should be 2/3 dimensional. Got {} dimensions.'.format(pic.ndimension()))
#     105
#     106         elif pic.ndimension() == 2:
#
# ValueError: pic should be 2/3 dimensional. Got 4 dimensions.

# %%
# First, load the EfficientNet with pre-trained parameters 
# ENet = EfficientNet.from_pretrained('efficientnet-b0').to(device)

# Convolutional neural network
class MyENet(nn.Module):
    def __init__(self, ENet):
        super(MyENet, self).__init__()
        # modify output layer of the pre-trained ENet 
        self.ENet = ENet
        num_ftrs = self.ENet._fc.in_features
        self.ENet._fc = nn.Linear(in_features=num_ftrs, out_features=512)
        # map Enet output to melanoma decision 
        self.output = nn.Sequential(nn.BatchNorm1d(512),
                                    nn.LeakyReLU(),
                                    nn.Dropout(p=0.2),
                                    nn.Linear(512, 1),
                                    nn.Sigmoid())
        
    def embedding(self, x):
        out = self.ENet(x)
        return out 
        
    def forward(self, x):
        out = self.ENet(x)
        out = self.output(out)
        return out

# %%
# 2 convolutional layers + 2 fully connected layers 
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=8, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(8),
            nn.LeakyReLU(),  
            nn.Dropout(p=0.2),
            nn.MaxPool2d(kernel_size=4, stride=4))
        self.layer2 = nn.Sequential(
            nn.Conv2d(8, 16, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(),
            nn.Dropout(p=0.2),
            nn.MaxPool2d(kernel_size=4, stride=4)) 
        self.fc = nn.Sequential(
            nn.Linear(4096, 64),
            nn.LeakyReLU(),
            nn.Dropout(p=0.2))
        self.output = nn.Sequential(
            nn.Linear(64, 1),
            nn.Sigmoid())
        
    def embedding(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = out.reshape(out.size(0), -1)
        out = self.fc(out)
        return out 
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = out.reshape(out.size(0), -1)
        out = self.fc(out)
        out = self.output(out)
        return out

# %%
# Train the model
# Use the prebuilt data loader.
path = "../../data-256/train/"
path_to_model = '../Models/model.ckpt'

# define batch size and accumulation steps 
num_epochs = 20
batchsize  = 280
accumulation_steps = 1 # ~ sort of like making an effective batchsize = acc.steps * batchsize ? 
evaluation_steps = 5
set_patience = 5 
best_val     = 0
verbose = True

# define custom scheduler 
def update_lr(epoch, batch_size=28):
    lr_start   = 0.001
    lr_max     = 0.000125 * batch_size
    lr_min     = 0.0001
    lr_ramp_ep = 5
    lr_sus_ep  = 0
    lr_decay   = 0.8
   
    if epoch < lr_ramp_ep:
        lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start

    elif epoch < lr_ramp_ep + lr_sus_ep:
        lr = lr_max

    else:
        lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min

    for g in optimizer.param_groups:
        g['lr'] = lr
        
# define custom loss 
def weighted_binary_cross_entropy(output, target, weights):
            
    loss = weights[1] * torch.mm(target.t(), torch.log(output)) + \
            weights[0] * torch.mm((1 - target).t(), torch.log(1 - output))

    return torch.neg(loss)[0][0]/len(output)
        
# loop through every k-fold 
for f in [0]: # folds 
    # initialize new model for each fold 
    # model = MyENet(ENet).to(device)
    model = ConvNet().to(device)
    
    # define lr and optimizer 
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    criterion = torch.nn.BCELoss()
    
    # scheduler reduces learning rate by factor of 10 when val auc does not improve
    scheduler = ReduceLROnPlateau(optimizer=optimizer, min_lr=3e-6, mode='max', patience=0, verbose=True)
    
    # pull the training and validation data for each fold
    inds = tfrecords == f
    train_df = train_df_allsamples.iloc[~inds, :].sample(frac=1)
    val_df = train_df_allsamples.iloc[inds, :].sample(frac=1)

    # evaluate performance on validation data 
    train_dataset = TrainDataset(train_df, path)                                              
    train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batchsize) 
    
    # evaluate performance on validation data 
    valid_dataset = TrainDataset(val_df, path)                                              
    valid_loader = torch.utils.data.DataLoader(dataset=valid_dataset, batch_size=batchsize) 

    # calculate weights for weighted loss function 
    class_weights = compute_class_weight(y=train_df['target'].values, class_weight='balanced', classes=np.unique(train_df['target'].values))
    class_weights = torch.FloatTensor(class_weights).to(device)
    
    # save validation statistics 
    val_roc = []
    val_acc = []
    val_precision = []
    val_recall = []
    
    # Reset gradients
    for epoch in range(num_epochs):
        
        # set up model for training     
        model.train()
        for i, (images, labels) in enumerate(train_loader):

            # send images and labels to gpu or cpu RAM 
            images = images.to(device)
            labels = torch.reshape(labels, [len(labels), 1])
            labels = labels.to(device)

            # Forward pass
            outputs = model(images)   
            
            # calculate performance 
            train_targets = np.array(labels.cpu().numpy(), np.int)
            train_predictions = outputs.detach().cpu().numpy().ravel()
            fpr, tpr, _ = roc_curve(train_targets, train_predictions)
            roc = auc(fpr, tpr)

            if sum(train_targets)[0] > 0:
                tn, fp, fn, tp = confusion_matrix(train_targets, np.round(train_predictions)).ravel()
                acc = (tp + tn) / len(train_targets)
                if (tp + fp) > 0:
                    precision = tp / (tp + fp)
                else:
                    precision = 0
                if (tp + fn) > 0:
                    recall = tp / (tp + fn)
                else:
                    recall = 0
            else:
                precision = 0
                recall = 0
            
            '''
            if recall > 0:
                
            else:
                # penalize low recall 
                loss = weighted_binary_cross_entropy(outputs, labels, class_weights) 
            '''
            loss = criterion(outputs, labels)
            
            loss = loss / accumulation_steps                # Normalize loss (if averaged)
            loss.backward()                                 # Backward pass
            if (i+1) % accumulation_steps == 0:             # Wait for several backward steps
                optimizer.step()                            # Now we can do an optimizer step
                model.zero_grad()                           # Reset gradients tensors
                
            if verbose and (i+1) % evaluation_steps == 0:
                # Print performance on minibatch train data 
                print ('\nFold [{}/{}], Epoch [{}/{}], Step [{}/{}], ROC AUC: {:.3f}, Acc: {:.3f}, Precision: {:.3f}, Recall {:.3f}\n'
                   .format(f+1, len(folds), epoch+1, num_epochs, i+1, len(train_loader), roc, acc, precision, recall))
                
        
        # Evaluate validation data at end of each epoch
        valid_predictions = []
        valid_targets = []
        model.eval() 
        with torch.no_grad():
            for j, (images, labels) in enumerate(valid_loader):
                images = images.to(device)

                labels = torch.reshape(labels, [len(labels), 1])
                labels = labels.to(device)

                # Forward pass
                outputs = model(images)

                # Calculate val ROC
                valid_predictions += list(outputs.detach().cpu().numpy())
                valid_targets += list(labels.cpu().numpy())

        # Calculate performance statistics on validation data 
        fpr, tpr, _ = roc_curve(np.array(valid_targets, np.int), np.array(valid_predictions).ravel())
        val_roc_epoch = auc(fpr, tpr)
        val_roc.append(val_roc_epoch)

        tn, fp, fn, tp = confusion_matrix(np.array(valid_targets, np.int), np.round(np.array(valid_predictions).ravel())).ravel()
        val_acc_epoch = (tp + tn) / len(valid_targets)
        if (tp + fp) > 0:
            val_precision_epoch = tp / (tp + fp)
        else:
            val_precision_epoch = 0
        if (tp + fn) > 0:
            val_recall_epoch = tp / (tp + fn)
        else:
            val_recall_epoch = 0

        val_acc.append(val_acc_epoch)
        val_precision.append(val_precision_epoch)
        val_recall.append(val_recall_epoch)

        print ('\nFold [{}/{}], Epoch [{}/{}], Val ROC AUC: {:.3f}, Val Acc: {:.3f}, Val Precision: {:.3f}, Val Recall {:.3f}\n'
               .format(f+1, len(folds), epoch+1, num_epochs, val_roc_epoch, val_acc_epoch, val_precision_epoch, val_recall_epoch))

        # learning rate is reduced if val roc doesn't improve 
        scheduler.step(val_roc_epoch)
        
        if val_roc_epoch > best_val:
            best_val = val_roc_epoch
            patience = set_patience        
            torch.save(model.state_dict(), path_to_model)  
        else:
            patience -= 1
            if patience == 0:
                print('Early stopping. Best validation roc_auc: {:.3f}'.format(best_val))
                model.load_state_dict(torch.load(path_to_model), strict=False)
                break

    # Load best model from fold 
    model.load_state_dict(torch.load(path_to_model))
# Out:
# Fold [1/15], Epoch [1/20], Step [5/111], ROC AUC: 0.512, Acc: 0.982, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [1/20], Step [10/111], ROC AUC: 0.646, Acc: 0.961, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [1/20], Step [15/111], ROC AUC: 0.650, Acc: 0.904, Precision: 0.038, Recall 0.333
#
#
# Fold [1/15], Epoch [1/20], Step [20/111], ROC AUC: 0.669, Acc: 0.921, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [1/20], Step [25/111], ROC AUC: 0.740, Acc: 0.950, Precision: 0.167, Recall 0.333
#
#
# Fold [1/15], Epoch [1/20], Step [30/111], ROC AUC: 0.755, Acc: 0.954, Precision: 0.222, Recall 0.250
#
#
# Fold [1/15], Epoch [1/20], Step [35/111], ROC AUC: 0.697, Acc: 0.932, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [1/20], Step [40/111], ROC AUC: 0.719, Acc: 0.957, Precision: 0.100, Recall 0.250
#
#
# Fold [1/15], Epoch [1/20], Step [45/111], ROC AUC: 0.689, Acc: 0.954, Precision: 0.143, Recall 0.125
#
#
# Fold [1/15], Epoch [1/20], Step [50/111], ROC AUC: 0.599, Acc: 0.961, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [1/20], Step [55/111], ROC AUC: 0.800, Acc: 0.946, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [1/20], Step [60/111], ROC AUC: 0.667, Acc: 0.871, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [1/20], Step [65/111], ROC AUC: 0.928, Acc: 0.889, Precision: 0.062, Recall 0.667
#
#
# Fold [1/15], Epoch [1/20], Step [70/111], ROC AUC: 0.725, Acc: 0.975, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [1/20], Step [75/111], ROC AUC: 0.740, Acc: 0.964, Precision: 0.125, Recall 0.250
#
#
# Fold [1/15], Epoch [1/20], Step [80/111], ROC AUC: 0.767, Acc: 0.939, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [1/20], Step [85/111], ROC AUC: 0.682, Acc: 0.921, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [1/20], Step [90/111], ROC AUC: 0.596, Acc: 0.843, Precision: 0.025, Recall 0.167
#
#
# Fold [1/15], Epoch [1/20], Step [95/111], ROC AUC: 0.480, Acc: 0.871, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [1/20], Step [100/111], ROC AUC: 0.850, Acc: 0.946, Precision: 0.071, Recall 0.333
#
#
# Fold [1/15], Epoch [1/20], Step [105/111], ROC AUC: 0.479, Acc: 0.975, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [1/20], Step [110/111], ROC AUC: 0.842, Acc: 0.989, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [1/20], Val ROC AUC: 0.771, Val Acc: 0.983, Val Precision: 0.000, Val Recall 0.000
#
#
# Fold [1/15], Epoch [2/20], Step [5/111], ROC AUC: 0.598, Acc: 0.982, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [2/20], Step [10/111], ROC AUC: 0.815, Acc: 0.961, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [2/20], Step [15/111], ROC AUC: 0.777, Acc: 0.936, Precision: 0.059, Recall 0.333
#
#
# Fold [1/15], Epoch [2/20], Step [20/111], ROC AUC: 0.641, Acc: 0.929, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [2/20], Step [25/111], ROC AUC: 0.776, Acc: 0.925, Precision: 0.059, Recall 0.167
#
#
# Fold [1/15], Epoch [2/20], Step [30/111], ROC AUC: 0.822, Acc: 0.957, Precision: 0.300, Recall 0.375
#
#
# Fold [1/15], Epoch [2/20], Step [35/111], ROC AUC: 0.619, Acc: 0.968, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [2/20], Step [40/111], ROC AUC: 0.671, Acc: 0.943, Precision: 0.071, Recall 0.250
#
#
# Fold [1/15], Epoch [2/20], Step [45/111], ROC AUC: 0.710, Acc: 0.961, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [2/20], Step [50/111], ROC AUC: 0.661, Acc: 0.982, Precision: 0.500, Recall 0.200
#
#
# Fold [1/15], Epoch [2/20], Step [55/111], ROC AUC: 0.668, Acc: 0.968, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [2/20], Step [60/111], ROC AUC: 0.778, Acc: 0.975, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [2/20], Step [65/111], ROC AUC: 0.817, Acc: 0.932, Precision: 0.056, Recall 0.333
#
#
# Fold [1/15], Epoch [2/20], Step [70/111], ROC AUC: 0.701, Acc: 0.875, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [2/20], Step [75/111], ROC AUC: 0.792, Acc: 0.900, Precision: 0.038, Recall 0.250
#
#
# Fold [1/15], Epoch [2/20], Step [80/111], ROC AUC: 0.872, Acc: 0.964, Precision: 0.333, Recall 0.429
#
#
# Fold [1/15], Epoch [2/20], Step [85/111], ROC AUC: 0.815, Acc: 0.929, Precision: 0.062, Recall 0.167
#
#
# Fold [1/15], Epoch [2/20], Step [90/111], ROC AUC: 0.720, Acc: 0.946, Precision: 0.091, Recall 0.167
#
#
# Fold [1/15], Epoch [2/20], Step [95/111], ROC AUC: 0.628, Acc: 0.957, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [2/20], Step [100/111], ROC AUC: 0.857, Acc: 0.982, Precision: 0.250, Recall 0.333
#
#
# Fold [1/15], Epoch [2/20], Step [105/111], ROC AUC: 0.610, Acc: 0.961, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [2/20], Step [110/111], ROC AUC: 0.734, Acc: 0.971, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [2/20], Val ROC AUC: 0.776, Val Acc: 0.970, Val Precision: 0.114, Val Recall 0.105
#
#
# Fold [1/15], Epoch [3/20], Step [5/111], ROC AUC: 0.726, Acc: 0.900, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [3/20], Step [10/111], ROC AUC: 0.667, Acc: 0.875, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [3/20], Step [15/111], ROC AUC: 0.690, Acc: 0.925, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [3/20], Step [20/111], ROC AUC: 0.806, Acc: 0.954, Precision: 0.091, Recall 0.250
#
#
# Fold [1/15], Epoch [3/20], Step [25/111], ROC AUC: 0.729, Acc: 0.975, Precision: 0.333, Recall 0.167
#
#
# Fold [1/15], Epoch [3/20], Step [30/111], ROC AUC: 0.747, Acc: 0.961, Precision: 0.286, Recall 0.250
#
#
# Fold [1/15], Epoch [3/20], Step [35/111], ROC AUC: 0.822, Acc: 0.904, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [3/20], Step [40/111], ROC AUC: 0.737, Acc: 0.904, Precision: 0.040, Recall 0.250
#
#
# Fold [1/15], Epoch [3/20], Step [45/111], ROC AUC: 0.689, Acc: 0.929, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [3/20], Step [50/111], ROC AUC: 0.588, Acc: 0.918, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [3/20], Step [55/111], ROC AUC: 0.727, Acc: 0.939, Precision: 0.077, Recall 0.167
#
#
# Fold [1/15], Epoch [3/20], Step [60/111], ROC AUC: 0.728, Acc: 0.971, Precision: 0.167, Recall 0.250
#
#
# Fold [1/15], Epoch [3/20], Step [65/111], ROC AUC: 0.824, Acc: 0.975, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [3/20], Step [70/111], ROC AUC: 0.694, Acc: 0.957, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [3/20], Step [75/111], ROC AUC: 0.644, Acc: 0.943, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [3/20], Step [80/111], ROC AUC: 0.767, Acc: 0.900, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [3/20], Step [85/111], ROC AUC: 0.734, Acc: 0.896, Precision: 0.040, Recall 0.167
#
#
# Fold [1/15], Epoch [3/20], Step [90/111], ROC AUC: 0.523, Acc: 0.921, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [3/20], Step [95/111], ROC AUC: 0.649, Acc: 0.939, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [3/20], Step [100/111], ROC AUC: 0.913, Acc: 0.914, Precision: 0.080, Recall 0.667
#
#
# Fold [1/15], Epoch [3/20], Step [105/111], ROC AUC: 0.543, Acc: 0.964, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [3/20], Step [110/111], ROC AUC: 0.906, Acc: 0.975, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [3/20], Val ROC AUC: 0.791, Val Acc: 0.983, Val Precision: 0.000, Val Recall 0.000
#
#
# Fold [1/15], Epoch [4/20], Step [5/111], ROC AUC: 0.779, Acc: 0.954, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [4/20], Step [10/111], ROC AUC: 0.686, Acc: 0.925, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [4/20], Step [15/111], ROC AUC: 0.674, Acc: 0.900, Precision: 0.037, Recall 0.333
#
#
# Fold [1/15], Epoch [4/20], Step [20/111], ROC AUC: 0.812, Acc: 0.946, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [4/20], Step [25/111], ROC AUC: 0.765, Acc: 0.925, Precision: 0.059, Recall 0.167
#
#
# Fold [1/15], Epoch [4/20], Step [30/111], ROC AUC: 0.825, Acc: 0.932, Precision: 0.211, Recall 0.500
#
#
# Fold [1/15], Epoch [4/20], Step [35/111], ROC AUC: 0.746, Acc: 0.907, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [4/20], Step [40/111], ROC AUC: 0.762, Acc: 0.968, Precision: 0.143, Recall 0.250
#
#
# Fold [1/15], Epoch [4/20], Step [45/111], ROC AUC: 0.693, Acc: 0.950, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [4/20], Step [50/111], ROC AUC: 0.593, Acc: 0.929, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [4/20], Step [55/111], ROC AUC: 0.651, Acc: 0.918, Precision: 0.053, Recall 0.167
# Fold [1/15], Epoch [4/20], Step [60/111], ROC AUC: 0.755, Acc: 0.950, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [4/20], Step [65/111], ROC AUC: 0.863, Acc: 0.961, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [4/20], Step [70/111], ROC AUC: 0.689, Acc: 0.982, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [4/20], Step [75/111], ROC AUC: 0.688, Acc: 0.979, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [4/20], Step [80/111], ROC AUC: 0.868, Acc: 0.961, Precision: 0.250, Recall 0.286
#
#
# Fold [1/15], Epoch [4/20], Step [85/111], ROC AUC: 0.818, Acc: 0.975, Precision: 0.333, Recall 0.167
#
#
# Fold [1/15], Epoch [4/20], Step [90/111], ROC AUC: 0.683, Acc: 0.964, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [4/20], Step [95/111], ROC AUC: 0.730, Acc: 0.961, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [4/20], Step [100/111], ROC AUC: 0.819, Acc: 0.961, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [4/20], Step [105/111], ROC AUC: 0.466, Acc: 0.900, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [4/20], Step [110/111], ROC AUC: 0.801, Acc: 0.914, Precision: 0.043, Recall 0.333
#
#
# Fold [1/15], Epoch [4/20], Val ROC AUC: 0.789, Val Acc: 0.966, Val Precision: 0.070, Val Recall 0.079
#
# Epoch     4: reducing learning rate of group 0 to 1.0000e-04.
#
# Fold [1/15], Epoch [5/20], Step [5/111], ROC AUC: 0.796, Acc: 0.918, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [5/20], Step [10/111], ROC AUC: 0.730, Acc: 0.968, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [5/20], Step [15/111], ROC AUC: 0.566, Acc: 0.936, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [5/20], Step [20/111], ROC AUC: 0.826, Acc: 0.932, Precision: 0.059, Recall 0.250
#
#
# Fold [1/15], Epoch [5/20], Step [25/111], ROC AUC: 0.835, Acc: 0.964, Precision: 0.250, Recall 0.333
#
#
# Fold [1/15], Epoch [5/20], Step [30/111], ROC AUC: 0.851, Acc: 0.950, Precision: 0.200, Recall 0.250
#
#
# Fold [1/15], Epoch [5/20], Step [35/111], ROC AUC: 0.806, Acc: 0.968, Precision: 0.143, Recall 0.250
#
#
# Fold [1/15], Epoch [5/20], Step [40/111], ROC AUC: 0.688, Acc: 0.943, Precision: 0.071, Recall 0.250
#
#
# Fold [1/15], Epoch [5/20], Step [45/111], ROC AUC: 0.708, Acc: 0.954, Precision: 0.143, Recall 0.125
#
#
# Fold [1/15], Epoch [5/20], Step [50/111], ROC AUC: 0.645, Acc: 0.968, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [5/20], Step [55/111], ROC AUC: 0.608, Acc: 0.957, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [5/20], Step [60/111], ROC AUC: 0.783, Acc: 0.971, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [5/20], Step [65/111], ROC AUC: 0.875, Acc: 0.957, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [5/20], Step [70/111], ROC AUC: 0.613, Acc: 0.968, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [5/20], Step [75/111], ROC AUC: 0.830, Acc: 0.968, Precision: 0.143, Recall 0.250
#
#
# Fold [1/15], Epoch [5/20], Step [80/111], ROC AUC: 0.881, Acc: 0.950, Precision: 0.111, Recall 0.143
#
#
# Fold [1/15], Epoch [5/20], Step [85/111], ROC AUC: 0.868, Acc: 0.954, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [5/20], Step [90/111], ROC AUC: 0.759, Acc: 0.946, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [5/20], Step [95/111], ROC AUC: 0.691, Acc: 0.943, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [5/20], Step [100/111], ROC AUC: 0.829, Acc: 0.957, Precision: 0.091, Recall 0.333
#
#
# Fold [1/15], Epoch [5/20], Step [105/111], ROC AUC: 0.619, Acc: 0.943, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [5/20], Step [110/111], ROC AUC: 0.812, Acc: 0.971, Precision: 0.143, Recall 0.333
#
#
# Fold [1/15], Epoch [5/20], Val ROC AUC: 0.805, Val Acc: 0.972, Val Precision: 0.038, Val Recall 0.026
#
#
# Fold [1/15], Epoch [6/20], Step [5/111], ROC AUC: 0.701, Acc: 0.950, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [6/20], Step [10/111], ROC AUC: 0.734, Acc: 0.975, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [6/20], Step [15/111], ROC AUC: 0.702, Acc: 0.968, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [6/20], Step [20/111], ROC AUC: 0.877, Acc: 0.975, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [6/20], Step [25/111], ROC AUC: 0.771, Acc: 0.979, Precision: 0.500, Recall 0.167
#
#
# Fold [1/15], Epoch [6/20], Step [30/111], ROC AUC: 0.856, Acc: 0.968, Precision: 0.400, Recall 0.250
#
#
# Fold [1/15], Epoch [6/20], Step [35/111], ROC AUC: 0.729, Acc: 0.950, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [6/20], Step [40/111], ROC AUC: 0.614, Acc: 0.964, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [6/20], Step [45/111], ROC AUC: 0.757, Acc: 0.961, Precision: 0.200, Recall 0.125
#
#
# Fold [1/15], Epoch [6/20], Step [50/111], ROC AUC: 0.660, Acc: 0.957, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [6/20], Step [55/111], ROC AUC: 0.799, Acc: 0.961, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [6/20], Step [60/111], ROC AUC: 0.710, Acc: 0.957, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [6/20], Step [65/111], ROC AUC: 0.835, Acc: 0.946, Precision: 0.071, Recall 0.333
#
#
# Fold [1/15], Epoch [6/20], Step [70/111], ROC AUC: 0.860, Acc: 0.954, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [6/20], Step [75/111], ROC AUC: 0.686, Acc: 0.975, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [6/20], Step [80/111], ROC AUC: 0.831, Acc: 0.936, Precision: 0.077, Recall 0.143
#
#
# Fold [1/15], Epoch [6/20], Step [85/111], ROC AUC: 0.829, Acc: 0.957, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [6/20], Step [90/111], ROC AUC: 0.612, Acc: 0.929, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [6/20], Step [95/111], ROC AUC: 0.609, Acc: 0.943, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [6/20], Step [100/111], ROC AUC: 0.940, Acc: 0.936, Precision: 0.105, Recall 0.667
#
#
# Fold [1/15], Epoch [6/20], Step [105/111], ROC AUC: 0.645, Acc: 0.936, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [6/20], Step [110/111], ROC AUC: 0.773, Acc: 0.950, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [6/20], Val ROC AUC: 0.823, Val Acc: 0.960, Val Precision: 0.111, Val Recall 0.184
#
#
# Fold [1/15], Epoch [7/20], Step [5/111], ROC AUC: 0.808, Acc: 0.946, Precision: 0.077, Recall 0.250
#
#
# Fold [1/15], Epoch [7/20], Step [10/111], ROC AUC: 0.768, Acc: 0.929, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [7/20], Step [15/111], ROC AUC: 0.746, Acc: 0.971, Precision: 0.143, Recall 0.333
#
#
# Fold [1/15], Epoch [7/20], Step [20/111], ROC AUC: 0.914, Acc: 0.943, Precision: 0.125, Recall 0.500
#
#
# Fold [1/15], Epoch [7/20], Step [25/111], ROC AUC: 0.902, Acc: 0.961, Precision: 0.273, Recall 0.500
#
#
# Fold [1/15], Epoch [7/20], Step [30/111], ROC AUC: 0.778, Acc: 0.950, Precision: 0.125, Recall 0.125
#
#
# Fold [1/15], Epoch [7/20], Step [35/111], ROC AUC: 0.796, Acc: 0.968, Precision: 0.143, Recall 0.250
#
#
# Fold [1/15], Epoch [7/20], Step [40/111], ROC AUC: 0.721, Acc: 0.964, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [7/20], Step [45/111], ROC AUC: 0.756, Acc: 0.957, Precision: 0.250, Recall 0.250
#
#
# Fold [1/15], Epoch [7/20], Step [50/111], ROC AUC: 0.803, Acc: 0.957, Precision: 0.111, Recall 0.200
#
#
# Fold [1/15], Epoch [7/20], Step [55/111], ROC AUC: 0.674, Acc: 0.964, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [7/20], Step [60/111], ROC AUC: 0.724, Acc: 0.954, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [7/20], Step [65/111], ROC AUC: 0.770, Acc: 0.979, Precision: 0.200, Recall 0.333
#
#
# Fold [1/15], Epoch [7/20], Step [70/111], ROC AUC: 0.700, Acc: 0.964, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [7/20], Step [75/111], ROC AUC: 0.706, Acc: 0.936, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [7/20], Step [80/111], ROC AUC: 0.840, Acc: 0.950, Precision: 0.111, Recall 0.143
#
#
# Fold [1/15], Epoch [7/20], Step [85/111], ROC AUC: 0.813, Acc: 0.946, Precision: 0.091, Recall 0.167
#
#
# Fold [1/15], Epoch [7/20], Step [90/111], ROC AUC: 0.564, Acc: 0.936, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [7/20], Step [95/111], ROC AUC: 0.701, Acc: 0.943, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [7/20], Step [100/111], ROC AUC: 0.968, Acc: 0.957, Precision: 0.091, Recall 0.333
#
#
# Fold [1/15], Epoch [7/20], Step [105/111], ROC AUC: 0.529, Acc: 0.954, Precision: 0.000, Recall 0.000
# Fold [1/15], Epoch [7/20], Step [110/111], ROC AUC: 0.686, Acc: 0.950, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [7/20], Val ROC AUC: 0.801, Val Acc: 0.972, Val Precision: 0.100, Val Recall 0.079
#
# Epoch     7: reducing learning rate of group 0 to 1.0000e-05.
#
# Fold [1/15], Epoch [8/20], Step [5/111], ROC AUC: 0.722, Acc: 0.939, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [8/20], Step [10/111], ROC AUC: 0.735, Acc: 0.957, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [8/20], Step [15/111], ROC AUC: 0.722, Acc: 0.979, Precision: 0.200, Recall 0.333
#
#
# Fold [1/15], Epoch [8/20], Step [20/111], ROC AUC: 0.849, Acc: 0.964, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [8/20], Step [25/111], ROC AUC: 0.866, Acc: 0.950, Precision: 0.100, Recall 0.167
#
#
# Fold [1/15], Epoch [8/20], Step [30/111], ROC AUC: 0.805, Acc: 0.950, Precision: 0.200, Recall 0.250
#
#
# Fold [1/15], Epoch [8/20], Step [35/111], ROC AUC: 0.562, Acc: 0.957, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [8/20], Step [40/111], ROC AUC: 0.665, Acc: 0.964, Precision: 0.125, Recall 0.250
#
#
# Fold [1/15], Epoch [8/20], Step [45/111], ROC AUC: 0.739, Acc: 0.946, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [8/20], Step [50/111], ROC AUC: 0.649, Acc: 0.954, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [8/20], Step [55/111], ROC AUC: 0.634, Acc: 0.943, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [8/20], Step [60/111], ROC AUC: 0.696, Acc: 0.968, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [8/20], Step [65/111], ROC AUC: 0.815, Acc: 0.961, Precision: 0.100, Recall 0.333
#
#
# Fold [1/15], Epoch [8/20], Step [70/111], ROC AUC: 0.500, Acc: 0.971, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [8/20], Step [75/111], ROC AUC: 0.712, Acc: 0.950, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [8/20], Step [80/111], ROC AUC: 0.791, Acc: 0.939, Precision: 0.083, Recall 0.143
#
#
# Fold [1/15], Epoch [8/20], Step [85/111], ROC AUC: 0.790, Acc: 0.943, Precision: 0.083, Recall 0.167
#
#
# Fold [1/15], Epoch [8/20], Step [90/111], ROC AUC: 0.775, Acc: 0.932, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [8/20], Step [95/111], ROC AUC: 0.671, Acc: 0.943, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [8/20], Step [100/111], ROC AUC: 0.947, Acc: 0.968, Precision: 0.125, Recall 0.333
#
#
# Fold [1/15], Epoch [8/20], Step [105/111], ROC AUC: 0.543, Acc: 0.946, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [8/20], Step [110/111], ROC AUC: 0.698, Acc: 0.957, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [8/20], Val ROC AUC: 0.801, Val Acc: 0.967, Val Precision: 0.073, Val Recall 0.079
#
# Epoch     8: reducing learning rate of group 0 to 3.0000e-06.
#
# Fold [1/15], Epoch [9/20], Step [5/111], ROC AUC: 0.707, Acc: 0.954, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [9/20], Step [10/111], ROC AUC: 0.714, Acc: 0.961, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [9/20], Step [15/111], ROC AUC: 0.745, Acc: 0.954, Precision: 0.083, Recall 0.333
#
#
# Fold [1/15], Epoch [9/20], Step [20/111], ROC AUC: 0.836, Acc: 0.961, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [9/20], Step [25/111], ROC AUC: 0.864, Acc: 0.968, Precision: 0.200, Recall 0.167
#
#
# Fold [1/15], Epoch [9/20], Step [30/111], ROC AUC: 0.795, Acc: 0.950, Precision: 0.200, Recall 0.250
#
#
# Fold [1/15], Epoch [9/20], Step [35/111], ROC AUC: 0.665, Acc: 0.950, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [9/20], Step [40/111], ROC AUC: 0.713, Acc: 0.957, Precision: 0.100, Recall 0.250
#
#
# Fold [1/15], Epoch [9/20], Step [45/111], ROC AUC: 0.738, Acc: 0.961, Precision: 0.200, Recall 0.125
#
#
# Fold [1/15], Epoch [9/20], Step [50/111], ROC AUC: 0.623, Acc: 0.946, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [9/20], Step [55/111], ROC AUC: 0.592, Acc: 0.957, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [9/20], Step [60/111], ROC AUC: 0.774, Acc: 0.961, Precision: 0.111, Recall 0.250
#
#
# Fold [1/15], Epoch [9/20], Step [65/111], ROC AUC: 0.846, Acc: 0.975, Precision: 0.167, Recall 0.333
#
#
# Fold [1/15], Epoch [9/20], Step [70/111], ROC AUC: 0.595, Acc: 0.968, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [9/20], Step [75/111], ROC AUC: 0.776, Acc: 0.936, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [9/20], Step [80/111], ROC AUC: 0.870, Acc: 0.950, Precision: 0.111, Recall 0.143
#
#
# Fold [1/15], Epoch [9/20], Step [85/111], ROC AUC: 0.874, Acc: 0.954, Precision: 0.111, Recall 0.167
#
#
# Fold [1/15], Epoch [9/20], Step [90/111], ROC AUC: 0.683, Acc: 0.936, Precision: 0.071, Recall 0.167
#
#
# Fold [1/15], Epoch [9/20], Step [95/111], ROC AUC: 0.677, Acc: 0.957, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [9/20], Step [100/111], ROC AUC: 0.905, Acc: 0.968, Precision: 0.200, Recall 0.667
#
#
# Fold [1/15], Epoch [9/20], Step [105/111], ROC AUC: 0.544, Acc: 0.964, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [9/20], Step [110/111], ROC AUC: 0.786, Acc: 0.961, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [9/20], Val ROC AUC: 0.815, Val Acc: 0.974, Val Precision: 0.154, Val Recall 0.105
#
#
# Fold [1/15], Epoch [10/20], Step [5/111], ROC AUC: 0.743, Acc: 0.950, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [10/20], Step [10/111], ROC AUC: 0.792, Acc: 0.957, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [10/20], Step [15/111], ROC AUC: 0.717, Acc: 0.936, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [10/20], Step [20/111], ROC AUC: 0.883, Acc: 0.946, Precision: 0.077, Recall 0.250
#
#
# Fold [1/15], Epoch [10/20], Step [25/111], ROC AUC: 0.795, Acc: 0.950, Precision: 0.100, Recall 0.167
#
#
# Fold [1/15], Epoch [10/20], Step [30/111], ROC AUC: 0.807, Acc: 0.943, Precision: 0.100, Recall 0.125
#
#
# Fold [1/15], Epoch [10/20], Step [35/111], ROC AUC: 0.731, Acc: 0.950, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [10/20], Step [40/111], ROC AUC: 0.719, Acc: 0.971, Precision: 0.167, Recall 0.250
#
#
# Fold [1/15], Epoch [10/20], Step [45/111], ROC AUC: 0.762, Acc: 0.939, Precision: 0.091, Recall 0.125
#
#
# Fold [1/15], Epoch [10/20], Step [50/111], ROC AUC: 0.665, Acc: 0.950, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [10/20], Step [55/111], ROC AUC: 0.622, Acc: 0.964, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [10/20], Step [60/111], ROC AUC: 0.793, Acc: 0.961, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [10/20], Step [65/111], ROC AUC: 0.846, Acc: 0.939, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [10/20], Step [70/111], ROC AUC: 0.833, Acc: 0.968, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [10/20], Step [75/111], ROC AUC: 0.836, Acc: 0.968, Precision: 0.143, Recall 0.250
#
#
# Fold [1/15], Epoch [10/20], Step [80/111], ROC AUC: 0.817, Acc: 0.946, Precision: 0.167, Recall 0.286
#
#
# Fold [1/15], Epoch [10/20], Step [85/111], ROC AUC: 0.833, Acc: 0.943, Precision: 0.083, Recall 0.167
#
#
# Fold [1/15], Epoch [10/20], Step [90/111], ROC AUC: 0.649, Acc: 0.936, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [10/20], Step [95/111], ROC AUC: 0.671, Acc: 0.939, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [10/20], Step [100/111], ROC AUC: 0.911, Acc: 0.968, Precision: 0.200, Recall 0.667
#
#
# Fold [1/15], Epoch [10/20], Step [105/111], ROC AUC: 0.606, Acc: 0.950, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [10/20], Step [110/111], ROC AUC: 0.845, Acc: 0.943, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [10/20], Val ROC AUC: 0.819, Val Acc: 0.968, Val Precision: 0.056, Val Recall 0.053
#
#
# Fold [1/15], Epoch [11/20], Step [5/111], ROC AUC: 0.822, Acc: 0.968, Precision: 0.143, Recall 0.250
#
#
# Fold [1/15], Epoch [11/20], Step [10/111], ROC AUC: 0.846, Acc: 0.954, Precision: 0.083, Recall 0.333
#
#
# Fold [1/15], Epoch [11/20], Step [15/111], ROC AUC: 0.653, Acc: 0.957, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [11/20], Step [20/111], ROC AUC: 0.804, Acc: 0.957, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [11/20], Step [25/111], ROC AUC: 0.805, Acc: 0.971, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [11/20], Step [30/111], ROC AUC: 0.777, Acc: 0.961, Precision: 0.333, Recall 0.375
#
#
# Fold [1/15], Epoch [11/20], Step [35/111], ROC AUC: 0.731, Acc: 0.946, Precision: 0.000, Recall 0.000
# Fold [1/15], Epoch [11/20], Step [40/111], ROC AUC: 0.733, Acc: 0.968, Precision: 0.143, Recall 0.250
#
#
# Fold [1/15], Epoch [11/20], Step [45/111], ROC AUC: 0.740, Acc: 0.946, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [11/20], Step [50/111], ROC AUC: 0.730, Acc: 0.968, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [11/20], Step [55/111], ROC AUC: 0.699, Acc: 0.950, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [11/20], Step [60/111], ROC AUC: 0.734, Acc: 0.961, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [11/20], Step [65/111], ROC AUC: 0.819, Acc: 0.954, Precision: 0.083, Recall 0.333
#
#
# Fold [1/15], Epoch [11/20], Step [70/111], ROC AUC: 0.707, Acc: 0.968, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [11/20], Step [75/111], ROC AUC: 0.713, Acc: 0.964, Precision: 0.125, Recall 0.250
#
#
# Fold [1/15], Epoch [11/20], Step [80/111], ROC AUC: 0.825, Acc: 0.968, Precision: 0.333, Recall 0.286
#
#
# Fold [1/15], Epoch [11/20], Step [85/111], ROC AUC: 0.825, Acc: 0.961, Precision: 0.143, Recall 0.167
#
#
# Fold [1/15], Epoch [11/20], Step [90/111], ROC AUC: 0.593, Acc: 0.936, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [11/20], Step [95/111], ROC AUC: 0.705, Acc: 0.943, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [11/20], Step [100/111], ROC AUC: 0.921, Acc: 0.950, Precision: 0.077, Recall 0.333
#
#
# Fold [1/15], Epoch [11/20], Step [105/111], ROC AUC: 0.495, Acc: 0.968, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [11/20], Step [110/111], ROC AUC: 0.880, Acc: 0.957, Precision: 0.000, Recall 0.000
#
#
# Fold [1/15], Epoch [11/20], Val ROC AUC: 0.792, Val Acc: 0.972, Val Precision: 0.074, Val Recall 0.053
#
# Early stopping. Best validation roc_auc: 0.823

# %%
plt.style.use('seaborn-colorblind')
plt.rcParams.update({'font.size': 16, 
                     'legend.framealpha':1, 
                     'legend.edgecolor':'inherit'}) 
plt.figure(figsize=(9, 6))

plt.plot(val_roc, label = 'Validation ROC AUC')
#plt.plot(val_acc, label = 'Validation accuracy')
#plt.plot(val_recall, label = 'Validation recall')
#plt.plot(val_precision, label = 'Validation precision')
plt.plot()
plt.legend()
plt.show()

# %%
np.max(valid_predictions)
# Out:
# 0.51489204

# %%
plt.style.use('seaborn-colorblind')
plt.rcParams.update({'font.size': 16, 
                     'legend.framealpha':1, 
                     'legend.edgecolor':'inherit'}) 
plt.figure(figsize=(9, 6))

plt.hist(np.array(valid_predictions).ravel())
plt.xlim([0, 1])
plt.show()
