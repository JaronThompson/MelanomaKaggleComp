# %%
import numpy as np 
import pandas as pd 
#import pydicom
import matplotlib.pyplot as plt 

import torch 
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.optim.lr_scheduler import ReduceLROnPlateau

from PIL import Image
from skimage.transform import resize
from sklearn.metrics import confusion_matrix, roc_curve, auc

# %%
# Device configuration (GPU can be enabled in settings)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
#device = 'cpu'
print(device)
# Out:
# cuda:0

# %%
# upload train dataframe
train_df_allsamples = pd.read_csv("../TrainTestDataFrames/marking.csv")
train_df_allsamples.head()
# Out:
#    patient_id      image_id  target  source     sex  age_approx  \
# 0  IP_7279968  ISIC_2637011       0  ISIC20    male        45.0
# 1  IP_3075186  ISIC_0015719       0  ISIC20  female        45.0
# 2  IP_2842074  ISIC_0052212       0  ISIC20  female        50.0
# 3  IP_6890425  ISIC_0068279       0  ISIC20  female        45.0
# 4  IP_8723313  ISIC_0074268       0  ISIC20  female        55.0
#
#   anatom_site_general_challenge
# 0                     head/neck
# 1               upper extremity
# 2               lower extremity
# 3                     head/neck
# 4               upper extremity

# %%
# create dictionary that maps image name to target 
image_names = train_df_allsamples["image_id"].values 
targets = train_df_allsamples["target"].values
img_to_target = {image_name:target for image_name, target in zip(image_names, targets)}

percent_tp = sum(targets)/len(targets) * 100 
print("{} training samples total.".format(len(targets)))
print("Only {:.3f} percent of training data set is a true positive.".format(percent_tp))
print("Therefore, the baseline accuracy is {:.3f}".format(np.max([percent_tp, 100-percent_tp])))
# Out:
# 60487 training samples total.
# Only 9.058 percent of training data set is a true positive.
# Therefore, the baseline accuracy is 90.942

# %%
# update so that the number of positives balances negatives
train_df_pos = train_df_allsamples.iloc[targets>0, :]
train_df_neg = train_df_allsamples.iloc[targets==0, :]
train_df_negsample = train_df_neg.sample(n=int(train_df_pos.shape[0]))

# concatenate negative and positive samples, then shuffle using .sample() 
#train_val_df = pd.concat((train_df_pos, train_df_negsample)).sample(frac=1)
train_val_df = train_df_allsamples.sample(frac=1)

train_val_split = .95
n_train_val = train_val_df.shape[0]
n_train = int(train_val_split*n_train_val)

train_df = train_val_df[:n_train]
val_df = train_val_df[n_train:]

# create dictionary that maps image name to target 
image_names = val_df["image_id"].values 
val_targets = val_df["target"].values

percent_tp = sum(val_targets)/len(val_targets) * 100 
baseline = np.max([percent_tp, 100-percent_tp])

print("{} Training and {} Validation samples".format(n_train, n_train_val-n_train))
print("{:.3f} percent of validation data set is a positive.".format(percent_tp))
print("Baseline validation accuracy is {:.3f}".format(baseline))
# Out:
# 57462 Training and 3025 Validation samples
# 9.289 percent of validation data set is a positive.
# Baseline validation accuracy is 90.711

# %%
meta_features = ['sex', 'age_approx', 'anatom_site_general_challenge'] 

encoder = {}
for feature in meta_features: 
    # determine unique features  
    categories = np.unique(np.array(train_df[feature].values, str))
    for i, category in enumerate(categories): 
        if category != 'nan':
            encoder[category] = np.float(i)
encoder['nan'] = np.nan

# define a unique transform each time a positive is resampled: 

# basic transform 
transform_1 = transforms.Compose([
    transforms.RandomRotation(degrees=5),
    transforms.ColorJitter(brightness=32. / 255.,saturation=0.5),
    transforms.RandomResizedCrop(size=256, scale=(0.5, 1.0), ratio=(0.8, 1.2)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])])

# horizontal or vertical flip 
transform_2 = transforms.Compose([
    transforms.RandomRotation(degrees=5),
    transforms.ColorJitter(brightness=32. / 255.,saturation=0.5),
    transforms.RandomResizedCrop(size=256, scale=(0.5, 1.0), ratio=(0.8, 1.2)),
    #transforms.RandomVerticalFlip(),
    transforms.RandomHorizontalFlip(1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])])

'''
# horizontal flip 
transform_3 = transforms.Compose([
    transforms.RandomRotation(degrees=5),
    transforms.RandomResizedCrop(size=256, scale=(0.5, 1.0), ratio=(0.8, 1.2)),
    transforms.RandomHorizontalFlip(1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])])

# vertical and horizontal flip (same as rotating 180 +/- 45 deg... but hopefully still useful)
transform_4 = transforms.Compose([
    transforms.RandomRotation(degrees=5),
    transforms.RandomResizedCrop(size=256, scale=(0.5, 1.0), ratio=(0.8, 1.2)),
    transforms.RandomHorizontalFlip(1),
    transforms.RandomVerticalFlip(1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])])
'''

# no flip or rotation for test/validation data 
transform_valid = transforms.Compose([
    transforms.RandomResizedCrop(size=256, scale=(1.0, 1.0), ratio=(1.0, 1.0)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])
])

def make_weights_for_balanced_classes(df, nclasses=2):   
    targets = df["target"].values
    count = [0] * nclasses                                                      
    for label in targets:                                                         
        count[label] += 1                                                     
    weight_per_class = [0.] * nclasses                                      
    N = float(sum(count))                                                   
    for i in range(nclasses):                                                   
        weight_per_class[i] = N/float(count[i])                                 
    weight = [0] * len(targets)                                              
    for idx, label in enumerate(targets):                                          
        weight[idx] = weight_per_class[label]   
        
    return np.array(weight)  

class ValidDataset(torch.utils.data.Dataset):
    def __init__(self, df, path_to_files):
        # 1. Initialize file paths or a list of file names.
        self.path = path_to_files
        self.df = df

    def __getitem__(self, index):
        # 1. Read one data from file (e.g. using numpy.fromfile, PIL.Image.open).
        
        # load X 
        img_name = self.df['image_id'].values[index]
        img_path = self.path + img_name + ".jpg"
        img = plt.imread(img_path)
        
        # determine meta data 
        meta = self.df[meta_features].values[index]
        meta_data = np.array([encoder[str(m)] for m in meta])
        
        # load y 
        label = self.df["target"].values[index]
        target = torch.tensor(label, dtype=torch.float32)
        
        # 2. Preprocess the data (e.g. torchvision.Transform).
        img = Image.fromarray(img)
        #img = img.resize((256, 256))
        img_processed = transform_valid(img)
        # 3. Return a data pair (e.g. image and label).
        return img_processed, target
        
    def __len__(self):
        # total size of your dataset.
        return self.df.shape[0]

class MyDataLoader():
    def __init__(self, df, path, batchsize, min_balance=None):
        # store df, path, weights, ...
        self.df = df 
        self.path = path
        self.w = make_weights_for_balanced_classes(df)
        self.batchsize = batchsize 
        self.balanced = True
        self.min_balance = min_balance
        
        # create a dictionary to map image_ids to index and target in dataframe 
        image_ids = self.df['image_id'].values 
        self.targets = self.df['target'].values
        inds = np.arange(len(image_ids))
        self.imgID2Idx = {im_id:ind for (im_id, ind) in zip(image_ids, inds)}
        self.imgID2Target = {im_id:target for (im_id, target) in zip(image_ids, self.targets)}
        
        # keep track of how many times samples have been drawn 
        self.counts = np.zeros(len(image_ids))
        
    def get_batch(self):
        # get image ids for the batch 
        if np.sum(self.w > 0) >= self.batchsize:
            batch_image_ids = self.df.sample(n=self.batchsize, weights=self.w)['image_id'].values
        else:
            # update batchsize 
            print("Updating batchsize, maximum dataset size reached")
            self.batchsize = np.sum(self.w > 0)
            batch_image_ids = self.df.sample(n=self.batchsize, weights=self.w)['image_id'].values
        
        # get the index locations for the image ids 
        batch_sample_inds = [self.imgID2Idx[im_id] for im_id in batch_image_ids]
        batch_targets = [self.imgID2Target[im_id] for im_id in batch_image_ids]
        
        # Update counts 
        self.counts[batch_sample_inds] += 1
        
        # Update sampling weights so that target=0 --> w = 0, target=1 --> w /= 2 
        for ind, target in zip(batch_sample_inds, batch_targets):
            # if the sample is a negative, then we don't want to sample it again 
            # if the sample has already been sampled 2 times, it shouldn't be sampled again
            # if target is positive, sampling should happen less frequently 
            if target == 0 or self.counts[ind] == 2:
                self.w[ind] = 0 
            else:
                self.w[ind] /= 2 
        
        # Data returned in shape [Batchsize, Channels, H, W]
        images = np.zeros((self.batchsize, 3, 256, 256)) 
        labels = np.zeros(self.batchsize)
        #meta_data = np.zeros((self.batchsize, 3))
        
        for i, index in enumerate(batch_sample_inds):
            
            # 1. load image
            img_name = self.df['image_id'].values[index]
            img_path = self.path + img_name + ".jpg"
            img = plt.imread(img_path)

            # 2. Preprocess the data (e.g. torchvision.Transform).
            img = Image.fromarray(img)
            if self.counts[index] == 1:
                images[i, :, :, :] = transform_1(img)
            if self.counts[index] == 2:
                images[i, :, :, :] = transform_2(img)
            '''
            if self.counts[index] == 3:
                images[i, :, :, :] = transform_3(img)
            if self.counts[index] == 4:
                images[i, :, :, :] = transform_4(img)
            '''
            
            # 3. store label 
            labels[i] = self.imgID2Target[img_name]
                
            # 4. get meta_data 
            #meta = self.df[meta_features].values[index]
            #meta_data[i, :] = np.array([encoder[str(m)] for m in meta])
                
        # Quit once all positive samples have zero valued weights 
        if np.sum(self.w[self.targets==1]) == 0:
            self.balanced = False
            
        # If a min balance is specified, quit at min balance
        if self.min_balance:
            if sum(labels)/len(labels) <= self.min_balance:
                self.balanced = False
        
        # return data 
        X = torch.tensor(images, dtype = torch.float32)
        y = torch.tensor(labels, dtype = torch.float32)
        return X, y #, meta_data

# %%
# 2 convolutional layers + 2 fully connected layers 
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=8, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(8),
            nn.LeakyReLU(),  
            nn.Dropout(p=0.2),
            nn.MaxPool2d(kernel_size=4, stride=4))
        self.layer2 = nn.Sequential(
            nn.Conv2d(8, 16, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Dropout(p=0.2),
            nn.MaxPool2d(kernel_size=4, stride=4)) 
        self.fc = nn.Sequential(
            nn.Linear(4096, 64),
            nn.ReLU(), # Using sigmoid, neurons were completely saturated (only 0 or 1 valued activations)
            nn.Dropout(p=0.2))
        self.output = nn.Sequential(
            nn.Linear(64, 1),
            nn.Sigmoid())
        
    def embedding(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = out.reshape(out.size(0), -1)
        out = self.fc(out)
        return out 
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = out.reshape(out.size(0), -1)
        out = self.fc(out)
        out = self.output(out)
        return out

model = ConvNet().to(device)
#model.load_state_dict(torch.load('../Models/CNNmodel.ckpt'), strict=False)

# %%
# Train the model
# Use the prebuilt data loader.
path = "../../data-512/512x512-dataset-melanoma/512x512-dataset-melanoma/"

# evaluate performance on validation data 
valid_dataset = ValidDataset(val_df, path)                                              
valid_loader = torch.utils.data.DataLoader(dataset=valid_dataset, batch_size=16) 


# save losses from training 
num_epochs = 20
batchsize  = 128

train_roc = []
val_roc   = []
losses    = []
patience     = 3
set_patience = 3 
best_val     = 0

# Loss and optimizer
criterion = nn.BCELoss()
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# scheduler reduces learning rate by factor of 10 when val auc does not improve
scheduler = ReduceLROnPlateau(optimizer=optimizer, mode='max', patience=1, verbose=True)


'''        
train_dataset = ValidDataset(train_df, path)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batchsize, shuffle=True)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
'''
for epoch in range(num_epochs):
    train_loader = MyDataLoader(train_df, path, batchsize=batchsize, min_balance=.3)
    while train_loader.balanced:
        images, labels = train_loader.get_batch()

        # set up model for training 
        model = model.train()
        
        images = images.to(device)
        labels = torch.reshape(labels, [len(labels), 1])
        labels = labels.to(device)
        
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # store loss
        losses.append(loss)
        
        # Calculate ROC
        predictions = outputs.detach().cpu().numpy().ravel()
        targets = labels.cpu().numpy().ravel()

        fpr, tpr, _ = roc_curve(np.array(targets, np.int), np.array(predictions).ravel())
        train_roc_auc = auc(fpr, tpr)
        train_roc.append(train_roc_auc)
        
        # Calculate balance 
        balance = np.sum(targets) / len(targets)
        
        print ('Epoch [{}/{}], Balance {:.2f}, Loss: {:.4f}, Train ROC AUC: {:.4f}' 
               .format(epoch+1, num_epochs, balance, loss.item(), train_roc_auc))
        
    # prep model for evaluation
    valid_predictions = []
    valid_targets = []
    model.eval() 
    with torch.no_grad():
        for j, (images, labels) in enumerate(valid_loader):
            images = images.to(device)

            labels = torch.reshape(labels, [len(labels), 1])
            labels = labels.to(device)

            # Forward pass
            outputs = model(images)

            # Calculate val ROC
            valid_predictions += list(outputs.detach().cpu().numpy().ravel())
            valid_targets += list(labels.cpu().numpy().ravel()) 

    fpr, tpr, _ = roc_curve(np.array(valid_targets, np.int), np.array(valid_predictions).ravel())
    val_roc_auc = auc(fpr, tpr)
    val_roc.append(val_roc_auc)
    
    print ('\nEpoch [{}/{}], Val ROC AUC: {:.4f}\n'.format(epoch+1, num_epochs, val_roc_auc))
    
    # learning rate is reduced if val roc doesn't improve 
    scheduler.step(val_roc_auc)
    
    if val_roc_auc >= best_val:
        best_val = val_roc_auc
        patience = set_patience        
        torch.save(model.state_dict(), '../Models/CNNmodel.ckpt')  
    else:
        patience -= 1
        if patience == 0:
            print('Early stopping. Best validation roc_auc: {:.3f}'.format(best_val))
            model.load_state_dict(torch.load('../Models/CNNmodel.ckpt'), strict=False)
            break
# Out:
# Epoch [1/10], Balance 0.57, Loss: 0.7571, Train ROC AUC: 0.5320
# Epoch [1/10], Balance 0.48, Loss: 2.6762, Train ROC AUC: 0.5902
# Epoch [1/10], Balance 0.56, Loss: 0.7495, Train ROC AUC: 0.7252
# Epoch [1/10], Balance 0.49, Loss: 0.8210, Train ROC AUC: 0.5519
# Epoch [1/10], Balance 0.47, Loss: 0.8953, Train ROC AUC: 0.5353
# Epoch [1/10], Balance 0.49, Loss: 0.8255, Train ROC AUC: 0.5839
# Epoch [1/10], Balance 0.41, Loss: 0.6313, Train ROC AUC: 0.7036
# Epoch [1/10], Balance 0.51, Loss: 0.6363, Train ROC AUC: 0.7223
# Epoch [1/10], Balance 0.54, Loss: 0.6759, Train ROC AUC: 0.6605
# Epoch [1/10], Balance 0.46, Loss: 0.6634, Train ROC AUC: 0.7286
# Epoch [1/10], Balance 0.52, Loss: 0.6811, Train ROC AUC: 0.6935
# Epoch [1/10], Balance 0.55, Loss: 0.6682, Train ROC AUC: 0.6805
# Epoch [1/10], Balance 0.44, Loss: 0.6908, Train ROC AUC: 0.7835
# Epoch [1/10], Balance 0.51, Loss: 0.6604, Train ROC AUC: 0.7358
# Epoch [1/10], Balance 0.48, Loss: 0.6603, Train ROC AUC: 0.7334
# Epoch [1/10], Balance 0.48, Loss: 0.6232, Train ROC AUC: 0.7444
# Epoch [1/10], Balance 0.41, Loss: 0.7180, Train ROC AUC: 0.7047
# Epoch [1/10], Balance 0.42, Loss: 0.5531, Train ROC AUC: 0.8226
# Epoch [1/10], Balance 0.46, Loss: 0.5960, Train ROC AUC: 0.7433
# Epoch [1/10], Balance 0.37, Loss: 0.5591, Train ROC AUC: 0.8038
# Epoch [1/10], Balance 0.51, Loss: 0.5780, Train ROC AUC: 0.7873
# Epoch [1/10], Balance 0.56, Loss: 0.6878, Train ROC AUC: 0.6746
# Epoch [1/10], Balance 0.41, Loss: 0.5946, Train ROC AUC: 0.7333
# Epoch [1/10], Balance 0.40, Loss: 0.6206, Train ROC AUC: 0.6565
# Epoch [1/10], Balance 0.42, Loss: 0.5815, Train ROC AUC: 0.7230
# Epoch [1/10], Balance 0.50, Loss: 0.6257, Train ROC AUC: 0.7506
# Epoch [1/10], Balance 0.48, Loss: 0.5950, Train ROC AUC: 0.7647
# Epoch [1/10], Balance 0.36, Loss: 0.5673, Train ROC AUC: 0.7646
# Epoch [1/10], Balance 0.55, Loss: 0.6148, Train ROC AUC: 0.7744
# Epoch [1/10], Balance 0.46, Loss: 0.5912, Train ROC AUC: 0.7494
# Epoch [1/10], Balance 0.46, Loss: 0.6036, Train ROC AUC: 0.7434
# Epoch [1/10], Balance 0.42, Loss: 0.6206, Train ROC AUC: 0.7102
# Epoch [1/10], Balance 0.45, Loss: 0.6040, Train ROC AUC: 0.7264
# Epoch [1/10], Balance 0.48, Loss: 0.6178, Train ROC AUC: 0.6946
# Epoch [1/10], Balance 0.48, Loss: 0.5715, Train ROC AUC: 0.7747
# Epoch [1/10], Balance 0.38, Loss: 0.5496, Train ROC AUC: 0.7737
# Epoch [1/10], Balance 0.44, Loss: 0.5662, Train ROC AUC: 0.7836
# Epoch [1/10], Balance 0.43, Loss: 0.6101, Train ROC AUC: 0.6854
# Epoch [1/10], Balance 0.47, Loss: 0.6097, Train ROC AUC: 0.7032
# Epoch [1/10], Balance 0.46, Loss: 0.6070, Train ROC AUC: 0.7087
# Epoch [1/10], Balance 0.47, Loss: 0.6080, Train ROC AUC: 0.7304
# Epoch [1/10], Balance 0.48, Loss: 0.5841, Train ROC AUC: 0.7751
# Epoch [1/10], Balance 0.45, Loss: 0.5452, Train ROC AUC: 0.8047
# Epoch [1/10], Balance 0.48, Loss: 0.5771, Train ROC AUC: 0.7605
# Epoch [1/10], Balance 0.41, Loss: 0.5812, Train ROC AUC: 0.7550
# Epoch [1/10], Balance 0.41, Loss: 0.5509, Train ROC AUC: 0.7657
# Epoch [1/10], Balance 0.45, Loss: 0.5704, Train ROC AUC: 0.7455
# Epoch [1/10], Balance 0.39, Loss: 0.5196, Train ROC AUC: 0.8088
# Epoch [1/10], Balance 0.51, Loss: 0.5792, Train ROC AUC: 0.7659
# Epoch [1/10], Balance 0.41, Loss: 0.5765, Train ROC AUC: 0.7301
# Epoch [1/10], Balance 0.45, Loss: 0.5820, Train ROC AUC: 0.7581
# Epoch [1/10], Balance 0.40, Loss: 0.5109, Train ROC AUC: 0.8495
# Epoch [1/10], Balance 0.44, Loss: 0.5956, Train ROC AUC: 0.7468
# Epoch [1/10], Balance 0.42, Loss: 0.5808, Train ROC AUC: 0.7481
# Epoch [1/10], Balance 0.43, Loss: 0.6464, Train ROC AUC: 0.6932
# Epoch [1/10], Balance 0.45, Loss: 0.6391, Train ROC AUC: 0.6932
# Epoch [1/10], Balance 0.43, Loss: 0.5648, Train ROC AUC: 0.7676
# Epoch [1/10], Balance 0.35, Loss: 0.5780, Train ROC AUC: 0.7609
# Epoch [1/10], Balance 0.43, Loss: 0.5291, Train ROC AUC: 0.8239
# Epoch [1/10], Balance 0.45, Loss: 0.5921, Train ROC AUC: 0.7428
# Epoch [1/10], Balance 0.51, Loss: 0.6108, Train ROC AUC: 0.7159
# Epoch [1/10], Balance 0.46, Loss: 0.5797, Train ROC AUC: 0.7873
# Epoch [1/10], Balance 0.40, Loss: 0.6014, Train ROC AUC: 0.7297
# Epoch [1/10], Balance 0.34, Loss: 0.5354, Train ROC AUC: 0.8129
# Epoch [1/10], Balance 0.41, Loss: 0.5555, Train ROC AUC: 0.7916
# Epoch [1/10], Balance 0.38, Loss: 0.5335, Train ROC AUC: 0.8003
# Epoch [1/10], Balance 0.41, Loss: 0.5587, Train ROC AUC: 0.7796
# Epoch [1/10], Balance 0.41, Loss: 0.5288, Train ROC AUC: 0.7850
# Epoch [1/10], Balance 0.48, Loss: 0.5113, Train ROC AUC: 0.8116
# Epoch [1/10], Balance 0.33, Loss: 0.5615, Train ROC AUC: 0.8040
# Epoch [1/10], Balance 0.43, Loss: 0.5223, Train ROC AUC: 0.8186
# Epoch [1/10], Balance 0.43, Loss: 0.5164, Train ROC AUC: 0.8394
# Epoch [1/10], Balance 0.44, Loss: 0.5431, Train ROC AUC: 0.7944
# Epoch [1/10], Balance 0.38, Loss: 0.5288, Train ROC AUC: 0.8013
# Epoch [1/10], Balance 0.40, Loss: 0.5064, Train ROC AUC: 0.8228
# Epoch [1/10], Balance 0.41, Loss: 0.6050, Train ROC AUC: 0.7371
# Epoch [1/10], Balance 0.40, Loss: 0.4804, Train ROC AUC: 0.8330
# Epoch [1/10], Balance 0.40, Loss: 0.5478, Train ROC AUC: 0.7751
# Epoch [1/10], Balance 0.41, Loss: 0.5982, Train ROC AUC: 0.7325
# Epoch [1/10], Balance 0.43, Loss: 0.6556, Train ROC AUC: 0.6836
# Epoch [1/10], Balance 0.31, Loss: 0.5635, Train ROC AUC: 0.7270
# Epoch [1/10], Balance 0.36, Loss: 0.5386, Train ROC AUC: 0.7829
# Epoch [1/10], Balance 0.42, Loss: 0.5801, Train ROC AUC: 0.7390
# Epoch [1/10], Balance 0.38, Loss: 0.5180, Train ROC AUC: 0.8078
# Epoch [1/10], Balance 0.33, Loss: 0.4922, Train ROC AUC: 0.7994
# Epoch [1/10], Balance 0.32, Loss: 0.5351, Train ROC AUC: 0.7362
# Epoch [1/10], Balance 0.33, Loss: 0.5078, Train ROC AUC: 0.8283
# Epoch [1/10], Balance 0.34, Loss: 0.5433, Train ROC AUC: 0.7462
# Epoch [1/10], Balance 0.35, Loss: 0.5402, Train ROC AUC: 0.7858
# Epoch [1/10], Balance 0.40, Loss: 0.5206, Train ROC AUC: 0.8004
# Epoch [1/10], Balance 0.34, Loss: 0.5142, Train ROC AUC: 0.7702
# Epoch [1/10], Balance 0.36, Loss: 0.5492, Train ROC AUC: 0.7434
# Epoch [1/10], Balance 0.36, Loss: 0.5640, Train ROC AUC: 0.7134
# Epoch [1/10], Balance 0.39, Loss: 0.5203, Train ROC AUC: 0.8113
# Epoch [1/10], Balance 0.36, Loss: 0.5551, Train ROC AUC: 0.7208
# Epoch [1/10], Balance 0.36, Loss: 0.5085, Train ROC AUC: 0.8073
# Epoch [1/10], Balance 0.29, Loss: 0.5191, Train ROC AUC: 0.7618
#
# Epoch [1/10], Val ROC AUC: 0.7986
#
# Epoch [2/10], Balance 0.55, Loss: 0.6088, Train ROC AUC: 0.7591
# Epoch [2/10], Balance 0.53, Loss: 0.5486, Train ROC AUC: 0.8488
# Epoch [2/10], Balance 0.42, Loss: 0.5513, Train ROC AUC: 0.7945
# Epoch [2/10], Balance 0.38, Loss: 0.5421, Train ROC AUC: 0.7623
# Epoch [2/10], Balance 0.48, Loss: 0.5441, Train ROC AUC: 0.7942
# Epoch [2/10], Balance 0.54, Loss: 0.5123, Train ROC AUC: 0.8190
# Epoch [2/10], Balance 0.52, Loss: 0.5142, Train ROC AUC: 0.8180
# Epoch [2/10], Balance 0.48, Loss: 0.4786, Train ROC AUC: 0.8353
# Epoch [2/10], Balance 0.40, Loss: 0.6449, Train ROC AUC: 0.7479
# Epoch [2/10], Balance 0.41, Loss: 0.5691, Train ROC AUC: 0.8062
# Epoch [2/10], Balance 0.52, Loss: 0.5869, Train ROC AUC: 0.7595
# Epoch [2/10], Balance 0.53, Loss: 0.5618, Train ROC AUC: 0.7483
# Epoch [2/10], Balance 0.48, Loss: 0.5831, Train ROC AUC: 0.7622
# Epoch [2/10], Balance 0.40, Loss: 0.5471, Train ROC AUC: 0.8024
# Epoch [2/10], Balance 0.41, Loss: 0.5840, Train ROC AUC: 0.7517
# Epoch [2/10], Balance 0.46, Loss: 0.5717, Train ROC AUC: 0.7730
# Epoch [2/10], Balance 0.37, Loss: 0.4638, Train ROC AUC: 0.8629
# Epoch [2/10], Balance 0.51, Loss: 0.6437, Train ROC AUC: 0.7357
# Epoch [2/10], Balance 0.52, Loss: 0.6112, Train ROC AUC: 0.7554
# Epoch [2/10], Balance 0.45, Loss: 0.5630, Train ROC AUC: 0.7833
# Epoch [2/10], Balance 0.59, Loss: 0.5838, Train ROC AUC: 0.7947
# Epoch [2/10], Balance 0.43, Loss: 0.5972, Train ROC AUC: 0.7081
# Epoch [2/10], Balance 0.54, Loss: 0.5826, Train ROC AUC: 0.7743
# Epoch [2/10], Balance 0.48, Loss: 0.5016, Train ROC AUC: 0.8547
# Epoch [2/10], Balance 0.42, Loss: 0.5121, Train ROC AUC: 0.8227
# Epoch [2/10], Balance 0.52, Loss: 0.6091, Train ROC AUC: 0.7375
# Epoch [2/10], Balance 0.47, Loss: 0.5629, Train ROC AUC: 0.7771
# Epoch [2/10], Balance 0.40, Loss: 0.6497, Train ROC AUC: 0.6832
# Epoch [2/10], Balance 0.45, Loss: 0.5961, Train ROC AUC: 0.7334
# Epoch [2/10], Balance 0.46, Loss: 0.5800, Train ROC AUC: 0.7458
# Epoch [2/10], Balance 0.51, Loss: 0.5571, Train ROC AUC: 0.7883
# Epoch [2/10], Balance 0.45, Loss: 0.5884, Train ROC AUC: 0.7425
# Epoch [2/10], Balance 0.37, Loss: 0.5469, Train ROC AUC: 0.7977
# Epoch [2/10], Balance 0.52, Loss: 0.5992, Train ROC AUC: 0.7379
# Epoch [2/10], Balance 0.44, Loss: 0.6170, Train ROC AUC: 0.7318
# Epoch [2/10], Balance 0.41, Loss: 0.5752, Train ROC AUC: 0.7667
# Epoch [2/10], Balance 0.39, Loss: 0.5537, Train ROC AUC: 0.7736
# Epoch [2/10], Balance 0.33, Loss: 0.5088, Train ROC AUC: 0.8203
# Epoch [2/10], Balance 0.43, Loss: 0.5454, Train ROC AUC: 0.8139
# Epoch [2/10], Balance 0.54, Loss: 0.6176, Train ROC AUC: 0.6987
# Epoch [2/10], Balance 0.39, Loss: 0.5571, Train ROC AUC: 0.7769
# Epoch [2/10], Balance 0.43, Loss: 0.5495, Train ROC AUC: 0.7790
# Epoch [2/10], Balance 0.34, Loss: 0.5516, Train ROC AUC: 0.7562
# Epoch [2/10], Balance 0.40, Loss: 0.5496, Train ROC AUC: 0.8018
# Epoch [2/10], Balance 0.46, Loss: 0.5500, Train ROC AUC: 0.8141
# Epoch [2/10], Balance 0.44, Loss: 0.5342, Train ROC AUC: 0.8315
# Epoch [2/10], Balance 0.41, Loss: 0.5513, Train ROC AUC: 0.7705
# Epoch [2/10], Balance 0.52, Loss: 0.6150, Train ROC AUC: 0.7345
# Epoch [2/10], Balance 0.41, Loss: 0.5454, Train ROC AUC: 0.7894
# Epoch [2/10], Balance 0.42, Loss: 0.5677, Train ROC AUC: 0.7663
# Epoch [2/10], Balance 0.41, Loss: 0.5498, Train ROC AUC: 0.7585
# Epoch [2/10], Balance 0.44, Loss: 0.5566, Train ROC AUC: 0.7758
# Epoch [2/10], Balance 0.50, Loss: 0.6432, Train ROC AUC: 0.7030
# Epoch [2/10], Balance 0.41, Loss: 0.4945, Train ROC AUC: 0.8381
# Epoch [2/10], Balance 0.48, Loss: 0.5691, Train ROC AUC: 0.7781
# Epoch [2/10], Balance 0.47, Loss: 0.4737, Train ROC AUC: 0.8821
# Epoch [2/10], Balance 0.41, Loss: 0.5647, Train ROC AUC: 0.7710
# Epoch [2/10], Balance 0.47, Loss: 0.5490, Train ROC AUC: 0.8061
# Epoch [2/10], Balance 0.43, Loss: 0.6442, Train ROC AUC: 0.7042
# Epoch [2/10], Balance 0.46, Loss: 0.5748, Train ROC AUC: 0.7507
# Epoch [2/10], Balance 0.45, Loss: 0.5283, Train ROC AUC: 0.7984
# Epoch [2/10], Balance 0.38, Loss: 0.5593, Train ROC AUC: 0.7623
# Epoch [2/10], Balance 0.41, Loss: 0.5634, Train ROC AUC: 0.7530
# Epoch [2/10], Balance 0.42, Loss: 0.5606, Train ROC AUC: 0.7723
# Epoch [2/10], Balance 0.41, Loss: 0.4988, Train ROC AUC: 0.8267
# Epoch [2/10], Balance 0.48, Loss: 0.5860, Train ROC AUC: 0.7778
# Epoch [2/10], Balance 0.39, Loss: 0.5548, Train ROC AUC: 0.7564
# Epoch [2/10], Balance 0.39, Loss: 0.5221, Train ROC AUC: 0.8059
# Epoch [2/10], Balance 0.41, Loss: 0.5619, Train ROC AUC: 0.7587
# Epoch [2/10], Balance 0.38, Loss: 0.5014, Train ROC AUC: 0.8295
# Epoch [2/10], Balance 0.47, Loss: 0.6033, Train ROC AUC: 0.7472
# Epoch [2/10], Balance 0.41, Loss: 0.5699, Train ROC AUC: 0.7551
# Epoch [2/10], Balance 0.40, Loss: 0.5375, Train ROC AUC: 0.7886
# Epoch [2/10], Balance 0.45, Loss: 0.5530, Train ROC AUC: 0.7672
# Epoch [2/10], Balance 0.39, Loss: 0.4820, Train ROC AUC: 0.8353
# Epoch [2/10], Balance 0.41, Loss: 0.6179, Train ROC AUC: 0.7112
# Epoch [2/10], Balance 0.47, Loss: 0.5031, Train ROC AUC: 0.8292
# Epoch [2/10], Balance 0.45, Loss: 0.4755, Train ROC AUC: 0.8578
# Epoch [2/10], Balance 0.36, Loss: 0.5211, Train ROC AUC: 0.8022
# Epoch [2/10], Balance 0.44, Loss: 0.5258, Train ROC AUC: 0.7912
# Epoch [2/10], Balance 0.41, Loss: 0.5081, Train ROC AUC: 0.8153
# Epoch [2/10], Balance 0.35, Loss: 0.5762, Train ROC AUC: 0.7507
# Epoch [2/10], Balance 0.51, Loss: 0.4692, Train ROC AUC: 0.8493
# Epoch [2/10], Balance 0.40, Loss: 0.6218, Train ROC AUC: 0.7023
# Epoch [2/10], Balance 0.41, Loss: 0.5731, Train ROC AUC: 0.7725
# Epoch [2/10], Balance 0.41, Loss: 0.5415, Train ROC AUC: 0.7791
# Epoch [2/10], Balance 0.30, Loss: 0.5898, Train ROC AUC: 0.7417
#
# Epoch [2/10], Val ROC AUC: 0.8097
#
# Epoch [3/10], Balance 0.41, Loss: 0.5319, Train ROC AUC: 0.7904
# Epoch [3/10], Balance 0.52, Loss: 0.6774, Train ROC AUC: 0.6940
# Epoch [3/10], Balance 0.48, Loss: 0.5447, Train ROC AUC: 0.8045
# Epoch [3/10], Balance 0.48, Loss: 0.5484, Train ROC AUC: 0.7621
# Epoch [3/10], Balance 0.52, Loss: 0.6198, Train ROC AUC: 0.7554
# Epoch [3/10], Balance 0.44, Loss: 0.5121, Train ROC AUC: 0.8428
# Epoch [3/10], Balance 0.45, Loss: 0.5128, Train ROC AUC: 0.8537
# Epoch [3/10], Balance 0.50, Loss: 0.5664, Train ROC AUC: 0.7759
# Epoch [3/10], Balance 0.47, Loss: 0.5693, Train ROC AUC: 0.7638
# Epoch [3/10], Balance 0.47, Loss: 0.5680, Train ROC AUC: 0.7870
# Epoch [3/10], Balance 0.47, Loss: 0.4867, Train ROC AUC: 0.8667
# Epoch [3/10], Balance 0.50, Loss: 0.5998, Train ROC AUC: 0.7502
# Epoch [3/10], Balance 0.52, Loss: 0.5385, Train ROC AUC: 0.8043
# Epoch [3/10], Balance 0.47, Loss: 0.5602, Train ROC AUC: 0.7958
# Epoch [3/10], Balance 0.48, Loss: 0.5248, Train ROC AUC: 0.8426
# Epoch [3/10], Balance 0.53, Loss: 0.5310, Train ROC AUC: 0.8120
# Epoch [3/10], Balance 0.49, Loss: 0.5900, Train ROC AUC: 0.7499
# Epoch [3/10], Balance 0.48, Loss: 0.5079, Train ROC AUC: 0.8341
# Epoch [3/10], Balance 0.49, Loss: 0.5869, Train ROC AUC: 0.7590
# Epoch [3/10], Balance 0.43, Loss: 0.6495, Train ROC AUC: 0.7258
# Epoch [3/10], Balance 0.48, Loss: 0.5654, Train ROC AUC: 0.7782
# Epoch [3/10], Balance 0.51, Loss: 0.5838, Train ROC AUC: 0.7713
# Epoch [3/10], Balance 0.48, Loss: 0.5845, Train ROC AUC: 0.7557
# Epoch [3/10], Balance 0.45, Loss: 0.6047, Train ROC AUC: 0.7167
# Epoch [3/10], Balance 0.38, Loss: 0.4835, Train ROC AUC: 0.8579
# Epoch [3/10], Balance 0.47, Loss: 0.5448, Train ROC AUC: 0.7880
# Epoch [3/10], Balance 0.49, Loss: 0.5903, Train ROC AUC: 0.7426
# Epoch [3/10], Balance 0.38, Loss: 0.5663, Train ROC AUC: 0.7285
# Epoch [3/10], Balance 0.41, Loss: 0.5442, Train ROC AUC: 0.7902
# Epoch [3/10], Balance 0.47, Loss: 0.4957, Train ROC AUC: 0.8674
# Epoch [3/10], Balance 0.47, Loss: 0.5292, Train ROC AUC: 0.8080
# Epoch [3/10], Balance 0.37, Loss: 0.5918, Train ROC AUC: 0.7549
# Epoch [3/10], Balance 0.52, Loss: 0.5811, Train ROC AUC: 0.7385
# Epoch [3/10], Balance 0.41, Loss: 0.5997, Train ROC AUC: 0.7152
# Epoch [3/10], Balance 0.40, Loss: 0.5676, Train ROC AUC: 0.7497
# Epoch [3/10], Balance 0.40, Loss: 0.4772, Train ROC AUC: 0.8718
# Epoch [3/10], Balance 0.41, Loss: 0.5647, Train ROC AUC: 0.7731
# Epoch [3/10], Balance 0.47, Loss: 0.5431, Train ROC AUC: 0.8100
# Epoch [3/10], Balance 0.39, Loss: 0.4904, Train ROC AUC: 0.8371
# Epoch [3/10], Balance 0.45, Loss: 0.5521, Train ROC AUC: 0.7808
# Epoch [3/10], Balance 0.42, Loss: 0.5150, Train ROC AUC: 0.8157
# Epoch [3/10], Balance 0.42, Loss: 0.5010, Train ROC AUC: 0.8234
# Epoch [3/10], Balance 0.48, Loss: 0.5304, Train ROC AUC: 0.7937
# Epoch [3/10], Balance 0.45, Loss: 0.4185, Train ROC AUC: 0.9014
# Epoch [3/10], Balance 0.39, Loss: 0.5200, Train ROC AUC: 0.7979
# Epoch [3/10], Balance 0.48, Loss: 0.6154, Train ROC AUC: 0.7487
# Epoch [3/10], Balance 0.42, Loss: 0.4630, Train ROC AUC: 0.8574
# Epoch [3/10], Balance 0.37, Loss: 0.5348, Train ROC AUC: 0.7938
# Epoch [3/10], Balance 0.43, Loss: 0.4790, Train ROC AUC: 0.8431
# Epoch [3/10], Balance 0.34, Loss: 0.5055, Train ROC AUC: 0.8252
# Epoch [3/10], Balance 0.51, Loss: 0.5116, Train ROC AUC: 0.8421
# Epoch [3/10], Balance 0.42, Loss: 0.5125, Train ROC AUC: 0.8013
# Epoch [3/10], Balance 0.46, Loss: 0.5282, Train ROC AUC: 0.7945
# Epoch [3/10], Balance 0.38, Loss: 0.4933, Train ROC AUC: 0.8313
# Epoch [3/10], Balance 0.38, Loss: 0.4976, Train ROC AUC: 0.8234
# Epoch [3/10], Balance 0.45, Loss: 0.5770, Train ROC AUC: 0.7907
# Epoch [3/10], Balance 0.38, Loss: 0.4703, Train ROC AUC: 0.8402
# Epoch [3/10], Balance 0.47, Loss: 0.5117, Train ROC AUC: 0.8382
# Epoch [3/10], Balance 0.43, Loss: 0.5366, Train ROC AUC: 0.8187
# Epoch [3/10], Balance 0.48, Loss: 0.5702, Train ROC AUC: 0.7793
# Epoch [3/10], Balance 0.45, Loss: 0.4648, Train ROC AUC: 0.8643
# Epoch [3/10], Balance 0.45, Loss: 0.5554, Train ROC AUC: 0.7734
# Epoch [3/10], Balance 0.43, Loss: 0.5302, Train ROC AUC: 0.7910
# Epoch [3/10], Balance 0.42, Loss: 0.5425, Train ROC AUC: 0.7853
# Epoch [3/10], Balance 0.49, Loss: 0.5945, Train ROC AUC: 0.7543
# Epoch [3/10], Balance 0.40, Loss: 0.5420, Train ROC AUC: 0.8032
# Epoch [3/10], Balance 0.41, Loss: 0.4923, Train ROC AUC: 0.8286
# Epoch [3/10], Balance 0.42, Loss: 0.5034, Train ROC AUC: 0.8081
# Epoch [3/10], Balance 0.44, Loss: 0.5221, Train ROC AUC: 0.8065
# Epoch [3/10], Balance 0.41, Loss: 0.4728, Train ROC AUC: 0.8756
# Epoch [3/10], Balance 0.43, Loss: 0.4861, Train ROC AUC: 0.8196
# Epoch [3/10], Balance 0.37, Loss: 0.5423, Train ROC AUC: 0.7909
# Epoch [3/10], Balance 0.45, Loss: 0.5332, Train ROC AUC: 0.8102
# Epoch [3/10], Balance 0.40, Loss: 0.4882, Train ROC AUC: 0.8556
# Epoch [3/10], Balance 0.42, Loss: 0.5536, Train ROC AUC: 0.7589
# Epoch [3/10], Balance 0.45, Loss: 0.6111, Train ROC AUC: 0.7007
# Epoch [3/10], Balance 0.40, Loss: 0.5383, Train ROC AUC: 0.8039
# Epoch [3/10], Balance 0.36, Loss: 0.5100, Train ROC AUC: 0.8026
# Epoch [3/10], Balance 0.35, Loss: 0.4680, Train ROC AUC: 0.8760
# Epoch [3/10], Balance 0.38, Loss: 0.4606, Train ROC AUC: 0.8393
# Epoch [3/10], Balance 0.44, Loss: 0.5392, Train ROC AUC: 0.7845
# Epoch [3/10], Balance 0.40, Loss: 0.5651, Train ROC AUC: 0.7476
# Epoch [3/10], Balance 0.35, Loss: 0.4978, Train ROC AUC: 0.8091
# Epoch [3/10], Balance 0.41, Loss: 0.5119, Train ROC AUC: 0.8106
# Epoch [3/10], Balance 0.30, Loss: 0.4816, Train ROC AUC: 0.8328
# Epoch [3/10], Balance 0.34, Loss: 0.5787, Train ROC AUC: 0.7234
# Epoch [3/10], Balance 0.41, Loss: 0.5278, Train ROC AUC: 0.7887
# Epoch [3/10], Balance 0.45, Loss: 0.5306, Train ROC AUC: 0.8175
# Epoch [3/10], Balance 0.38, Loss: 0.5585, Train ROC AUC: 0.7654
# Epoch [3/10], Balance 0.34, Loss: 0.5162, Train ROC AUC: 0.7900
# Epoch [3/10], Balance 0.45, Loss: 0.6250, Train ROC AUC: 0.7172
# Epoch [3/10], Balance 0.38, Loss: 0.5275, Train ROC AUC: 0.7964
# Epoch [3/10], Balance 0.30, Loss: 0.5683, Train ROC AUC: 0.6943
#
# Epoch [3/10], Val ROC AUC: 0.8231
#
# Epoch [4/10], Balance 0.38, Loss: 0.5144, Train ROC AUC: 0.8180
# Epoch [4/10], Balance 0.52, Loss: 0.5641, Train ROC AUC: 0.8095
# Epoch [4/10], Balance 0.58, Loss: 0.5087, Train ROC AUC: 0.8660
# Epoch [4/10], Balance 0.52, Loss: 0.5926, Train ROC AUC: 0.7586
# Epoch [4/10], Balance 0.47, Loss: 0.5374, Train ROC AUC: 0.7821
# Epoch [4/10], Balance 0.38, Loss: 0.5677, Train ROC AUC: 0.7277
# Epoch [4/10], Balance 0.50, Loss: 0.5424, Train ROC AUC: 0.8280
# Epoch [4/10], Balance 0.56, Loss: 0.4810, Train ROC AUC: 0.8723
# Epoch [4/10], Balance 0.43, Loss: 0.5185, Train ROC AUC: 0.8214
# Epoch [4/10], Balance 0.50, Loss: 0.4676, Train ROC AUC: 0.8635
# Epoch [4/10], Balance 0.43, Loss: 0.5601, Train ROC AUC: 0.7995
# Epoch [4/10], Balance 0.45, Loss: 0.5179, Train ROC AUC: 0.8158
# Epoch [4/10], Balance 0.44, Loss: 0.5218, Train ROC AUC: 0.8167
# Epoch [4/10], Balance 0.52, Loss: 0.4869, Train ROC AUC: 0.8348
# Epoch [4/10], Balance 0.52, Loss: 0.5462, Train ROC AUC: 0.8311
# Epoch [4/10], Balance 0.52, Loss: 0.4951, Train ROC AUC: 0.8414
# Epoch [4/10], Balance 0.44, Loss: 0.5356, Train ROC AUC: 0.8105
# Epoch [4/10], Balance 0.48, Loss: 0.4661, Train ROC AUC: 0.8658
# Epoch [4/10], Balance 0.44, Loss: 0.5078, Train ROC AUC: 0.7989
# Epoch [4/10], Balance 0.45, Loss: 0.5287, Train ROC AUC: 0.7947
# Epoch [4/10], Balance 0.47, Loss: 0.5542, Train ROC AUC: 0.7689
# Epoch [4/10], Balance 0.49, Loss: 0.4979, Train ROC AUC: 0.8286
# Epoch [4/10], Balance 0.43, Loss: 0.5102, Train ROC AUC: 0.8318
# Epoch [4/10], Balance 0.48, Loss: 0.4922, Train ROC AUC: 0.8544
# Epoch [4/10], Balance 0.45, Loss: 0.5805, Train ROC AUC: 0.7739
# Epoch [4/10], Balance 0.49, Loss: 0.5858, Train ROC AUC: 0.7917
# Epoch [4/10], Balance 0.50, Loss: 0.5421, Train ROC AUC: 0.8103
# Epoch [4/10], Balance 0.45, Loss: 0.5143, Train ROC AUC: 0.8140
# Epoch [4/10], Balance 0.43, Loss: 0.5549, Train ROC AUC: 0.7870
# Epoch [4/10], Balance 0.38, Loss: 0.5604, Train ROC AUC: 0.7966
# Epoch [4/10], Balance 0.44, Loss: 0.5698, Train ROC AUC: 0.7599
# Epoch [4/10], Balance 0.47, Loss: 0.5452, Train ROC AUC: 0.7895
# Epoch [4/10], Balance 0.38, Loss: 0.5035, Train ROC AUC: 0.8366
# Epoch [4/10], Balance 0.41, Loss: 0.5182, Train ROC AUC: 0.8072
# Epoch [4/10], Balance 0.38, Loss: 0.4763, Train ROC AUC: 0.8632
# Epoch [4/10], Balance 0.41, Loss: 0.4974, Train ROC AUC: 0.8426
# Epoch [4/10], Balance 0.41, Loss: 0.5754, Train ROC AUC: 0.7470
# Epoch [4/10], Balance 0.46, Loss: 0.5057, Train ROC AUC: 0.8277
# Epoch [4/10], Balance 0.46, Loss: 0.5492, Train ROC AUC: 0.8086
# Epoch [4/10], Balance 0.51, Loss: 0.5304, Train ROC AUC: 0.8143
# Epoch [4/10], Balance 0.46, Loss: 0.6416, Train ROC AUC: 0.7302
# Epoch [4/10], Balance 0.43, Loss: 0.5380, Train ROC AUC: 0.7803
# Epoch [4/10], Balance 0.38, Loss: 0.5035, Train ROC AUC: 0.8174
# Epoch [4/10], Balance 0.40, Loss: 0.5928, Train ROC AUC: 0.7394
# Epoch [4/10], Balance 0.45, Loss: 0.5627, Train ROC AUC: 0.7433
# Epoch [4/10], Balance 0.51, Loss: 0.5276, Train ROC AUC: 0.8159
# Epoch [4/10], Balance 0.47, Loss: 0.5127, Train ROC AUC: 0.8164
# Epoch [4/10], Balance 0.46, Loss: 0.5179, Train ROC AUC: 0.7986
# Epoch [4/10], Balance 0.41, Loss: 0.5591, Train ROC AUC: 0.7594
# Epoch [4/10], Balance 0.44, Loss: 0.5188, Train ROC AUC: 0.8276
# Epoch [4/10], Balance 0.39, Loss: 0.4962, Train ROC AUC: 0.8087
# Epoch [4/10], Balance 0.44, Loss: 0.5963, Train ROC AUC: 0.7571
# Epoch [4/10], Balance 0.44, Loss: 0.5571, Train ROC AUC: 0.7938
# Epoch [4/10], Balance 0.49, Loss: 0.6427, Train ROC AUC: 0.6919
# Epoch [4/10], Balance 0.45, Loss: 0.5322, Train ROC AUC: 0.7797
# Epoch [4/10], Balance 0.46, Loss: 0.5030, Train ROC AUC: 0.8000
# Epoch [4/10], Balance 0.43, Loss: 0.5591, Train ROC AUC: 0.7613
# Epoch [4/10], Balance 0.38, Loss: 0.5085, Train ROC AUC: 0.8079
# Epoch [4/10], Balance 0.44, Loss: 0.5076, Train ROC AUC: 0.8483
# Epoch [4/10], Balance 0.44, Loss: 0.5306, Train ROC AUC: 0.8201
# Epoch [4/10], Balance 0.38, Loss: 0.5204, Train ROC AUC: 0.7941
# Epoch [4/10], Balance 0.41, Loss: 0.4796, Train ROC AUC: 0.8468
# Epoch [4/10], Balance 0.42, Loss: 0.4823, Train ROC AUC: 0.8276
# Epoch [4/10], Balance 0.36, Loss: 0.5509, Train ROC AUC: 0.7606
# Epoch [4/10], Balance 0.49, Loss: 0.6017, Train ROC AUC: 0.7745
# Epoch [4/10], Balance 0.43, Loss: 0.6117, Train ROC AUC: 0.7268
# Epoch [4/10], Balance 0.42, Loss: 0.5583, Train ROC AUC: 0.7452
# Epoch [4/10], Balance 0.41, Loss: 0.5509, Train ROC AUC: 0.7694
# Epoch [4/10], Balance 0.38, Loss: 0.5108, Train ROC AUC: 0.8059
# Epoch [4/10], Balance 0.37, Loss: 0.5604, Train ROC AUC: 0.7699
# Epoch [4/10], Balance 0.42, Loss: 0.5367, Train ROC AUC: 0.7798
# Epoch [4/10], Balance 0.41, Loss: 0.5429, Train ROC AUC: 0.7835
# Epoch [4/10], Balance 0.38, Loss: 0.5451, Train ROC AUC: 0.8007
# Epoch [4/10], Balance 0.42, Loss: 0.5465, Train ROC AUC: 0.7820
# Epoch [4/10], Balance 0.38, Loss: 0.5337, Train ROC AUC: 0.7618
# Epoch [4/10], Balance 0.45, Loss: 0.5924, Train ROC AUC: 0.7714
# Epoch [4/10], Balance 0.41, Loss: 0.5181, Train ROC AUC: 0.8003
# Epoch [4/10], Balance 0.38, Loss: 0.5051, Train ROC AUC: 0.8197
# Epoch [4/10], Balance 0.42, Loss: 0.5026, Train ROC AUC: 0.7967
# Epoch [4/10], Balance 0.34, Loss: 0.4984, Train ROC AUC: 0.8138
# Epoch [4/10], Balance 0.37, Loss: 0.5827, Train ROC AUC: 0.7121
# Epoch [4/10], Balance 0.36, Loss: 0.5155, Train ROC AUC: 0.8441
# Epoch [4/10], Balance 0.37, Loss: 0.5150, Train ROC AUC: 0.7941
# Epoch [4/10], Balance 0.37, Loss: 0.4593, Train ROC AUC: 0.8513
# Epoch [4/10], Balance 0.35, Loss: 0.4480, Train ROC AUC: 0.8648
# Epoch [4/10], Balance 0.33, Loss: 0.4869, Train ROC AUC: 0.8167
# Epoch [4/10], Balance 0.42, Loss: 0.4558, Train ROC AUC: 0.8692
# Epoch [4/10], Balance 0.38, Loss: 0.5351, Train ROC AUC: 0.7957
# Epoch [4/10], Balance 0.41, Loss: 0.4827, Train ROC AUC: 0.8224
# Epoch [4/10], Balance 0.38, Loss: 0.4917, Train ROC AUC: 0.7928
# Epoch [4/10], Balance 0.39, Loss: 0.5455, Train ROC AUC: 0.7741
# Epoch [4/10], Balance 0.46, Loss: 0.5529, Train ROC AUC: 0.7944
# Epoch [4/10], Balance 0.30, Loss: 0.4441, Train ROC AUC: 0.8657
# Epoch [4/10], Balance 0.38, Loss: 0.6198, Train ROC AUC: 0.7312
# Epoch [4/10], Balance 0.31, Loss: 0.4621, Train ROC AUC: 0.8415
# Epoch [4/10], Balance 0.36, Loss: 0.4472, Train ROC AUC: 0.8535
# Epoch [4/10], Balance 0.32, Loss: 0.5032, Train ROC AUC: 0.7881
# Epoch [4/10], Balance 0.34, Loss: 0.4485, Train ROC AUC: 0.8497
# Epoch [4/10], Balance 0.38, Loss: 0.4939, Train ROC AUC: 0.8445
# Epoch [4/10], Balance 0.38, Loss: 0.5012, Train ROC AUC: 0.8151
# Epoch [4/10], Balance 0.40, Loss: 0.4603, Train ROC AUC: 0.8685
# Epoch [4/10], Balance 0.32, Loss: 0.5168, Train ROC AUC: 0.7925
# Epoch [4/10], Balance 0.36, Loss: 0.4746, Train ROC AUC: 0.8265
# Epoch [4/10], Balance 0.26, Loss: 0.4892, Train ROC AUC: 0.8080
#
# Epoch [4/10], Val ROC AUC: 0.8420
#
# Epoch [5/10], Balance 0.45, Loss: 0.4856, Train ROC AUC: 0.8616
# Epoch [5/10], Balance 0.41, Loss: 0.5674, Train ROC AUC: 0.7449
# Epoch [5/10], Balance 0.53, Loss: 0.5609, Train ROC AUC: 0.8110
# Epoch [5/10], Balance 0.45, Loss: 0.5488, Train ROC AUC: 0.7814
# Epoch [5/10], Balance 0.46, Loss: 0.4497, Train ROC AUC: 0.8820
# Epoch [5/10], Balance 0.43, Loss: 0.5476, Train ROC AUC: 0.7813
# Epoch [5/10], Balance 0.41, Loss: 0.4717, Train ROC AUC: 0.8472
# Epoch [5/10], Balance 0.48, Loss: 0.5325, Train ROC AUC: 0.8199
# Epoch [5/10], Balance 0.50, Loss: 0.5121, Train ROC AUC: 0.8147
# Epoch [5/10], Balance 0.56, Loss: 0.4385, Train ROC AUC: 0.8909
# Epoch [5/10], Balance 0.50, Loss: 0.5496, Train ROC AUC: 0.7888
# Epoch [5/10], Balance 0.46, Loss: 0.5214, Train ROC AUC: 0.8133
# Epoch [5/10], Balance 0.54, Loss: 0.5385, Train ROC AUC: 0.8005
# Epoch [5/10], Balance 0.53, Loss: 0.5545, Train ROC AUC: 0.7848
# Epoch [5/10], Balance 0.45, Loss: 0.5273, Train ROC AUC: 0.8226
# Epoch [5/10], Balance 0.52, Loss: 0.4785, Train ROC AUC: 0.8514
# Epoch [5/10], Balance 0.43, Loss: 0.5485, Train ROC AUC: 0.8007
# Epoch [5/10], Balance 0.47, Loss: 0.5208, Train ROC AUC: 0.8176
# Epoch [5/10], Balance 0.42, Loss: 0.5461, Train ROC AUC: 0.8086
# Epoch [5/10], Balance 0.41, Loss: 0.5018, Train ROC AUC: 0.8342
# Epoch [5/10], Balance 0.52, Loss: 0.5486, Train ROC AUC: 0.7952
# Epoch [5/10], Balance 0.52, Loss: 0.6157, Train ROC AUC: 0.7529
# Epoch [5/10], Balance 0.52, Loss: 0.5239, Train ROC AUC: 0.8394
# Epoch [5/10], Balance 0.48, Loss: 0.5089, Train ROC AUC: 0.8326
# Epoch [5/10], Balance 0.45, Loss: 0.5603, Train ROC AUC: 0.7897
# Epoch [5/10], Balance 0.48, Loss: 0.5199, Train ROC AUC: 0.8233
# Epoch [5/10], Balance 0.50, Loss: 0.4576, Train ROC AUC: 0.8704
# Epoch [5/10], Balance 0.53, Loss: 0.5233, Train ROC AUC: 0.8056
# Epoch [5/10], Balance 0.44, Loss: 0.5299, Train ROC AUC: 0.8197
# Epoch [5/10], Balance 0.50, Loss: 0.4981, Train ROC AUC: 0.8625
# Epoch [5/10], Balance 0.50, Loss: 0.5472, Train ROC AUC: 0.7871
# Epoch [5/10], Balance 0.46, Loss: 0.5541, Train ROC AUC: 0.7612
# Epoch [5/10], Balance 0.38, Loss: 0.5193, Train ROC AUC: 0.8106
# Epoch [5/10], Balance 0.50, Loss: 0.4670, Train ROC AUC: 0.8582
# Epoch [5/10], Balance 0.40, Loss: 0.5008, Train ROC AUC: 0.8286
# Epoch [5/10], Balance 0.52, Loss: 0.5190, Train ROC AUC: 0.8019
# Epoch [5/10], Balance 0.34, Loss: 0.4913, Train ROC AUC: 0.8225
# Epoch [5/10], Balance 0.43, Loss: 0.4974, Train ROC AUC: 0.8274
# Epoch [5/10], Balance 0.49, Loss: 0.5595, Train ROC AUC: 0.7932
# Epoch [5/10], Balance 0.41, Loss: 0.5245, Train ROC AUC: 0.8214
# Epoch [5/10], Balance 0.46, Loss: 0.5878, Train ROC AUC: 0.7381
# Epoch [5/10], Balance 0.43, Loss: 0.4940, Train ROC AUC: 0.8379
# Epoch [5/10], Balance 0.52, Loss: 0.5158, Train ROC AUC: 0.8193
# Epoch [5/10], Balance 0.46, Loss: 0.4703, Train ROC AUC: 0.8767
# Epoch [5/10], Balance 0.39, Loss: 0.4569, Train ROC AUC: 0.8754
# Epoch [5/10], Balance 0.42, Loss: 0.5266, Train ROC AUC: 0.8143
# Epoch [5/10], Balance 0.38, Loss: 0.4936, Train ROC AUC: 0.8432
# Epoch [5/10], Balance 0.44, Loss: 0.4884, Train ROC AUC: 0.8323
# Epoch [5/10], Balance 0.41, Loss: 0.4693, Train ROC AUC: 0.8491
# Epoch [5/10], Balance 0.41, Loss: 0.5101, Train ROC AUC: 0.8167
# Epoch [5/10], Balance 0.44, Loss: 0.5274, Train ROC AUC: 0.8048
# Epoch [5/10], Balance 0.42, Loss: 0.5053, Train ROC AUC: 0.8400
# Epoch [5/10], Balance 0.44, Loss: 0.5482, Train ROC AUC: 0.8058
# Epoch [5/10], Balance 0.41, Loss: 0.4778, Train ROC AUC: 0.8462
# Epoch [5/10], Balance 0.39, Loss: 0.4917, Train ROC AUC: 0.8226
# Epoch [5/10], Balance 0.42, Loss: 0.5364, Train ROC AUC: 0.8038
# Epoch [5/10], Balance 0.48, Loss: 0.5971, Train ROC AUC: 0.7472
# Epoch [5/10], Balance 0.44, Loss: 0.4966, Train ROC AUC: 0.8222
# Epoch [5/10], Balance 0.42, Loss: 0.5492, Train ROC AUC: 0.7818
# Epoch [5/10], Balance 0.42, Loss: 0.5388, Train ROC AUC: 0.7932
# Epoch [5/10], Balance 0.38, Loss: 0.5332, Train ROC AUC: 0.7762
# Epoch [5/10], Balance 0.39, Loss: 0.5234, Train ROC AUC: 0.7990
# Epoch [5/10], Balance 0.47, Loss: 0.4548, Train ROC AUC: 0.8615
# Epoch [5/10], Balance 0.43, Loss: 0.5597, Train ROC AUC: 0.7732
# Epoch [5/10], Balance 0.42, Loss: 0.5069, Train ROC AUC: 0.8316
# Epoch [5/10], Balance 0.40, Loss: 0.5064, Train ROC AUC: 0.8210
# Epoch [5/10], Balance 0.41, Loss: 0.5414, Train ROC AUC: 0.8136
# Epoch [5/10], Balance 0.47, Loss: 0.5006, Train ROC AUC: 0.8485
# Epoch [5/10], Balance 0.34, Loss: 0.5143, Train ROC AUC: 0.7780
# Epoch [5/10], Balance 0.45, Loss: 0.4955, Train ROC AUC: 0.8286
# Epoch [5/10], Balance 0.36, Loss: 0.4341, Train ROC AUC: 0.8773
# Epoch [5/10], Balance 0.45, Loss: 0.5075, Train ROC AUC: 0.8224
# Epoch [5/10], Balance 0.37, Loss: 0.5117, Train ROC AUC: 0.8013
# Epoch [5/10], Balance 0.34, Loss: 0.5135, Train ROC AUC: 0.8029
# Epoch [5/10], Balance 0.41, Loss: 0.5358, Train ROC AUC: 0.8172
# Epoch [5/10], Balance 0.44, Loss: 0.5158, Train ROC AUC: 0.8323
# Epoch [5/10], Balance 0.48, Loss: 0.5474, Train ROC AUC: 0.7832
# Epoch [5/10], Balance 0.41, Loss: 0.5462, Train ROC AUC: 0.7836
# Epoch [5/10], Balance 0.37, Loss: 0.5734, Train ROC AUC: 0.7568
# Epoch [5/10], Balance 0.35, Loss: 0.5686, Train ROC AUC: 0.7368
# Epoch [5/10], Balance 0.45, Loss: 0.5385, Train ROC AUC: 0.7848
# Epoch [5/10], Balance 0.37, Loss: 0.4397, Train ROC AUC: 0.8936
# Epoch [5/10], Balance 0.46, Loss: 0.4724, Train ROC AUC: 0.8821
# Epoch [5/10], Balance 0.37, Loss: 0.4354, Train ROC AUC: 0.8658
# Epoch [5/10], Balance 0.45, Loss: 0.4618, Train ROC AUC: 0.8558
# Epoch [5/10], Balance 0.24, Loss: 0.4114, Train ROC AUC: 0.8829
#
# Epoch [5/10], Val ROC AUC: 0.8490
#
# Epoch [6/10], Balance 0.43, Loss: 0.4873, Train ROC AUC: 0.8389
# Epoch [6/10], Balance 0.48, Loss: 0.5223, Train ROC AUC: 0.8463
# Epoch [6/10], Balance 0.50, Loss: 0.5802, Train ROC AUC: 0.8491
# Epoch [6/10], Balance 0.45, Loss: 0.4647, Train ROC AUC: 0.8594
# Epoch [6/10], Balance 0.47, Loss: 0.6206, Train ROC AUC: 0.7686
# Epoch [6/10], Balance 0.56, Loss: 0.5194, Train ROC AUC: 0.8328
# Epoch [6/10], Balance 0.50, Loss: 0.4854, Train ROC AUC: 0.8308
# Epoch [6/10], Balance 0.47, Loss: 0.5165, Train ROC AUC: 0.8240
# Epoch [6/10], Balance 0.45, Loss: 0.5353, Train ROC AUC: 0.8347
# Epoch [6/10], Balance 0.49, Loss: 0.4863, Train ROC AUC: 0.8491
# Epoch [6/10], Balance 0.41, Loss: 0.5746, Train ROC AUC: 0.7831
# Epoch [6/10], Balance 0.56, Loss: 0.5361, Train ROC AUC: 0.7991
# Epoch [6/10], Balance 0.51, Loss: 0.4747, Train ROC AUC: 0.8653
# Epoch [6/10], Balance 0.55, Loss: 0.5205, Train ROC AUC: 0.8206
# Epoch [6/10], Balance 0.52, Loss: 0.4965, Train ROC AUC: 0.8409
# Epoch [6/10], Balance 0.44, Loss: 0.5051, Train ROC AUC: 0.8239
# Epoch [6/10], Balance 0.41, Loss: 0.5229, Train ROC AUC: 0.7967
# Epoch [6/10], Balance 0.45, Loss: 0.4387, Train ROC AUC: 0.8734
# Epoch [6/10], Balance 0.51, Loss: 0.4897, Train ROC AUC: 0.8589
# Epoch [6/10], Balance 0.45, Loss: 0.4926, Train ROC AUC: 0.8342
# Epoch [6/10], Balance 0.52, Loss: 0.4213, Train ROC AUC: 0.9168
# Epoch [6/10], Balance 0.38, Loss: 0.5480, Train ROC AUC: 0.8099
# Epoch [6/10], Balance 0.51, Loss: 0.6423, Train ROC AUC: 0.7466
# Epoch [6/10], Balance 0.43, Loss: 0.5044, Train ROC AUC: 0.8413
# Epoch [6/10], Balance 0.47, Loss: 0.4742, Train ROC AUC: 0.8495
# Epoch [6/10], Balance 0.45, Loss: 0.5502, Train ROC AUC: 0.7915
# Epoch [6/10], Balance 0.49, Loss: 0.5359, Train ROC AUC: 0.8022
# Epoch [6/10], Balance 0.54, Loss: 0.4662, Train ROC AUC: 0.8629
# Epoch [6/10], Balance 0.47, Loss: 0.5487, Train ROC AUC: 0.7866
# Epoch [6/10], Balance 0.49, Loss: 0.4930, Train ROC AUC: 0.8300
# Epoch [6/10], Balance 0.43, Loss: 0.5343, Train ROC AUC: 0.8214
# Epoch [6/10], Balance 0.40, Loss: 0.5305, Train ROC AUC: 0.8235
# Epoch [6/10], Balance 0.55, Loss: 0.4945, Train ROC AUC: 0.8421
# Epoch [6/10], Balance 0.41, Loss: 0.5104, Train ROC AUC: 0.8353
# Epoch [6/10], Balance 0.43, Loss: 0.5569, Train ROC AUC: 0.7741
# Epoch [6/10], Balance 0.43, Loss: 0.5285, Train ROC AUC: 0.8007
# Epoch [6/10], Balance 0.40, Loss: 0.5199, Train ROC AUC: 0.8144
# Epoch [6/10], Balance 0.50, Loss: 0.4578, Train ROC AUC: 0.8721
# Epoch [6/10], Balance 0.42, Loss: 0.5288, Train ROC AUC: 0.7893
# Epoch [6/10], Balance 0.55, Loss: 0.5452, Train ROC AUC: 0.8443
# Epoch [6/10], Balance 0.49, Loss: 0.4925, Train ROC AUC: 0.8647
# Epoch [6/10], Balance 0.47, Loss: 0.4934, Train ROC AUC: 0.8387
# Epoch [6/10], Balance 0.39, Loss: 0.5314, Train ROC AUC: 0.8078
# Epoch [6/10], Balance 0.44, Loss: 0.5560, Train ROC AUC: 0.7733
# Epoch [6/10], Balance 0.48, Loss: 0.4870, Train ROC AUC: 0.8399
# Epoch [6/10], Balance 0.48, Loss: 0.5459, Train ROC AUC: 0.7918
# Epoch [6/10], Balance 0.45, Loss: 0.5359, Train ROC AUC: 0.7837
# Epoch [6/10], Balance 0.42, Loss: 0.5295, Train ROC AUC: 0.7865
# Epoch [6/10], Balance 0.41, Loss: 0.4947, Train ROC AUC: 0.8155
# Epoch [6/10], Balance 0.45, Loss: 0.4771, Train ROC AUC: 0.8594
# Epoch [6/10], Balance 0.45, Loss: 0.5507, Train ROC AUC: 0.7714
# Epoch [6/10], Balance 0.48, Loss: 0.5202, Train ROC AUC: 0.8214
# Epoch [6/10], Balance 0.42, Loss: 0.5695, Train ROC AUC: 0.7538
# Epoch [6/10], Balance 0.41, Loss: 0.5266, Train ROC AUC: 0.8193
# Epoch [6/10], Balance 0.47, Loss: 0.5734, Train ROC AUC: 0.7593
# Epoch [6/10], Balance 0.36, Loss: 0.4416, Train ROC AUC: 0.8902
# Epoch [6/10], Balance 0.41, Loss: 0.5006, Train ROC AUC: 0.8391
# Epoch [6/10], Balance 0.47, Loss: 0.5334, Train ROC AUC: 0.8265
# Epoch [6/10], Balance 0.46, Loss: 0.5233, Train ROC AUC: 0.8082
# Epoch [6/10], Balance 0.47, Loss: 0.5422, Train ROC AUC: 0.7776
# Epoch [6/10], Balance 0.47, Loss: 0.4816, Train ROC AUC: 0.8471
# Epoch [6/10], Balance 0.43, Loss: 0.5540, Train ROC AUC: 0.8086
# Epoch [6/10], Balance 0.47, Loss: 0.4449, Train ROC AUC: 0.8958
# Epoch [6/10], Balance 0.50, Loss: 0.5566, Train ROC AUC: 0.7964
# Epoch [6/10], Balance 0.38, Loss: 0.5145, Train ROC AUC: 0.8133
# Epoch [6/10], Balance 0.45, Loss: 0.4759, Train ROC AUC: 0.8404
# Epoch [6/10], Balance 0.38, Loss: 0.5059, Train ROC AUC: 0.8138
# Epoch [6/10], Balance 0.45, Loss: 0.4556, Train ROC AUC: 0.8645
# Epoch [6/10], Balance 0.45, Loss: 0.4996, Train ROC AUC: 0.8191
# Epoch [6/10], Balance 0.41, Loss: 0.5178, Train ROC AUC: 0.8205
# Epoch [6/10], Balance 0.41, Loss: 0.5666, Train ROC AUC: 0.7585
# Epoch [6/10], Balance 0.39, Loss: 0.4782, Train ROC AUC: 0.8395
# Epoch [6/10], Balance 0.46, Loss: 0.4818, Train ROC AUC: 0.8396
# Epoch [6/10], Balance 0.44, Loss: 0.5377, Train ROC AUC: 0.7896
# Epoch [6/10], Balance 0.42, Loss: 0.4898, Train ROC AUC: 0.8276
# Epoch [6/10], Balance 0.45, Loss: 0.4561, Train ROC AUC: 0.8663
# Epoch [6/10], Balance 0.41, Loss: 0.5447, Train ROC AUC: 0.8038
# Epoch [6/10], Balance 0.37, Loss: 0.5019, Train ROC AUC: 0.8245
# Epoch [6/10], Balance 0.39, Loss: 0.5299, Train ROC AUC: 0.8028
# Epoch [6/10], Balance 0.38, Loss: 0.4763, Train ROC AUC: 0.8402
# Epoch [6/10], Balance 0.45, Loss: 0.4745, Train ROC AUC: 0.8464
# Epoch [6/10], Balance 0.37, Loss: 0.4730, Train ROC AUC: 0.8471
# Epoch [6/10], Balance 0.35, Loss: 0.4872, Train ROC AUC: 0.8331
# Epoch [6/10], Balance 0.41, Loss: 0.4901, Train ROC AUC: 0.8238
# Epoch [6/10], Balance 0.48, Loss: 0.5640, Train ROC AUC: 0.7783
# Epoch [6/10], Balance 0.39, Loss: 0.4615, Train ROC AUC: 0.8692
# Epoch [6/10], Balance 0.35, Loss: 0.5100, Train ROC AUC: 0.8102
# Epoch [6/10], Balance 0.36, Loss: 0.4866, Train ROC AUC: 0.8260
# Epoch [6/10], Balance 0.39, Loss: 0.4367, Train ROC AUC: 0.8958
# Epoch [6/10], Balance 0.37, Loss: 0.5244, Train ROC AUC: 0.8004
# Epoch [6/10], Balance 0.35, Loss: 0.4479, Train ROC AUC: 0.8525
# Epoch [6/10], Balance 0.41, Loss: 0.5343, Train ROC AUC: 0.8211
# Epoch [6/10], Balance 0.35, Loss: 0.4734, Train ROC AUC: 0.8225
# Epoch [6/10], Balance 0.41, Loss: 0.4945, Train ROC AUC: 0.8292
# Epoch [6/10], Balance 0.30, Loss: 0.4221, Train ROC AUC: 0.8649
#
# Epoch [6/10], Val ROC AUC: 0.8512
#
# Epoch [7/10], Balance 0.56, Loss: 0.5896, Train ROC AUC: 0.8126
# Epoch [7/10], Balance 0.54, Loss: 0.5112, Train ROC AUC: 0.8381
# Epoch [7/10], Balance 0.51, Loss: 0.5780, Train ROC AUC: 0.7800
# Epoch [7/10], Balance 0.48, Loss: 0.5634, Train ROC AUC: 0.7810
# Epoch [7/10], Balance 0.47, Loss: 0.5501, Train ROC AUC: 0.7775
# Epoch [7/10], Balance 0.50, Loss: 0.4721, Train ROC AUC: 0.8655
# Epoch [7/10], Balance 0.57, Loss: 0.5259, Train ROC AUC: 0.7968
# Epoch [7/10], Balance 0.48, Loss: 0.5700, Train ROC AUC: 0.7786
# Epoch [7/10], Balance 0.50, Loss: 0.4913, Train ROC AUC: 0.8655
# Epoch [7/10], Balance 0.42, Loss: 0.5082, Train ROC AUC: 0.8458
# Epoch [7/10], Balance 0.53, Loss: 0.4799, Train ROC AUC: 0.8319
# Epoch [7/10], Balance 0.48, Loss: 0.4505, Train ROC AUC: 0.8693
# Epoch [7/10], Balance 0.49, Loss: 0.5481, Train ROC AUC: 0.7861
# Epoch [7/10], Balance 0.49, Loss: 0.5466, Train ROC AUC: 0.8005
# Epoch [7/10], Balance 0.53, Loss: 0.5603, Train ROC AUC: 0.7953
# Epoch [7/10], Balance 0.49, Loss: 0.4958, Train ROC AUC: 0.8418
# Epoch [7/10], Balance 0.48, Loss: 0.4846, Train ROC AUC: 0.8359
# Epoch [7/10], Balance 0.41, Loss: 0.5219, Train ROC AUC: 0.8229
# Epoch [7/10], Balance 0.50, Loss: 0.5208, Train ROC AUC: 0.8153
# Epoch [7/10], Balance 0.44, Loss: 0.5500, Train ROC AUC: 0.7875
# Epoch [7/10], Balance 0.49, Loss: 0.4567, Train ROC AUC: 0.8742
# Epoch [7/10], Balance 0.54, Loss: 0.4623, Train ROC AUC: 0.8805
# Epoch [7/10], Balance 0.47, Loss: 0.5177, Train ROC AUC: 0.8282
# Epoch [7/10], Balance 0.55, Loss: 0.5044, Train ROC AUC: 0.8374
# Epoch [7/10], Balance 0.40, Loss: 0.5433, Train ROC AUC: 0.8021
# Epoch [7/10], Balance 0.49, Loss: 0.5427, Train ROC AUC: 0.8001
# Epoch [7/10], Balance 0.49, Loss: 0.4946, Train ROC AUC: 0.8252
# Epoch [7/10], Balance 0.47, Loss: 0.5799, Train ROC AUC: 0.7689
# Epoch [7/10], Balance 0.49, Loss: 0.5120, Train ROC AUC: 0.8051
# Epoch [7/10], Balance 0.41, Loss: 0.5481, Train ROC AUC: 0.7904
# Epoch [7/10], Balance 0.45, Loss: 0.4267, Train ROC AUC: 0.8957
# Epoch [7/10], Balance 0.47, Loss: 0.4450, Train ROC AUC: 0.8703
# Epoch [7/10], Balance 0.43, Loss: 0.4431, Train ROC AUC: 0.8786
# Epoch [7/10], Balance 0.51, Loss: 0.4522, Train ROC AUC: 0.8652
# Epoch [7/10], Balance 0.38, Loss: 0.4680, Train ROC AUC: 0.8534
# Epoch [7/10], Balance 0.41, Loss: 0.5536, Train ROC AUC: 0.7566
# Epoch [7/10], Balance 0.42, Loss: 0.3982, Train ROC AUC: 0.8924
# Epoch [7/10], Balance 0.45, Loss: 0.5930, Train ROC AUC: 0.7633
# Epoch [7/10], Balance 0.47, Loss: 0.5891, Train ROC AUC: 0.7740
# Epoch [7/10], Balance 0.51, Loss: 0.5161, Train ROC AUC: 0.8545
# Epoch [7/10], Balance 0.48, Loss: 0.4573, Train ROC AUC: 0.8808
# Epoch [7/10], Balance 0.37, Loss: 0.5850, Train ROC AUC: 0.7748
# Epoch [7/10], Balance 0.41, Loss: 0.5251, Train ROC AUC: 0.7997
# Epoch [7/10], Balance 0.48, Loss: 0.5288, Train ROC AUC: 0.8171
# Epoch [7/10], Balance 0.43, Loss: 0.4910, Train ROC AUC: 0.8403
# Epoch [7/10], Balance 0.50, Loss: 0.4723, Train ROC AUC: 0.8657
# Epoch [7/10], Balance 0.48, Loss: 0.5504, Train ROC AUC: 0.7837
# Epoch [7/10], Balance 0.39, Loss: 0.5140, Train ROC AUC: 0.8200
# Epoch [7/10], Balance 0.36, Loss: 0.5064, Train ROC AUC: 0.8189
# Epoch [7/10], Balance 0.41, Loss: 0.4931, Train ROC AUC: 0.8233
# Epoch [7/10], Balance 0.38, Loss: 0.5637, Train ROC AUC: 0.7743
# Epoch [7/10], Balance 0.37, Loss: 0.5570, Train ROC AUC: 0.7523
# Epoch [7/10], Balance 0.41, Loss: 0.4648, Train ROC AUC: 0.8473
# Epoch [7/10], Balance 0.46, Loss: 0.5176, Train ROC AUC: 0.8339
# Epoch [7/10], Balance 0.50, Loss: 0.5280, Train ROC AUC: 0.8206
# Epoch [7/10], Balance 0.46, Loss: 0.5284, Train ROC AUC: 0.8176
# Epoch [7/10], Balance 0.45, Loss: 0.6455, Train ROC AUC: 0.6969
# Epoch [7/10], Balance 0.36, Loss: 0.5312, Train ROC AUC: 0.7910
# Epoch [7/10], Balance 0.41, Loss: 0.4682, Train ROC AUC: 0.8659
# Epoch [7/10], Balance 0.42, Loss: 0.5116, Train ROC AUC: 0.8268
# Epoch [7/10], Balance 0.39, Loss: 0.5121, Train ROC AUC: 0.7808
# Epoch [7/10], Balance 0.42, Loss: 0.4461, Train ROC AUC: 0.8784
# Epoch [7/10], Balance 0.44, Loss: 0.5203, Train ROC AUC: 0.8052
# Epoch [7/10], Balance 0.39, Loss: 0.4338, Train ROC AUC: 0.9003
# Epoch [7/10], Balance 0.46, Loss: 0.4904, Train ROC AUC: 0.8246
# Epoch [7/10], Balance 0.34, Loss: 0.5593, Train ROC AUC: 0.7934
# Epoch [7/10], Balance 0.50, Loss: 0.4866, Train ROC AUC: 0.8521
# Epoch [7/10], Balance 0.38, Loss: 0.4386, Train ROC AUC: 0.8820
# Epoch [7/10], Balance 0.41, Loss: 0.5450, Train ROC AUC: 0.7947
# Epoch [7/10], Balance 0.42, Loss: 0.5041, Train ROC AUC: 0.8380
# Epoch [7/10], Balance 0.34, Loss: 0.5102, Train ROC AUC: 0.8071
# Epoch [7/10], Balance 0.43, Loss: 0.5770, Train ROC AUC: 0.7450
# Epoch [7/10], Balance 0.34, Loss: 0.4468, Train ROC AUC: 0.8379
# Epoch [7/10], Balance 0.40, Loss: 0.4660, Train ROC AUC: 0.8491
# Epoch [7/10], Balance 0.38, Loss: 0.5843, Train ROC AUC: 0.7458
# Epoch [7/10], Balance 0.41, Loss: 0.4906, Train ROC AUC: 0.8417
# Epoch [7/10], Balance 0.41, Loss: 0.4710, Train ROC AUC: 0.8408
# Epoch [7/10], Balance 0.37, Loss: 0.4496, Train ROC AUC: 0.8631
# Epoch [7/10], Balance 0.40, Loss: 0.5135, Train ROC AUC: 0.8151
# Epoch [7/10], Balance 0.34, Loss: 0.5334, Train ROC AUC: 0.7799
# Epoch [7/10], Balance 0.42, Loss: 0.6206, Train ROC AUC: 0.7583
# Epoch [7/10], Balance 0.38, Loss: 0.4974, Train ROC AUC: 0.7799
# Epoch [7/10], Balance 0.34, Loss: 0.4522, Train ROC AUC: 0.8602
# Epoch [7/10], Balance 0.41, Loss: 0.4948, Train ROC AUC: 0.8262
# Epoch [7/10], Balance 0.34, Loss: 0.4842, Train ROC AUC: 0.8374
# Epoch [7/10], Balance 0.42, Loss: 0.5148, Train ROC AUC: 0.7983
# Epoch [7/10], Balance 0.34, Loss: 0.5259, Train ROC AUC: 0.7683
# Epoch [7/10], Balance 0.38, Loss: 0.4831, Train ROC AUC: 0.8404
# Epoch [7/10], Balance 0.45, Loss: 0.5636, Train ROC AUC: 0.7902
# Epoch [7/10], Balance 0.34, Loss: 0.4476, Train ROC AUC: 0.8477
# Epoch [7/10], Balance 0.40, Loss: 0.4957, Train ROC AUC: 0.8130
# Epoch [7/10], Balance 0.37, Loss: 0.4635, Train ROC AUC: 0.8361
# Epoch [7/10], Balance 0.41, Loss: 0.4720, Train ROC AUC: 0.8564
# Epoch [7/10], Balance 0.38, Loss: 0.5027, Train ROC AUC: 0.8318
# Epoch [7/10], Balance 0.36, Loss: 0.4570, Train ROC AUC: 0.8542
# Epoch [7/10], Balance 0.38, Loss: 0.4867, Train ROC AUC: 0.8151
# Epoch [7/10], Balance 0.33, Loss: 0.4526, Train ROC AUC: 0.8425
# Epoch [7/10], Balance 0.35, Loss: 0.4461, Train ROC AUC: 0.8580
# Epoch [7/10], Balance 0.42, Loss: 0.5366, Train ROC AUC: 0.8073
# Epoch [7/10], Balance 0.34, Loss: 0.4923, Train ROC AUC: 0.8090
# Epoch [7/10], Balance 0.41, Loss: 0.5005, Train ROC AUC: 0.8260
# Epoch [7/10], Balance 0.39, Loss: 0.4855, Train ROC AUC: 0.8350
# Epoch [7/10], Balance 0.35, Loss: 0.4617, Train ROC AUC: 0.8439
# Epoch [7/10], Balance 0.33, Loss: 0.4808, Train ROC AUC: 0.8188
# Epoch [7/10], Balance 0.43, Loss: 0.5441, Train ROC AUC: 0.8019
# Epoch [7/10], Balance 0.38, Loss: 0.5446, Train ROC AUC: 0.7588
# Epoch [7/10], Balance 0.38, Loss: 0.4549, Train ROC AUC: 0.8582
# Epoch [7/10], Balance 0.32, Loss: 0.4556, Train ROC AUC: 0.8567
# Epoch [7/10], Balance 0.34, Loss: 0.5059, Train ROC AUC: 0.8101
# Epoch [7/10], Balance 0.27, Loss: 0.4281, Train ROC AUC: 0.8636
#
# Epoch [7/10], Val ROC AUC: 0.8495
#
# Epoch [8/10], Balance 0.45, Loss: 0.4841, Train ROC AUC: 0.8557
# Epoch [8/10], Balance 0.39, Loss: 0.4627, Train ROC AUC: 0.8329
# Epoch [8/10], Balance 0.46, Loss: 0.6104, Train ROC AUC: 0.7600
# Epoch [8/10], Balance 0.55, Loss: 0.5663, Train ROC AUC: 0.8278
# Epoch [8/10], Balance 0.44, Loss: 0.5564, Train ROC AUC: 0.7830
# Epoch [8/10], Balance 0.48, Loss: 0.4697, Train ROC AUC: 0.8476
# Epoch [8/10], Balance 0.40, Loss: 0.5093, Train ROC AUC: 0.8153
# Epoch [8/10], Balance 0.46, Loss: 0.5247, Train ROC AUC: 0.8047
# Epoch [8/10], Balance 0.46, Loss: 0.4815, Train ROC AUC: 0.8380
# Epoch [8/10], Balance 0.52, Loss: 0.4944, Train ROC AUC: 0.8602
# Epoch [8/10], Balance 0.46, Loss: 0.5323, Train ROC AUC: 0.8099
# Epoch [8/10], Balance 0.52, Loss: 0.4585, Train ROC AUC: 0.8684
# Epoch [8/10], Balance 0.50, Loss: 0.5799, Train ROC AUC: 0.7599
# Epoch [8/10], Balance 0.58, Loss: 0.4882, Train ROC AUC: 0.8168
# Epoch [8/10], Balance 0.51, Loss: 0.4612, Train ROC AUC: 0.8553
# Epoch [8/10], Balance 0.41, Loss: 0.5637, Train ROC AUC: 0.7986
# Epoch [8/10], Balance 0.41, Loss: 0.5245, Train ROC AUC: 0.8273
# Epoch [8/10], Balance 0.52, Loss: 0.4765, Train ROC AUC: 0.8463
# Epoch [8/10], Balance 0.52, Loss: 0.5003, Train ROC AUC: 0.8229
# Epoch [8/10], Balance 0.48, Loss: 0.4350, Train ROC AUC: 0.8786
# Epoch [8/10], Balance 0.52, Loss: 0.5221, Train ROC AUC: 0.8199
# Epoch [8/10], Balance 0.38, Loss: 0.4670, Train ROC AUC: 0.8365
# Epoch [8/10], Balance 0.50, Loss: 0.4854, Train ROC AUC: 0.8544
# Epoch [8/10], Balance 0.41, Loss: 0.4553, Train ROC AUC: 0.8549
# Epoch [8/10], Balance 0.45, Loss: 0.4259, Train ROC AUC: 0.8839
# Epoch [8/10], Balance 0.45, Loss: 0.4487, Train ROC AUC: 0.8826
# Epoch [8/10], Balance 0.47, Loss: 0.5616, Train ROC AUC: 0.7772
# Epoch [8/10], Balance 0.43, Loss: 0.4042, Train ROC AUC: 0.9014
# Epoch [8/10], Balance 0.41, Loss: 0.5389, Train ROC AUC: 0.7878
# Epoch [8/10], Balance 0.48, Loss: 0.4486, Train ROC AUC: 0.8887
# Epoch [8/10], Balance 0.41, Loss: 0.5343, Train ROC AUC: 0.8193
# Epoch [8/10], Balance 0.44, Loss: 0.4275, Train ROC AUC: 0.8844
# Epoch [8/10], Balance 0.51, Loss: 0.4788, Train ROC AUC: 0.8530
# Epoch [8/10], Balance 0.52, Loss: 0.5312, Train ROC AUC: 0.8243
# Epoch [8/10], Balance 0.46, Loss: 0.4757, Train ROC AUC: 0.8467
# Epoch [8/10], Balance 0.48, Loss: 0.5154, Train ROC AUC: 0.8121
# Epoch [8/10], Balance 0.43, Loss: 0.5506, Train ROC AUC: 0.7733
# Epoch [8/10], Balance 0.43, Loss: 0.4756, Train ROC AUC: 0.8376
# Epoch [8/10], Balance 0.43, Loss: 0.4878, Train ROC AUC: 0.8523
# Epoch [8/10], Balance 0.50, Loss: 0.4736, Train ROC AUC: 0.8271
# Epoch [8/10], Balance 0.48, Loss: 0.4617, Train ROC AUC: 0.8583
# Epoch [8/10], Balance 0.39, Loss: 0.4941, Train ROC AUC: 0.8241
# Epoch [8/10], Balance 0.47, Loss: 0.5230, Train ROC AUC: 0.7973
# Epoch [8/10], Balance 0.48, Loss: 0.4288, Train ROC AUC: 0.8913
# Epoch [8/10], Balance 0.42, Loss: 0.4806, Train ROC AUC: 0.8626
# Epoch [8/10], Balance 0.50, Loss: 0.5440, Train ROC AUC: 0.8239
# Epoch [8/10], Balance 0.46, Loss: 0.5211, Train ROC AUC: 0.8457
# Epoch [8/10], Balance 0.38, Loss: 0.4688, Train ROC AUC: 0.8486
# Epoch [8/10], Balance 0.46, Loss: 0.4687, Train ROC AUC: 0.8445
# Epoch [8/10], Balance 0.44, Loss: 0.5742, Train ROC AUC: 0.7619
# Epoch [8/10], Balance 0.43, Loss: 0.5590, Train ROC AUC: 0.7776
# Epoch [8/10], Balance 0.40, Loss: 0.4815, Train ROC AUC: 0.8462
# Epoch [8/10], Balance 0.41, Loss: 0.5133, Train ROC AUC: 0.8117
# Epoch [8/10], Balance 0.41, Loss: 0.5042, Train ROC AUC: 0.8247
# Epoch [8/10], Balance 0.43, Loss: 0.5010, Train ROC AUC: 0.8321
# Epoch [8/10], Balance 0.43, Loss: 0.4218, Train ROC AUC: 0.8988
# Epoch [8/10], Balance 0.40, Loss: 0.4762, Train ROC AUC: 0.8643
# Epoch [8/10], Balance 0.47, Loss: 0.4580, Train ROC AUC: 0.8635
# Epoch [8/10], Balance 0.39, Loss: 0.5256, Train ROC AUC: 0.7956
# Epoch [8/10], Balance 0.44, Loss: 0.4080, Train ROC AUC: 0.8953
# Epoch [8/10], Balance 0.45, Loss: 0.4058, Train ROC AUC: 0.9045
# Epoch [8/10], Balance 0.36, Loss: 0.4524, Train ROC AUC: 0.8596
# Epoch [8/10], Balance 0.46, Loss: 0.5491, Train ROC AUC: 0.8344
# Epoch [8/10], Balance 0.41, Loss: 0.4733, Train ROC AUC: 0.8322
# Epoch [8/10], Balance 0.35, Loss: 0.4956, Train ROC AUC: 0.8103
# Epoch [8/10], Balance 0.40, Loss: 0.4724, Train ROC AUC: 0.8245
# Epoch [8/10], Balance 0.45, Loss: 0.4600, Train ROC AUC: 0.8711
# Epoch [8/10], Balance 0.48, Loss: 0.5766, Train ROC AUC: 0.7824
# Epoch [8/10], Balance 0.43, Loss: 0.5485, Train ROC AUC: 0.7776
# Epoch [8/10], Balance 0.43, Loss: 0.4409, Train ROC AUC: 0.8677
# Epoch [8/10], Balance 0.36, Loss: 0.4905, Train ROC AUC: 0.8216
# Epoch [8/10], Balance 0.42, Loss: 0.4564, Train ROC AUC: 0.8704
# Epoch [8/10], Balance 0.38, Loss: 0.5073, Train ROC AUC: 0.8119
# Epoch [8/10], Balance 0.35, Loss: 0.5216, Train ROC AUC: 0.8013
# Epoch [8/10], Balance 0.35, Loss: 0.4291, Train ROC AUC: 0.8961
# Epoch [8/10], Balance 0.46, Loss: 0.4735, Train ROC AUC: 0.8595
# Epoch [8/10], Balance 0.40, Loss: 0.4318, Train ROC AUC: 0.8645
# Epoch [8/10], Balance 0.34, Loss: 0.5095, Train ROC AUC: 0.8153
# Epoch [8/10], Balance 0.39, Loss: 0.4183, Train ROC AUC: 0.8946
# Epoch [8/10], Balance 0.50, Loss: 0.4968, Train ROC AUC: 0.8673
# Epoch [8/10], Balance 0.36, Loss: 0.5619, Train ROC AUC: 0.7853
# Epoch [8/10], Balance 0.30, Loss: 0.4491, Train ROC AUC: 0.8450
# Epoch [8/10], Balance 0.48, Loss: 0.5156, Train ROC AUC: 0.8614
# Epoch [8/10], Balance 0.38, Loss: 0.5116, Train ROC AUC: 0.8091
# Epoch [8/10], Balance 0.38, Loss: 0.5336, Train ROC AUC: 0.7852
# Epoch [8/10], Balance 0.38, Loss: 0.4718, Train ROC AUC: 0.8466
# Epoch [8/10], Balance 0.40, Loss: 0.4530, Train ROC AUC: 0.8486
# Epoch [8/10], Balance 0.37, Loss: 0.4833, Train ROC AUC: 0.8227
# Epoch [8/10], Balance 0.41, Loss: 0.5255, Train ROC AUC: 0.7914
# Epoch [8/10], Balance 0.44, Loss: 0.5065, Train ROC AUC: 0.8052
# Epoch [8/10], Balance 0.29, Loss: 0.5226, Train ROC AUC: 0.7704
#
# Epoch [8/10], Val ROC AUC: 0.8566
#
# Epoch [9/10], Balance 0.35, Loss: 0.4754, Train ROC AUC: 0.8422
# Epoch [9/10], Balance 0.48, Loss: 0.4893, Train ROC AUC: 0.8724
# Epoch [9/10], Balance 0.53, Loss: 0.5650, Train ROC AUC: 0.8310
# Epoch [9/10], Balance 0.51, Loss: 0.5363, Train ROC AUC: 0.7954
# Epoch [9/10], Balance 0.43, Loss: 0.5060, Train ROC AUC: 0.8222
# Epoch [9/10], Balance 0.55, Loss: 0.4320, Train ROC AUC: 0.8987
# Epoch [9/10], Balance 0.49, Loss: 0.4638, Train ROC AUC: 0.8559
# Epoch [9/10], Balance 0.51, Loss: 0.5046, Train ROC AUC: 0.8165
# Epoch [9/10], Balance 0.52, Loss: 0.4507, Train ROC AUC: 0.8641
# Epoch [9/10], Balance 0.48, Loss: 0.5396, Train ROC AUC: 0.8011
# Epoch [9/10], Balance 0.51, Loss: 0.4893, Train ROC AUC: 0.8452
# Epoch [9/10], Balance 0.44, Loss: 0.5099, Train ROC AUC: 0.8346
# Epoch [9/10], Balance 0.45, Loss: 0.5162, Train ROC AUC: 0.8238
# Epoch [9/10], Balance 0.52, Loss: 0.4799, Train ROC AUC: 0.8571
# Epoch [9/10], Balance 0.44, Loss: 0.5175, Train ROC AUC: 0.8026
# Epoch [9/10], Balance 0.54, Loss: 0.4981, Train ROC AUC: 0.8429
# Epoch [9/10], Balance 0.55, Loss: 0.4946, Train ROC AUC: 0.8211
# Epoch [9/10], Balance 0.51, Loss: 0.4942, Train ROC AUC: 0.8486
# Epoch [9/10], Balance 0.50, Loss: 0.4419, Train ROC AUC: 0.8884
# Epoch [9/10], Balance 0.52, Loss: 0.5028, Train ROC AUC: 0.8458
# Epoch [9/10], Balance 0.44, Loss: 0.4601, Train ROC AUC: 0.8557
# Epoch [9/10], Balance 0.47, Loss: 0.4618, Train ROC AUC: 0.8576
# Epoch [9/10], Balance 0.45, Loss: 0.4208, Train ROC AUC: 0.8841
# Epoch [9/10], Balance 0.47, Loss: 0.4885, Train ROC AUC: 0.8373
# Epoch [9/10], Balance 0.50, Loss: 0.4352, Train ROC AUC: 0.8893
# Epoch [9/10], Balance 0.49, Loss: 0.4973, Train ROC AUC: 0.8228
# Epoch [9/10], Balance 0.50, Loss: 0.4389, Train ROC AUC: 0.8711
# Epoch [9/10], Balance 0.44, Loss: 0.4170, Train ROC AUC: 0.8872
# Epoch [9/10], Balance 0.45, Loss: 0.4565, Train ROC AUC: 0.8628
# Epoch [9/10], Balance 0.44, Loss: 0.4605, Train ROC AUC: 0.8519
# Epoch [9/10], Balance 0.38, Loss: 0.4620, Train ROC AUC: 0.8571
# Epoch [9/10], Balance 0.47, Loss: 0.4785, Train ROC AUC: 0.8331
# Epoch [9/10], Balance 0.47, Loss: 0.4723, Train ROC AUC: 0.8581
# Epoch [9/10], Balance 0.49, Loss: 0.5448, Train ROC AUC: 0.8154
# Epoch [9/10], Balance 0.44, Loss: 0.4428, Train ROC AUC: 0.8638
# Epoch [9/10], Balance 0.50, Loss: 0.5085, Train ROC AUC: 0.8383
# Epoch [9/10], Balance 0.46, Loss: 0.5854, Train ROC AUC: 0.7632
# Epoch [9/10], Balance 0.44, Loss: 0.5336, Train ROC AUC: 0.8106
# Epoch [9/10], Balance 0.39, Loss: 0.5689, Train ROC AUC: 0.7917
# Epoch [9/10], Balance 0.49, Loss: 0.5071, Train ROC AUC: 0.8216
# Epoch [9/10], Balance 0.46, Loss: 0.4888, Train ROC AUC: 0.8163
# Epoch [9/10], Balance 0.45, Loss: 0.5546, Train ROC AUC: 0.7793
# Epoch [9/10], Balance 0.42, Loss: 0.4460, Train ROC AUC: 0.8766
# Epoch [9/10], Balance 0.50, Loss: 0.5145, Train ROC AUC: 0.8666
# Epoch [9/10], Balance 0.43, Loss: 0.5443, Train ROC AUC: 0.7753
# Epoch [9/10], Balance 0.44, Loss: 0.4712, Train ROC AUC: 0.8490
# Epoch [9/10], Balance 0.38, Loss: 0.4292, Train ROC AUC: 0.8901
# Epoch [9/10], Balance 0.34, Loss: 0.5107, Train ROC AUC: 0.7965
# Epoch [9/10], Balance 0.43, Loss: 0.5027, Train ROC AUC: 0.8254
# Epoch [9/10], Balance 0.41, Loss: 0.4931, Train ROC AUC: 0.8226
# Epoch [9/10], Balance 0.36, Loss: 0.4402, Train ROC AUC: 0.8666
# Epoch [9/10], Balance 0.50, Loss: 0.4704, Train ROC AUC: 0.8599
# Epoch [9/10], Balance 0.39, Loss: 0.5101, Train ROC AUC: 0.8308
# Epoch [9/10], Balance 0.40, Loss: 0.4493, Train ROC AUC: 0.8551
# Epoch [9/10], Balance 0.43, Loss: 0.5023, Train ROC AUC: 0.8511
# Epoch [9/10], Balance 0.46, Loss: 0.5535, Train ROC AUC: 0.7924
# Epoch [9/10], Balance 0.35, Loss: 0.5320, Train ROC AUC: 0.7952
# Epoch [9/10], Balance 0.45, Loss: 0.4574, Train ROC AUC: 0.8621
# Epoch [9/10], Balance 0.44, Loss: 0.4666, Train ROC AUC: 0.8542
# Epoch [9/10], Balance 0.37, Loss: 0.4581, Train ROC AUC: 0.8455
# Epoch [9/10], Balance 0.44, Loss: 0.4849, Train ROC AUC: 0.8312
# Epoch [9/10], Balance 0.42, Loss: 0.4894, Train ROC AUC: 0.8340
# Epoch [9/10], Balance 0.36, Loss: 0.4872, Train ROC AUC: 0.8028
# Epoch [9/10], Balance 0.38, Loss: 0.4784, Train ROC AUC: 0.8440
# Epoch [9/10], Balance 0.39, Loss: 0.4802, Train ROC AUC: 0.8236
# Epoch [9/10], Balance 0.43, Loss: 0.5526, Train ROC AUC: 0.7821
# Epoch [9/10], Balance 0.43, Loss: 0.5724, Train ROC AUC: 0.8057
# Epoch [9/10], Balance 0.39, Loss: 0.5553, Train ROC AUC: 0.7477
# Epoch [9/10], Balance 0.48, Loss: 0.4523, Train ROC AUC: 0.8882
# Epoch [9/10], Balance 0.42, Loss: 0.5075, Train ROC AUC: 0.8291
# Epoch [9/10], Balance 0.41, Loss: 0.5223, Train ROC AUC: 0.7862
# Epoch [9/10], Balance 0.30, Loss: 0.5403, Train ROC AUC: 0.7959
#
# Epoch [9/10], Val ROC AUC: 0.8617
#
# Epoch [10/10], Balance 0.49, Loss: 0.4949, Train ROC AUC: 0.8342
# Epoch [10/10], Balance 0.48, Loss: 0.4810, Train ROC AUC: 0.8479
# Epoch [10/10], Balance 0.54, Loss: 0.5179, Train ROC AUC: 0.8175
# Epoch [10/10], Balance 0.47, Loss: 0.4379, Train ROC AUC: 0.8620
# Epoch [10/10], Balance 0.55, Loss: 0.5151, Train ROC AUC: 0.8298
# Epoch [10/10], Balance 0.46, Loss: 0.5066, Train ROC AUC: 0.8391
# Epoch [10/10], Balance 0.54, Loss: 0.5383, Train ROC AUC: 0.8040
# Epoch [10/10], Balance 0.51, Loss: 0.4916, Train ROC AUC: 0.8493
# Epoch [10/10], Balance 0.41, Loss: 0.4925, Train ROC AUC: 0.8387
# Epoch [10/10], Balance 0.48, Loss: 0.5151, Train ROC AUC: 0.8194
# Epoch [10/10], Balance 0.41, Loss: 0.4279, Train ROC AUC: 0.8833
# Epoch [10/10], Balance 0.50, Loss: 0.5160, Train ROC AUC: 0.8235
# Epoch [10/10], Balance 0.45, Loss: 0.4916, Train ROC AUC: 0.8468
# Epoch [10/10], Balance 0.55, Loss: 0.4728, Train ROC AUC: 0.8488
# Epoch [10/10], Balance 0.46, Loss: 0.5676, Train ROC AUC: 0.7883
# Epoch [10/10], Balance 0.52, Loss: 0.5017, Train ROC AUC: 0.8356
# Epoch [10/10], Balance 0.52, Loss: 0.4048, Train ROC AUC: 0.9085
# Epoch [10/10], Balance 0.45, Loss: 0.5038, Train ROC AUC: 0.8349
# Epoch [10/10], Balance 0.46, Loss: 0.4376, Train ROC AUC: 0.8725
# Epoch [10/10], Balance 0.46, Loss: 0.4850, Train ROC AUC: 0.8534
# Epoch [10/10], Balance 0.42, Loss: 0.4380, Train ROC AUC: 0.8791
# Epoch [10/10], Balance 0.48, Loss: 0.4252, Train ROC AUC: 0.8931
# Epoch [10/10], Balance 0.53, Loss: 0.5156, Train ROC AUC: 0.8397
# Epoch [10/10], Balance 0.52, Loss: 0.4918, Train ROC AUC: 0.8429
# Epoch [10/10], Balance 0.40, Loss: 0.5330, Train ROC AUC: 0.7902
# Epoch [10/10], Balance 0.36, Loss: 0.4893, Train ROC AUC: 0.8452
# Epoch [10/10], Balance 0.38, Loss: 0.4329, Train ROC AUC: 0.8706
# Epoch [10/10], Balance 0.58, Loss: 0.5313, Train ROC AUC: 0.8208
# Epoch [10/10], Balance 0.47, Loss: 0.5003, Train ROC AUC: 0.8331
# Epoch [10/10], Balance 0.45, Loss: 0.4633, Train ROC AUC: 0.8592
# Epoch [10/10], Balance 0.53, Loss: 0.4181, Train ROC AUC: 0.8915
# Epoch [10/10], Balance 0.46, Loss: 0.4986, Train ROC AUC: 0.8320
# Epoch [10/10], Balance 0.45, Loss: 0.4826, Train ROC AUC: 0.8530
# Epoch [10/10], Balance 0.43, Loss: 0.5069, Train ROC AUC: 0.8250
# Epoch [10/10], Balance 0.45, Loss: 0.5470, Train ROC AUC: 0.8127
# Epoch [10/10], Balance 0.38, Loss: 0.5347, Train ROC AUC: 0.8328
# Epoch [10/10], Balance 0.45, Loss: 0.4509, Train ROC AUC: 0.8815
# Epoch [10/10], Balance 0.47, Loss: 0.4753, Train ROC AUC: 0.8583
# Epoch [10/10], Balance 0.50, Loss: 0.4598, Train ROC AUC: 0.8501
# Epoch [10/10], Balance 0.44, Loss: 0.4744, Train ROC AUC: 0.8301
# Epoch [10/10], Balance 0.45, Loss: 0.5239, Train ROC AUC: 0.7924
# Epoch [10/10], Balance 0.45, Loss: 0.4837, Train ROC AUC: 0.8495
# Epoch [10/10], Balance 0.48, Loss: 0.4727, Train ROC AUC: 0.8538
# Epoch [10/10], Balance 0.42, Loss: 0.5159, Train ROC AUC: 0.8131
# Epoch [10/10], Balance 0.40, Loss: 0.4544, Train ROC AUC: 0.8579
# Epoch [10/10], Balance 0.42, Loss: 0.4833, Train ROC AUC: 0.8387
# Epoch [10/10], Balance 0.42, Loss: 0.4623, Train ROC AUC: 0.8746
# Epoch [10/10], Balance 0.40, Loss: 0.4478, Train ROC AUC: 0.8556
# Epoch [10/10], Balance 0.39, Loss: 0.5246, Train ROC AUC: 0.8113
# Epoch [10/10], Balance 0.42, Loss: 0.5054, Train ROC AUC: 0.8151
# Epoch [10/10], Balance 0.42, Loss: 0.4588, Train ROC AUC: 0.8555
# Epoch [10/10], Balance 0.45, Loss: 0.4254, Train ROC AUC: 0.8878
# Epoch [10/10], Balance 0.49, Loss: 0.4694, Train ROC AUC: 0.8620
# Epoch [10/10], Balance 0.41, Loss: 0.4740, Train ROC AUC: 0.8544
# Epoch [10/10], Balance 0.40, Loss: 0.5241, Train ROC AUC: 0.8021
# Epoch [10/10], Balance 0.44, Loss: 0.4471, Train ROC AUC: 0.8843
# Epoch [10/10], Balance 0.45, Loss: 0.5039, Train ROC AUC: 0.8186
# Epoch [10/10], Balance 0.44, Loss: 0.4761, Train ROC AUC: 0.8442
# Epoch [10/10], Balance 0.46, Loss: 0.5120, Train ROC AUC: 0.8179
# Epoch [10/10], Balance 0.42, Loss: 0.4033, Train ROC AUC: 0.9089
# Epoch [10/10], Balance 0.42, Loss: 0.4625, Train ROC AUC: 0.8438
# Epoch [10/10], Balance 0.41, Loss: 0.4561, Train ROC AUC: 0.8571
# Epoch [10/10], Balance 0.38, Loss: 0.5140, Train ROC AUC: 0.8158
# Epoch [10/10], Balance 0.40, Loss: 0.4861, Train ROC AUC: 0.8396
# Epoch [10/10], Balance 0.38, Loss: 0.4358, Train ROC AUC: 0.8844
# Epoch [10/10], Balance 0.40, Loss: 0.4386, Train ROC AUC: 0.8694
# Epoch [10/10], Balance 0.43, Loss: 0.4699, Train ROC AUC: 0.8461
# Epoch [10/10], Balance 0.49, Loss: 0.5430, Train ROC AUC: 0.8170
# Epoch [10/10], Balance 0.42, Loss: 0.5245, Train ROC AUC: 0.8332
# Epoch [10/10], Balance 0.43, Loss: 0.5434, Train ROC AUC: 0.8147
# Epoch [10/10], Balance 0.35, Loss: 0.4281, Train ROC AUC: 0.8809
# Epoch [10/10], Balance 0.37, Loss: 0.3984, Train ROC AUC: 0.8939
# Epoch [10/10], Balance 0.39, Loss: 0.5043, Train ROC AUC: 0.8156
# Epoch [10/10], Balance 0.35, Loss: 0.4729, Train ROC AUC: 0.8416
# Epoch [10/10], Balance 0.40, Loss: 0.4671, Train ROC AUC: 0.8591
# Epoch [10/10], Balance 0.51, Loss: 0.4772, Train ROC AUC: 0.8495
# Epoch [10/10], Balance 0.39, Loss: 0.4959, Train ROC AUC: 0.7992
# Epoch [10/10], Balance 0.37, Loss: 0.4751, Train ROC AUC: 0.8256
# Epoch [10/10], Balance 0.34, Loss: 0.4123, Train ROC AUC: 0.8854
# Epoch [10/10], Balance 0.41, Loss: 0.5175, Train ROC AUC: 0.8262
# Epoch [10/10], Balance 0.38, Loss: 0.5263, Train ROC AUC: 0.7755
# Epoch [10/10], Balance 0.38, Loss: 0.4545, Train ROC AUC: 0.8760
# Epoch [10/10], Balance 0.37, Loss: 0.4841, Train ROC AUC: 0.8004
# Epoch [10/10], Balance 0.38, Loss: 0.4213, Train ROC AUC: 0.8887
# Epoch [10/10], Balance 0.37, Loss: 0.4949, Train ROC AUC: 0.8266
# Epoch [10/10], Balance 0.38, Loss: 0.4682, Train ROC AUC: 0.8219
# Epoch [10/10], Balance 0.38, Loss: 0.5277, Train ROC AUC: 0.7911
# Epoch [10/10], Balance 0.34, Loss: 0.4420, Train ROC AUC: 0.8503
# Epoch [10/10], Balance 0.36, Loss: 0.4054, Train ROC AUC: 0.8836
# Epoch [10/10], Balance 0.34, Loss: 0.4248, Train ROC AUC: 0.8916
# Epoch [10/10], Balance 0.32, Loss: 0.4364, Train ROC AUC: 0.8560
# Epoch [10/10], Balance 0.43, Loss: 0.4269, Train ROC AUC: 0.8785
# Epoch [10/10], Balance 0.42, Loss: 0.4758, Train ROC AUC: 0.8433
# Epoch [10/10], Balance 0.39, Loss: 0.4924, Train ROC AUC: 0.8169
# Epoch [10/10], Balance 0.34, Loss: 0.4486, Train ROC AUC: 0.8460
# Epoch [10/10], Balance 0.44, Loss: 0.4740, Train ROC AUC: 0.8533
# Epoch [10/10], Balance 0.33, Loss: 0.3988, Train ROC AUC: 0.9039
# Epoch [10/10], Balance 0.33, Loss: 0.5041, Train ROC AUC: 0.8206
# Epoch [10/10], Balance 0.48, Loss: 0.5357, Train ROC AUC: 0.8131
# Epoch [10/10], Balance 0.31, Loss: 0.4737, Train ROC AUC: 0.8361
# Epoch [10/10], Balance 0.33, Loss: 0.4654, Train ROC AUC: 0.8234
# Epoch [10/10], Balance 0.32, Loss: 0.4277, Train ROC AUC: 0.8639
# Epoch [10/10], Balance 0.40, Loss: 0.4207, Train ROC AUC: 0.8956
# Epoch [10/10], Balance 0.34, Loss: 0.3837, Train ROC AUC: 0.8975
# Epoch [10/10], Balance 0.32, Loss: 0.4139, Train ROC AUC: 0.8646
# Epoch [10/10], Balance 0.34, Loss: 0.4332, Train ROC AUC: 0.8658
# Epoch [10/10], Balance 0.37, Loss: 0.5319, Train ROC AUC: 0.8001
# Epoch [10/10], Balance 0.30, Loss: 0.4544, Train ROC AUC: 0.8436
#
# Epoch [10/10], Val ROC AUC: 0.8568

# %%
plt.style.use('seaborn-colorblind')
plt.rcParams.update({'font.size': 16, 
                     'legend.framealpha':1, 
                     'legend.edgecolor':'inherit'}) 
plt.figure(figsize=(9, 6))

plt.plot(losses,label='Train loss')
#plt.ylim([.4, .8])
plt.legend()
plt.show()

# %%
plt.style.use('seaborn-colorblind')
plt.rcParams.update({'font.size': 16, 
                     'legend.framealpha':1, 
                     'legend.edgecolor':'inherit'}) 
plt.figure(figsize=(9, 6))

plt.plot(train_roc, label = 'Train ROC AUC')
plt.legend()
plt.show()

# %%
plt.style.use('seaborn-colorblind')
plt.rcParams.update({'font.size': 16, 
                     'legend.framealpha':1, 
                     'legend.edgecolor':'inherit'}) 
plt.figure(figsize=(9, 6))

plt.plot(val_roc, label = 'Validation ROC AUC')
plt.legend()
plt.show()

# %%
valid_predictions = []
valid_targets = []

model.eval() # prep model for evaluation
with torch.no_grad():
    for i, (images, labels) in enumerate(valid_loader):
        images = images.to(device)

        labels = torch.reshape(labels, [len(labels), 1])
        labels = labels.to(device)

        # Forward pass
        outputs = model(images)
        valid_predictions += list(outputs.detach().cpu().numpy().ravel())
        valid_targets += list(labels.cpu().numpy().ravel()) 

fpr, tpr, _ = roc_curve(np.array(valid_targets, np.int), np.array(valid_predictions).ravel())
roc_auc = auc(fpr, tpr)

percent_tp = sum(valid_targets)/len(valid_targets) * 100 
baseline = np.max([percent_tp, 100-percent_tp])
acc = 100 * np.sum(np.round(valid_predictions) == np.array(valid_targets)) / len(valid_targets)

print('\nBaseline classification accuracy: {:.2f}'.format(baseline))
print('\nModel classification accuracy:    {:.2f}'.format(acc))

plt.style.use('seaborn-colorblind')
plt.rcParams.update({'font.size': 16, 
                     'legend.framealpha':1, 
                     'legend.edgecolor':'inherit'}) 
plt.figure(figsize=(9, 6))

lw = 2
plt.plot(fpr, tpr, 
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")

plt.tight_layout()
plt.show()
# Out:
# Baseline classification accuracy: 90.71
#
# Model classification accuracy:    89.69

# %%
tn, fp, fn, tp = confusion_matrix(np.array(valid_targets, np.int), np.round(np.array(valid_predictions).ravel())).ravel()

accuracy = (tp + tn) / len(valid_targets)
precision = tp / (tp + fp)
recall = tp / (tp + fn)
print("Model accuracy: {:.2f}".format(accuracy))
print("Model precision: {:.2f}".format(precision))
print("Model recall: {:.2f}".format(recall))

print("\nConfusion Matrix: ")
print(confusion_matrix(np.array(valid_targets, np.int), np.round(np.array(valid_predictions).ravel())))
# Out:
# Model accuracy: 0.90
# Model precision: 0.44
# Model recall: 0.40
#
# Confusion Matrix:
# [[2601  143]
#  [ 169  112]]

# %%
train_df.to_csv("CNN_train_df.csv", index=False)
val_df.to_csv("CNN_val_df.csv", index=False)
